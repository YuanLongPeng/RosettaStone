# %% [markdown]
# <a href="https://colab.research.google.com/github/YuanLongPeng/RosettaStone/blob/main/%E3%80%8CTransformer_Based%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The source code was adapted from https://colab.research.google.com/github/keras-team/keras-io/blob/master/examples/nlp/ipynb/neural_machine_translation_with_transformer.ipynb

# %%
import pathlib
import random
import string
import re
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

# %% [markdown]
# Download training and testing dataset.

# %%
def loadDataset(language):
  text_file = keras.utils.get_file(
      fname=language,
      origin="https://github.com/multi30k/dataset/raw/master/data/task1/raw/"+language,
      extract=True,
      cache_dir="/content/",
  )

  import gzip

  g = gzip.GzipFile(mode="rb", fileobj=open('/content/datasets/'+language, 'rb'))
  open(r"/content/datasets/" + language + '.txt', "wb").write(g.read())

  text_file = r"/content/datasets/" + language + '.txt'

  with open(text_file) as f:
      lines = f.read().split("\n")[:-1]
  text_pairs = []
  for line in lines:
      spa = "[start] " + line + " [end]"
      text_pairs.append(spa)
  
  return text_pairs

# %%
train_cs = loadDataset('train.cs.gz')
train_de = loadDataset('train.de.gz')
train_en = loadDataset('train.en.gz')
train_fr = loadDataset('train.fr.gz')
# Out:
# Downloading data from https://github.com/multi30k/dataset/raw/master/data/task1/raw/train.cs.gz
# 598016/593827 [==============================] - 0s 0us/step
# 606208/593827 [==============================] - 0s 0us/step
# Downloading data from https://github.com/multi30k/dataset/raw/master/data/task1/raw/train.de.gz
# 638976/637044 [==============================] - 0s 0us/step
# 647168/637044 [==============================] - 0s 0us/step
# Downloading data from https://github.com/multi30k/dataset/raw/master/data/task1/raw/train.en.gz
# 573440/568929 [==============================] - 0s 0us/step
# 581632/568929 [==============================] - 0s 0us/step
# Downloading data from https://github.com/multi30k/dataset/raw/master/data/task1/raw/train.fr.gz
# 606208/604242 [==============================] - 0s 0us/step
# 614400/604242 [==============================] - 0s 0us/step

# %%
val_cs = loadDataset('val.cs.gz')
val_de = loadDataset('val.de.gz')
val_en = loadDataset('val.en.gz')
val_fr = loadDataset('val.fr.gz')
# Out:
# Downloading data from https://github.com/multi30k/dataset/raw/master/data/task1/raw/val.cs.gz
# 24576/22096 [=================================] - 0s 0us/step
# 32768/22096 [============================================] - 0s 0us/step
# Downloading data from https://github.com/multi30k/dataset/raw/master/data/task1/raw/val.de.gz
# 32768/24681 [=======================================] - 0s 0us/step
# 40960/24681 [=================================================] - 0s 0us/step
# Downloading data from https://github.com/multi30k/dataset/raw/master/data/task1/raw/val.en.gz
# 24576/21650 [==================================] - 0s 0us/step
# 32768/21650 [=============================================] - 0s 0us/step
# Downloading data from https://github.com/multi30k/dataset/raw/master/data/task1/raw/val.fr.gz
# 24576/23001 [================================] - 0s 0us/step
# 32768/23001 [==========================================] - 0s 0us/step

# %% [markdown]
# Count distinguished words for embedding layer and count the maximum length of sentence.

# %%
len_train_cs = len(set(' '.join(train_cs).split(' '))) + 1
sequence_length_cs = max([len(pair.split(' ')) for pair in train_cs])
print(f'The number of embedding words for Czech: {len_train_cs}')
print(f'The maximum length of sentence for Czech: {sequence_length_cs}')

len_train_de = len(set(' '.join(train_de).split(' '))) + 1
sequence_length_de = max([len(pair.split(' ')) for pair in train_de])
print(f'The number of embedding words for Deutsch: {len_train_de}')
print(f'The maximum length of sentence for Deutsch: {sequence_length_de}')

len_train_en = len(set(' '.join(train_en).split(' '))) + 1
sequence_length_en = max([len(pair.split(' ')) for pair in train_en])
print(f'The number of embedding words for English: {len_train_en}')
print(f'The maximum length of sentence for English: {sequence_length_en}')

len_train_fr = len(set(' '.join(train_fr).split(' '))) + 1
sequence_length_fr = max([len(pair.split(' ')) for pair in train_fr])
print(f'The number of embedding words for French: {len_train_fr}')
print(f'The maximum length of sentence for French: {sequence_length_fr}')
# Out:
# The number of embedding words for Czech: 30177
# The maximum length of sentence for Czech: 35
# The number of embedding words for Deutsch: 24910
# The maximum length of sentence for Deutsch: 41
# The number of embedding words for English: 15460
# The maximum length of sentence for English: 39
# The number of embedding words for French: 17007
# The maximum length of sentence for French: 45

# %% [markdown]
# Prepare TextVectorization layer for encoders and decoders

# %%
strip_chars = string.punctuation.replace("[", "").replace("]", "")

def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")



sequence_length = max([sequence_length_cs, sequence_length_de, sequence_length_en, sequence_length_fr])
batch_size = 128

#TextVectorization layer for encoder of Czech
cs_vectorization = TextVectorization(
    max_tokens=len_train_cs, output_mode="int", output_sequence_length=sequence_length,
)

#TextVectorization layer for decoder of Czech
auto_cs_vectorization = TextVectorization(
    max_tokens=len_train_cs, output_mode="int", output_sequence_length=sequence_length+1, standardize=custom_standardization,
)

#TextVectorization layer for encoder of Deutsch
de_vectorization = TextVectorization(
    max_tokens=len_train_de, output_mode="int", output_sequence_length=sequence_length,
)

#TextVectorization layer for decoder of Deutsch
de_de_vectorization = TextVectorization(
    max_tokens=len_train_de, output_mode="int", output_sequence_length=sequence_length+1, standardize=custom_standardization,
)

#TextVectorization layer for encoder of English
en_vectorization = TextVectorization(
    max_tokens=len_train_en, output_mode="int", output_sequence_length=sequence_length+1, standardize=custom_standardization,
)

#TextVectorization layer for encoder of French
fr_vectorization = TextVectorization(
    max_tokens=len_train_fr, output_mode="int", output_sequence_length=sequence_length,
)

cs_vectorization.adapt(train_cs)
auto_cs_vectorization.adapt(train_cs)
de_vectorization.adapt(train_de)
de_de_vectorization.adapt(train_de)
en_vectorization.adapt(train_en)
fr_vectorization.adapt(train_fr)

# %% [markdown]
# Prepare data format for Czech to Deutsch and Czech.

# %%
def format_dataset(cs, de):
    auto_cs = auto_cs_vectorization(cs)
    input_cs = cs_vectorization(cs)
    de = de_de_vectorization(de)
    return ({"encoder_inputs": input_cs, "decoder_inputs": de[:, :-1], "autodecoder_inputs": auto_cs[:, :-1],}, {"de": de[:, 1:], "cs": auto_cs[:, 1:]})


def make_dataset(cs_texts, de_texts):
    cs_texts = list(cs_texts)
    de_texts = list(de_texts)
    dataset = tf.data.Dataset.from_tensor_slices((cs_texts, de_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds = make_dataset(train_cs, train_de)

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["Czech encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["Deutsch decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f'inputs["Czech decoder_inputs"].shape: {inputs["autodecoder_inputs"].shape}')
    print(f"Deutsch targets.shape: {targets['de'].shape}")
    print(f"Czech targets.shape: {targets['cs'].shape}")
# Out:
# inputs["Czech encoder_inputs"].shape: (128, 45)
# inputs["Deutsch decoder_inputs"].shape: (128, 45)
# inputs["Czech decoder_inputs"].shape: (128, 45)
# Deutsch targets.shape: (128, 45)
# Czech targets.shape: (128, 45)

# %% [markdown]
# Define the encoder and decoder of Transformer model

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super(TransformerEncoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, mask=None):
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, tf.newaxis, :], dtype="int32")
        attention_output = self.attention(
            query=inputs, value=inputs, key=inputs, attention_mask=padding_mask
        )
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super(PositionalEmbedding, self).__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super(TransformerDecoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(latent_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, attention_mask=causal_mask
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)

# %% [markdown]
# Create the encoder of Czech, decoder of Deutsch and decoder of Czech.
#
# Define the model of Czech to Deutsch and Czech.

# %%
embed_dim = 256
latent_dim = 2048
num_heads = 8

#####################Create encoder of Czech#############################################################
encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")
x = PositionalEmbedding(sequence_length, len_train_cs, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
encoder = keras.Model(encoder_inputs, encoder_outputs)


#####################Create decoder of Deutsch#############################################################
decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="decoder_state_inputs")
x = PositionalEmbedding(sequence_length, len_train_de, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(len_train_de, activation="softmax")(x)
decoder = keras.Model([decoder_inputs, encoded_seq_inputs], decoder_outputs, name="de")


#####################Create decoder of Czech#############################################################
autodecoder_inputs = keras.Input(shape=(None,), dtype="int64", name="autodecoder_inputs")
autoencoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="autodecoder_state_inputs")
x = PositionalEmbedding(sequence_length, len_train_cs, embed_dim)(autodecoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, autoencoded_seq_inputs)
x = layers.Dropout(0.5)(x)
autodecoder_outputs = layers.Dense(len_train_cs, activation="softmax")(x)
autodecoder = keras.Model([autodecoder_inputs, autoencoded_seq_inputs], autodecoder_outputs, name="cs")


#####################Define the model of Czech to Deutsch and Czech.#############################################################
decoder_outputs = decoder([decoder_inputs, encoder_outputs])
autodecoder_outputs = autodecoder([autodecoder_inputs, encoder_outputs])
transformer = keras.Model(
    [encoder_inputs, decoder_inputs, autodecoder_inputs], [decoder_outputs, autodecoder_outputs], name="transformer"
)

# %% [markdown]
# Train the model of Czech to Deutsch and Czech.

# %%
epochs = 100

transformer.summary()
transformer.compile(
    "adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
transformer.fit(train_ds, epochs=epochs)
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding (Position  (None, None, 256)   7736832     ['encoder_inputs[0][0]']
#  alEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder (Transform  (None, None, 256)   3155456     ['positional_embedding[0][0]']
#  erEncoder)
#
#  autodecoder_inputs (InputLayer  [(None, None)]      0           []
#  )
#
#  de (Functional)                (None, None, 24910)  18049870    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
#  cs (Functional)                (None, None, 30177)  20751841    ['autodecoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
# ==================================================================================================
# Total params: 49,693,999
# Trainable params: 49,693,999
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 227/227 [==============================] - 493s 2s/step - loss: 2.6598 - de_loss: 1.3393 - cs_loss: 1.3205 - de_accuracy: 0.3273 - cs_accuracy: 0.2959
# Epoch 2/100
# 227/227 [==============================] - 506s 2s/step - loss: 1.7331 - de_loss: 0.9547 - cs_loss: 0.7785 - de_accuracy: 0.4595 - cs_accuracy: 0.5549
# Epoch 3/100
# 227/227 [==============================] - 487s 2s/step - loss: 1.1422 - de_loss: 0.7840 - cs_loss: 0.3582 - de_accuracy: 0.5333 - cs_accuracy: 0.8142
# Epoch 4/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.8577 - de_loss: 0.6650 - cs_loss: 0.1927 - de_accuracy: 0.5825 - cs_accuracy: 0.8998
# Epoch 5/100
# 227/227 [==============================] - 503s 2s/step - loss: 0.6890 - de_loss: 0.5740 - cs_loss: 0.1150 - de_accuracy: 0.6196 - cs_accuracy: 0.9378
# Epoch 6/100
# 227/227 [==============================] - 512s 2s/step - loss: 0.5645 - de_loss: 0.4971 - cs_loss: 0.0674 - de_accuracy: 0.6520 - cs_accuracy: 0.9621
# Epoch 7/100
# 227/227 [==============================] - 512s 2s/step - loss: 0.4682 - de_loss: 0.4301 - cs_loss: 0.0381 - de_accuracy: 0.6835 - cs_accuracy: 0.9784
# Epoch 8/100
# 227/227 [==============================] - 504s 2s/step - loss: 0.3971 - de_loss: 0.3752 - cs_loss: 0.0219 - de_accuracy: 0.7113 - cs_accuracy: 0.9885
# Epoch 9/100
# 227/227 [==============================] - 499s 2s/step - loss: 0.3374 - de_loss: 0.3245 - cs_loss: 0.0130 - de_accuracy: 0.7420 - cs_accuracy: 0.9938
# Epoch 10/100
# 227/227 [==============================] - 501s 2s/step - loss: 0.2902 - de_loss: 0.2808 - cs_loss: 0.0094 - de_accuracy: 0.7700 - cs_accuracy: 0.9957
# Epoch 11/100
# 227/227 [==============================] - 506s 2s/step - loss: 0.2527 - de_loss: 0.2460 - cs_loss: 0.0067 - de_accuracy: 0.7928 - cs_accuracy: 0.9970
# Epoch 12/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.2240 - de_loss: 0.2187 - cs_loss: 0.0053 - de_accuracy: 0.8119 - cs_accuracy: 0.9975
# Epoch 13/100
# 227/227 [==============================] - 501s 2s/step - loss: 0.2013 - de_loss: 0.1967 - cs_loss: 0.0046 - de_accuracy: 0.8271 - cs_accuracy: 0.9978
# Epoch 14/100
# 227/227 [==============================] - 493s 2s/step - loss: 0.1816 - de_loss: 0.1773 - cs_loss: 0.0044 - de_accuracy: 0.8417 - cs_accuracy: 0.9978
# Epoch 15/100
# 227/227 [==============================] - 506s 2s/step - loss: 0.1636 - de_loss: 0.1590 - cs_loss: 0.0045 - de_accuracy: 0.8559 - cs_accuracy: 0.9974
# Epoch 16/100
# 227/227 [==============================] - 512s 2s/step - loss: 0.1509 - de_loss: 0.1460 - cs_loss: 0.0049 - de_accuracy: 0.8651 - cs_accuracy: 0.9970
# Epoch 17/100
# 227/227 [==============================] - 515s 2s/step - loss: 0.1397 - de_loss: 0.1356 - cs_loss: 0.0040 - de_accuracy: 0.8738 - cs_accuracy: 0.9975
# Epoch 18/100
# 227/227 [==============================] - 510s 2s/step - loss: 0.1289 - de_loss: 0.1251 - cs_loss: 0.0039 - de_accuracy: 0.8823 - cs_accuracy: 0.9974
# Epoch 19/100
# 227/227 [==============================] - 514s 2s/step - loss: 0.1197 - de_loss: 0.1156 - cs_loss: 0.0041 - de_accuracy: 0.8906 - cs_accuracy: 0.9971
# Epoch 20/100
# 227/227 [==============================] - 507s 2s/step - loss: 0.1091 - de_loss: 0.1056 - cs_loss: 0.0035 - de_accuracy: 0.8988 - cs_accuracy: 0.9974
# Epoch 21/100
# 227/227 [==============================] - 502s 2s/step - loss: 0.1023 - de_loss: 0.0983 - cs_loss: 0.0040 - de_accuracy: 0.9057 - cs_accuracy: 0.9969
# Epoch 22/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.0939 - de_loss: 0.0909 - cs_loss: 0.0030 - de_accuracy: 0.9122 - cs_accuracy: 0.9977
# Epoch 23/100
# 227/227 [==============================] - 497s 2s/step - loss: 0.0896 - de_loss: 0.0859 - cs_loss: 0.0037 - de_accuracy: 0.9161 - cs_accuracy: 0.9971
# Epoch 24/100
# 227/227 [==============================] - 488s 2s/step - loss: 0.0880 - de_loss: 0.0823 - cs_loss: 0.0056 - de_accuracy: 0.9193 - cs_accuracy: 0.9954
# Epoch 25/100
# 227/227 [==============================] - 485s 2s/step - loss: 0.0808 - de_loss: 0.0778 - cs_loss: 0.0031 - de_accuracy: 0.9236 - cs_accuracy: 0.9974
# Epoch 26/100
# 227/227 [==============================] - 488s 2s/step - loss: 0.0756 - de_loss: 0.0727 - cs_loss: 0.0029 - de_accuracy: 0.9281 - cs_accuracy: 0.9974
# Epoch 27/100
# 227/227 [==============================] - 484s 2s/step - loss: 0.0722 - de_loss: 0.0696 - cs_loss: 0.0026 - de_accuracy: 0.9315 - cs_accuracy: 0.9977
# Epoch 28/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.0667 - de_loss: 0.0644 - cs_loss: 0.0023 - de_accuracy: 0.9360 - cs_accuracy: 0.9979
# Epoch 29/100
# 227/227 [==============================] - 499s 2s/step - loss: 0.0661 - de_loss: 0.0622 - cs_loss: 0.0039 - de_accuracy: 0.9385 - cs_accuracy: 0.9967
# Epoch 30/100
# 227/227 [==============================] - 496s 2s/step - loss: 0.0615 - de_loss: 0.0584 - cs_loss: 0.0031 - de_accuracy: 0.9419 - cs_accuracy: 0.9971
# Epoch 31/100
# 227/227 [==============================] - 493s 2s/step - loss: 0.0579 - de_loss: 0.0556 - cs_loss: 0.0022 - de_accuracy: 0.9449 - cs_accuracy: 0.9978
# Epoch 32/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.0581 - de_loss: 0.0541 - cs_loss: 0.0040 - de_accuracy: 0.9460 - cs_accuracy: 0.9963
# Epoch 33/100
# 227/227 [==============================] - 492s 2s/step - loss: 0.0572 - de_loss: 0.0527 - cs_loss: 0.0045 - de_accuracy: 0.9479 - cs_accuracy: 0.9956
# Epoch 34/100
# 227/227 [==============================] - 489s 2s/step - loss: 0.0514 - de_loss: 0.0490 - cs_loss: 0.0025 - de_accuracy: 0.9514 - cs_accuracy: 0.9977
# Epoch 35/100
# 227/227 [==============================] - 500s 2s/step - loss: 0.0503 - de_loss: 0.0477 - cs_loss: 0.0026 - de_accuracy: 0.9526 - cs_accuracy: 0.9975
# Epoch 36/100
# 227/227 [==============================] - 497s 2s/step - loss: 0.0475 - de_loss: 0.0452 - cs_loss: 0.0023 - de_accuracy: 0.9548 - cs_accuracy: 0.9976
# Epoch 37/100
# 227/227 [==============================] - 495s 2s/step - loss: 0.0461 - de_loss: 0.0435 - cs_loss: 0.0026 - de_accuracy: 0.9567 - cs_accuracy: 0.9973
# Epoch 38/100
# 227/227 [==============================] - 493s 2s/step - loss: 0.0455 - de_loss: 0.0425 - cs_loss: 0.0029 - de_accuracy: 0.9577 - cs_accuracy: 0.9971
# Epoch 39/100
# 227/227 [==============================] - 493s 2s/step - loss: 0.0424 - de_loss: 0.0399 - cs_loss: 0.0025 - de_accuracy: 0.9606 - cs_accuracy: 0.9975
# Epoch 40/100
# 227/227 [==============================] - 487s 2s/step - loss: 0.0397 - de_loss: 0.0381 - cs_loss: 0.0016 - de_accuracy: 0.9617 - cs_accuracy: 0.9983
# Epoch 41/100
# 227/227 [==============================] - 495s 2s/step - loss: 0.0383 - de_loss: 0.0368 - cs_loss: 0.0015 - de_accuracy: 0.9632 - cs_accuracy: 0.9984
# Epoch 42/100
# 227/227 [==============================] - 500s 2s/step - loss: 0.0376 - de_loss: 0.0353 - cs_loss: 0.0023 - de_accuracy: 0.9645 - cs_accuracy: 0.9978
# Epoch 43/100
# 227/227 [==============================] - 495s 2s/step - loss: 0.0422 - de_loss: 0.0376 - cs_loss: 0.0046 - de_accuracy: 0.9623 - cs_accuracy: 0.9955
# Epoch 44/100
# 227/227 [==============================] - 495s 2s/step - loss: 0.0379 - de_loss: 0.0355 - cs_loss: 0.0025 - de_accuracy: 0.9644 - cs_accuracy: 0.9975
# Epoch 45/100
# 227/227 [==============================] - 492s 2s/step - loss: 0.0396 - de_loss: 0.0353 - cs_loss: 0.0043 - de_accuracy: 0.9648 - cs_accuracy: 0.9961
# Epoch 46/100
# 227/227 [==============================] - 489s 2s/step - loss: 0.0375 - de_loss: 0.0344 - cs_loss: 0.0031 - de_accuracy: 0.9656 - cs_accuracy: 0.9967
# Epoch 47/100
# 227/227 [==============================] - 491s 2s/step - loss: 0.0340 - de_loss: 0.0319 - cs_loss: 0.0021 - de_accuracy: 0.9679 - cs_accuracy: 0.9979
# Epoch 48/100
# 227/227 [==============================] - 491s 2s/step - loss: 0.0335 - de_loss: 0.0313 - cs_loss: 0.0021 - de_accuracy: 0.9687 - cs_accuracy: 0.9978
# Epoch 49/100
# 227/227 [==============================] - 489s 2s/step - loss: 0.0325 - de_loss: 0.0307 - cs_loss: 0.0018 - de_accuracy: 0.9693 - cs_accuracy: 0.9981
# Epoch 50/100
# 227/227 [==============================] - 495s 2s/step - loss: 0.0297 - de_loss: 0.0283 - cs_loss: 0.0013 - de_accuracy: 0.9717 - cs_accuracy: 0.9985
# Epoch 51/100
# 227/227 [==============================] - 490s 2s/step - loss: 0.0292 - de_loss: 0.0277 - cs_loss: 0.0015 - de_accuracy: 0.9721 - cs_accuracy: 0.9984
# Epoch 52/100
# 227/227 [==============================] - 479s 2s/step - loss: 0.0293 - de_loss: 0.0279 - cs_loss: 0.0014 - de_accuracy: 0.9723 - cs_accuracy: 0.9984
# Epoch 53/100
# 227/227 [==============================] - 485s 2s/step - loss: 0.0294 - de_loss: 0.0276 - cs_loss: 0.0019 - de_accuracy: 0.9721 - cs_accuracy: 0.9980
# Epoch 54/100
# 227/227 [==============================] - 491s 2s/step - loss: 0.0393 - de_loss: 0.0319 - cs_loss: 0.0073 - de_accuracy: 0.9684 - cs_accuracy: 0.9934
# Epoch 55/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.0331 - de_loss: 0.0295 - cs_loss: 0.0036 - de_accuracy: 0.9707 - cs_accuracy: 0.9964
# Epoch 56/100
# 227/227 [==============================] - 489s 2s/step - loss: 0.0288 - de_loss: 0.0265 - cs_loss: 0.0023 - de_accuracy: 0.9734 - cs_accuracy: 0.9978
# Epoch 57/100
# 227/227 [==============================] - 497s 2s/step - loss: 0.0259 - de_loss: 0.0240 - cs_loss: 0.0019 - de_accuracy: 0.9761 - cs_accuracy: 0.9981
# Epoch 58/100
# 227/227 [==============================] - 496s 2s/step - loss: 0.0259 - de_loss: 0.0240 - cs_loss: 0.0018 - de_accuracy: 0.9761 - cs_accuracy: 0.9980
# Epoch 59/100
# 227/227 [==============================] - 495s 2s/step - loss: 0.0248 - de_loss: 0.0231 - cs_loss: 0.0017 - de_accuracy: 0.9768 - cs_accuracy: 0.9982
# Epoch 60/100
# 227/227 [==============================] - 499s 2s/step - loss: 0.0256 - de_loss: 0.0231 - cs_loss: 0.0025 - de_accuracy: 0.9769 - cs_accuracy: 0.9977
# Epoch 61/100
# 227/227 [==============================] - 489s 2s/step - loss: 0.0273 - de_loss: 0.0244 - cs_loss: 0.0029 - de_accuracy: 0.9756 - cs_accuracy: 0.9972
# Epoch 62/100
# 227/227 [==============================] - 495s 2s/step - loss: 0.0260 - de_loss: 0.0236 - cs_loss: 0.0024 - de_accuracy: 0.9768 - cs_accuracy: 0.9977
# Epoch 63/100
# 227/227 [==============================] - 489s 2s/step - loss: 0.0246 - de_loss: 0.0226 - cs_loss: 0.0019 - de_accuracy: 0.9773 - cs_accuracy: 0.9980
# Epoch 64/100
# 227/227 [==============================] - 499s 2s/step - loss: 0.0235 - de_loss: 0.0220 - cs_loss: 0.0015 - de_accuracy: 0.9781 - cs_accuracy: 0.9985
# Epoch 65/100
# 227/227 [==============================] - 497s 2s/step - loss: 0.0262 - de_loss: 0.0231 - cs_loss: 0.0031 - de_accuracy: 0.9768 - cs_accuracy: 0.9969
# Epoch 66/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.0251 - de_loss: 0.0220 - cs_loss: 0.0031 - de_accuracy: 0.9779 - cs_accuracy: 0.9973
# Epoch 67/100
# 227/227 [==============================] - 496s 2s/step - loss: 0.0242 - de_loss: 0.0215 - cs_loss: 0.0027 - de_accuracy: 0.9785 - cs_accuracy: 0.9974
# Epoch 68/100
# 227/227 [==============================] - 498s 2s/step - loss: 0.0222 - de_loss: 0.0208 - cs_loss: 0.0014 - de_accuracy: 0.9795 - cs_accuracy: 0.9985
# Epoch 69/100
# 227/227 [==============================] - 493s 2s/step - loss: 0.0209 - de_loss: 0.0197 - cs_loss: 0.0012 - de_accuracy: 0.9802 - cs_accuracy: 0.9987
# Epoch 70/100
# 227/227 [==============================] - 498s 2s/step - loss: 0.0204 - de_loss: 0.0192 - cs_loss: 0.0013 - de_accuracy: 0.9809 - cs_accuracy: 0.9986
# Epoch 71/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.0207 - de_loss: 0.0192 - cs_loss: 0.0015 - de_accuracy: 0.9811 - cs_accuracy: 0.9986
# Epoch 72/100
# 227/227 [==============================] - 491s 2s/step - loss: 0.0205 - de_loss: 0.0192 - cs_loss: 0.0014 - de_accuracy: 0.9809 - cs_accuracy: 0.9986
# Epoch 73/100
# 227/227 [==============================] - 503s 2s/step - loss: 0.0221 - de_loss: 0.0202 - cs_loss: 0.0020 - de_accuracy: 0.9799 - cs_accuracy: 0.9979
# Epoch 74/100
# 227/227 [==============================] - 489s 2s/step - loss: 0.0224 - de_loss: 0.0199 - cs_loss: 0.0025 - de_accuracy: 0.9802 - cs_accuracy: 0.9977
# Epoch 75/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.0237 - de_loss: 0.0208 - cs_loss: 0.0028 - de_accuracy: 0.9793 - cs_accuracy: 0.9972
# Epoch 76/100
# 227/227 [==============================] - 499s 2s/step - loss: 0.0209 - de_loss: 0.0186 - cs_loss: 0.0023 - de_accuracy: 0.9814 - cs_accuracy: 0.9977
# Epoch 77/100
# 227/227 [==============================] - 501s 2s/step - loss: 0.0190 - de_loss: 0.0174 - cs_loss: 0.0016 - de_accuracy: 0.9827 - cs_accuracy: 0.9984
# Epoch 78/100
# 227/227 [==============================] - 502s 2s/step - loss: 0.0200 - de_loss: 0.0178 - cs_loss: 0.0022 - de_accuracy: 0.9823 - cs_accuracy: 0.9978
# Epoch 79/100
# 227/227 [==============================] - 502s 2s/step - loss: 0.0205 - de_loss: 0.0181 - cs_loss: 0.0024 - de_accuracy: 0.9821 - cs_accuracy: 0.9976
# Epoch 80/100
# 227/227 [==============================] - 496s 2s/step - loss: 0.0198 - de_loss: 0.0176 - cs_loss: 0.0022 - de_accuracy: 0.9826 - cs_accuracy: 0.9979
# Epoch 81/100
# 227/227 [==============================] - 504s 2s/step - loss: 0.0185 - de_loss: 0.0169 - cs_loss: 0.0016 - de_accuracy: 0.9834 - cs_accuracy: 0.9983
# Epoch 82/100
# 227/227 [==============================] - 509s 2s/step - loss: 0.0174 - de_loss: 0.0162 - cs_loss: 0.0013 - de_accuracy: 0.9842 - cs_accuracy: 0.9986
# Epoch 83/100
# 227/227 [==============================] - 516s 2s/step - loss: 0.0161 - de_loss: 0.0151 - cs_loss: 0.0011 - de_accuracy: 0.9848 - cs_accuracy: 0.9989
# Epoch 84/100
# 227/227 [==============================] - 498s 2s/step - loss: 0.0185 - de_loss: 0.0169 - cs_loss: 0.0017 - de_accuracy: 0.9835 - cs_accuracy: 0.9984
# Epoch 85/100
# 227/227 [==============================] - 520s 2s/step - loss: 0.0228 - de_loss: 0.0189 - cs_loss: 0.0039 - de_accuracy: 0.9813 - cs_accuracy: 0.9965
# Epoch 86/100
# 227/227 [==============================] - 523s 2s/step - loss: 0.0188 - de_loss: 0.0170 - cs_loss: 0.0018 - de_accuracy: 0.9833 - cs_accuracy: 0.9982
# Epoch 87/100
# 227/227 [==============================] - 513s 2s/step - loss: 0.0166 - de_loss: 0.0154 - cs_loss: 0.0012 - de_accuracy: 0.9848 - cs_accuracy: 0.9987
# Epoch 88/100
# 227/227 [==============================] - 537s 2s/step - loss: 0.0155 - de_loss: 0.0143 - cs_loss: 0.0012 - de_accuracy: 0.9856 - cs_accuracy: 0.9988
# Epoch 89/100
# 227/227 [==============================] - 549s 2s/step - loss: 0.0165 - de_loss: 0.0147 - cs_loss: 0.0019 - de_accuracy: 0.9854 - cs_accuracy: 0.9982
# Epoch 90/100
# 227/227 [==============================] - 505s 2s/step - loss: 0.0199 - de_loss: 0.0170 - cs_loss: 0.0029 - de_accuracy: 0.9834 - cs_accuracy: 0.9974
# Epoch 91/100
# 227/227 [==============================] - 557s 2s/step - loss: 0.0200 - de_loss: 0.0176 - cs_loss: 0.0024 - de_accuracy: 0.9825 - cs_accuracy: 0.9975
# Epoch 92/100
# 227/227 [==============================] - 538s 2s/step - loss: 0.0165 - de_loss: 0.0154 - cs_loss: 0.0012 - de_accuracy: 0.9848 - cs_accuracy: 0.9986
# Epoch 93/100
# 227/227 [==============================] - 521s 2s/step - loss: 0.0149 - de_loss: 0.0139 - cs_loss: 0.0010 - de_accuracy: 0.9864 - cs_accuracy: 0.9989
# Epoch 94/100
# 227/227 [==============================] - 508s 2s/step - loss: 0.0153 - de_loss: 0.0141 - cs_loss: 0.0012 - de_accuracy: 0.9861 - cs_accuracy: 0.9987
# Epoch 95/100
# 227/227 [==============================] - 506s 2s/step - loss: 0.0178 - de_loss: 0.0159 - cs_loss: 0.0019 - de_accuracy: 0.9844 - cs_accuracy: 0.9980
# Epoch 96/100
# 227/227 [==============================] - 494s 2s/step - loss: 0.0163 - de_loss: 0.0147 - cs_loss: 0.0017 - de_accuracy: 0.9856 - cs_accuracy: 0.9982
# Epoch 97/100
# 227/227 [==============================] - 513s 2s/step - loss: 0.0168 - de_loss: 0.0148 - cs_loss: 0.0020 - de_accuracy: 0.9855 - cs_accuracy: 0.9981
# Epoch 98/100
# 227/227 [==============================] - 535s 2s/step - loss: 0.0178 - de_loss: 0.0152 - cs_loss: 0.0026 - de_accuracy: 0.9854 - cs_accuracy: 0.9975
# Epoch 99/100
# 227/227 [==============================] - 534s 2s/step - loss: 0.0170 - de_loss: 0.0150 - cs_loss: 0.0019 - de_accuracy: 0.9854 - cs_accuracy: 0.9981
# Epoch 100/100
# 227/227 [==============================] - 530s 2s/step - loss: 0.0159 - de_loss: 0.0141 - cs_loss: 0.0018 - de_accuracy: 0.9865 - cs_accuracy: 0.9984

# %% [markdown]
# Decrease the learning rate to train the model of Czech to Deutsch and Czech.

# %%
epochs = 50  # This should be at least 30 for convergence

transformer.summary()
opt = keras.optimizers.Adam(learning_rate=0.0001)
transformer.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"], optimizer=opt)
transformer.fit(train_ds, epochs=epochs)#, validation_data=train_ds
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding (Position  (None, None, 256)   7736832     ['encoder_inputs[0][0]']
#  alEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder (Transform  (None, None, 256)   3155456     ['positional_embedding[0][0]']
#  erEncoder)
#
#  autodecoder_inputs (InputLayer  [(None, None)]      0           []
#  )
#
#  de (Functional)                (None, None, 24910)  18049870    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
#  cs (Functional)                (None, None, 30177)  20751841    ['autodecoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
# ==================================================================================================
# Total params: 49,693,999
# Trainable params: 49,693,999
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 227/227 [==============================] - 538s 2s/step - loss: 0.0086 - de_loss: 0.0078 - cs_loss: 8.8707e-04 - de_accuracy: 0.9925 - cs_accuracy: 0.9991
# Epoch 2/50
# 227/227 [==============================] - 536s 2s/step - loss: 0.0037 - de_loss: 0.0032 - cs_loss: 4.4087e-04 - de_accuracy: 0.9970 - cs_accuracy: 0.9995
# Epoch 3/50
# 227/227 [==============================] - 530s 2s/step - loss: 0.0023 - de_loss: 0.0020 - cs_loss: 2.7051e-04 - de_accuracy: 0.9982 - cs_accuracy: 0.9997
# Epoch 4/50
# 227/227 [==============================] - 530s 2s/step - loss: 0.0018 - de_loss: 0.0016 - cs_loss: 2.2426e-04 - de_accuracy: 0.9986 - cs_accuracy: 0.9997
# Epoch 5/50
# 227/227 [==============================] - 543s 2s/step - loss: 0.0014 - de_loss: 0.0013 - cs_loss: 1.6292e-04 - de_accuracy: 0.9989 - cs_accuracy: 0.9998
# Epoch 6/50
# 227/227 [==============================] - 536s 2s/step - loss: 0.0012 - de_loss: 0.0011 - cs_loss: 1.2952e-04 - de_accuracy: 0.9991 - cs_accuracy: 0.9998
# Epoch 7/50
# 227/227 [==============================] - 525s 2s/step - loss: 0.0011 - de_loss: 9.7844e-04 - cs_loss: 1.0824e-04 - de_accuracy: 0.9992 - cs_accuracy: 0.9999
# Epoch 8/50
# 227/227 [==============================] - 516s 2s/step - loss: 9.8692e-04 - de_loss: 8.8809e-04 - cs_loss: 9.8834e-05 - de_accuracy: 0.9993 - cs_accuracy: 0.9999
# Epoch 9/50
# 227/227 [==============================] - 521s 2s/step - loss: 8.9256e-04 - de_loss: 8.1225e-04 - cs_loss: 8.0318e-05 - de_accuracy: 0.9993 - cs_accuracy: 0.9999
# Epoch 10/50
# 227/227 [==============================] - 520s 2s/step - loss: 8.3197e-04 - de_loss: 7.4532e-04 - cs_loss: 8.6652e-05 - de_accuracy: 0.9994 - cs_accuracy: 0.9999
# Epoch 11/50
# 227/227 [==============================] - 516s 2s/step - loss: 7.2405e-04 - de_loss: 6.5363e-04 - cs_loss: 7.0422e-05 - de_accuracy: 0.9995 - cs_accuracy: 0.9999
# Epoch 12/50
# 227/227 [==============================] - 506s 2s/step - loss: 6.9583e-04 - de_loss: 6.2585e-04 - cs_loss: 6.9980e-05 - de_accuracy: 0.9995 - cs_accuracy: 0.9999
# Epoch 13/50
# 227/227 [==============================] - 508s 2s/step - loss: 6.7476e-04 - de_loss: 6.1133e-04 - cs_loss: 6.3436e-05 - de_accuracy: 0.9995 - cs_accuracy: 0.9999
# Epoch 14/50
# 227/227 [==============================] - 500s 2s/step - loss: 6.3868e-04 - de_loss: 5.8720e-04 - cs_loss: 5.1473e-05 - de_accuracy: 0.9995 - cs_accuracy: 1.0000
# Epoch 15/50
# 227/227 [==============================] - 505s 2s/step - loss: 5.6472e-04 - de_loss: 5.0718e-04 - cs_loss: 5.7546e-05 - de_accuracy: 0.9996 - cs_accuracy: 0.9999
# Epoch 16/50
# 227/227 [==============================] - 506s 2s/step - loss: 5.5304e-04 - de_loss: 5.0421e-04 - cs_loss: 4.8833e-05 - de_accuracy: 0.9996 - cs_accuracy: 1.0000
# Epoch 17/50
# 227/227 [==============================] - 554s 2s/step - loss: 5.3102e-04 - de_loss: 4.8394e-04 - cs_loss: 4.7076e-05 - de_accuracy: 0.9996 - cs_accuracy: 1.0000
# Epoch 18/50
# 227/227 [==============================] - 545s 2s/step - loss: 5.2133e-04 - de_loss: 4.8538e-04 - cs_loss: 3.5949e-05 - de_accuracy: 0.9996 - cs_accuracy: 1.0000
# Epoch 19/50
# 227/227 [==============================] - 499s 2s/step - loss: 4.7784e-04 - de_loss: 4.3672e-04 - cs_loss: 4.1118e-05 - de_accuracy: 0.9996 - cs_accuracy: 1.0000
# Epoch 20/50
# 227/227 [==============================] - 508s 2s/step - loss: 5.0193e-04 - de_loss: 4.6252e-04 - cs_loss: 3.9410e-05 - de_accuracy: 0.9996 - cs_accuracy: 1.0000
# Epoch 21/50
# 227/227 [==============================] - 506s 2s/step - loss: 4.6998e-04 - de_loss: 4.2809e-04 - cs_loss: 4.1892e-05 - de_accuracy: 0.9996 - cs_accuracy: 1.0000
# Epoch 22/50
# 227/227 [==============================] - 504s 2s/step - loss: 4.7442e-04 - de_loss: 4.2908e-04 - cs_loss: 4.5337e-05 - de_accuracy: 0.9996 - cs_accuracy: 1.0000
# Epoch 23/50
# 227/227 [==============================] - 501s 2s/step - loss: 4.5269e-04 - de_loss: 4.2043e-04 - cs_loss: 3.2255e-05 - de_accuracy: 0.9996 - cs_accuracy: 1.0000
# Epoch 24/50
# 227/227 [==============================] - 501s 2s/step - loss: 4.3212e-04 - de_loss: 3.9609e-04 - cs_loss: 3.6030e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 25/50
# 227/227 [==============================] - 507s 2s/step - loss: 4.2928e-04 - de_loss: 4.0357e-04 - cs_loss: 2.5708e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 26/50
# 227/227 [==============================] - 503s 2s/step - loss: 3.6230e-04 - de_loss: 3.3689e-04 - cs_loss: 2.5408e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 27/50
# 227/227 [==============================] - 504s 2s/step - loss: 4.0285e-04 - de_loss: 3.7137e-04 - cs_loss: 3.1479e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 28/50
# 227/227 [==============================] - 511s 2s/step - loss: 3.8619e-04 - de_loss: 3.6313e-04 - cs_loss: 2.3059e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 29/50
# 227/227 [==============================] - 501s 2s/step - loss: 3.8276e-04 - de_loss: 3.5460e-04 - cs_loss: 2.8153e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 30/50
# 227/227 [==============================] - 504s 2s/step - loss: 3.4398e-04 - de_loss: 3.2259e-04 - cs_loss: 2.1386e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 31/50
# 227/227 [==============================] - 507s 2s/step - loss: 3.9036e-04 - de_loss: 3.6673e-04 - cs_loss: 2.3635e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 32/50
# 227/227 [==============================] - 514s 2s/step - loss: 3.5797e-04 - de_loss: 3.3776e-04 - cs_loss: 2.0206e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 33/50
# 227/227 [==============================] - 513s 2s/step - loss: 3.4280e-04 - de_loss: 3.1863e-04 - cs_loss: 2.4167e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 34/50
# 227/227 [==============================] - 503s 2s/step - loss: 3.8274e-04 - de_loss: 3.6272e-04 - cs_loss: 2.0018e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 35/50
# 227/227 [==============================] - 497s 2s/step - loss: 3.3171e-04 - de_loss: 3.0202e-04 - cs_loss: 2.9689e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 36/50
# 227/227 [==============================] - 504s 2s/step - loss: 3.6887e-04 - de_loss: 3.5295e-04 - cs_loss: 1.5917e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 37/50
# 227/227 [==============================] - 509s 2s/step - loss: 2.9080e-04 - de_loss: 2.7487e-04 - cs_loss: 1.5936e-05 - de_accuracy: 0.9998 - cs_accuracy: 1.0000
# Epoch 38/50
# 227/227 [==============================] - 630s 3s/step - loss: 2.7728e-04 - de_loss: 2.6347e-04 - cs_loss: 1.3816e-05 - de_accuracy: 0.9998 - cs_accuracy: 1.0000
# Epoch 39/50
# 227/227 [==============================] - 621s 3s/step - loss: 3.1151e-04 - de_loss: 2.9284e-04 - cs_loss: 1.8669e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 40/50
# 227/227 [==============================] - 618s 3s/step - loss: 3.1584e-04 - de_loss: 3.0175e-04 - cs_loss: 1.4097e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 41/50
# 227/227 [==============================] - 625s 3s/step - loss: 3.2041e-04 - de_loss: 3.0352e-04 - cs_loss: 1.6888e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 42/50
# 227/227 [==============================] - 620s 3s/step - loss: 3.2338e-04 - de_loss: 3.0756e-04 - cs_loss: 1.5819e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 43/50
# 227/227 [==============================] - 623s 3s/step - loss: 2.9246e-04 - de_loss: 2.7525e-04 - cs_loss: 1.7213e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 44/50
# 227/227 [==============================] - 625s 3s/step - loss: 3.1811e-04 - de_loss: 2.8925e-04 - cs_loss: 2.8854e-05 - de_accuracy: 0.9997 - cs_accuracy: 1.0000
# Epoch 45/50
# 227/227 [==============================] - 624s 3s/step - loss: 2.6272e-04 - de_loss: 2.4647e-04 - cs_loss: 1.6255e-05 - de_accuracy: 0.9998 - cs_accuracy: 1.0000
# Epoch 46/50
# 227/227 [==============================] - 635s 3s/step - loss: 2.9914e-04 - de_loss: 2.8285e-04 - cs_loss: 1.6294e-05 - de_accuracy: 0.9998 - cs_accuracy: 1.0000
# Epoch 47/50
# 227/227 [==============================] - 634s 3s/step - loss: 2.4323e-04 - de_loss: 2.2611e-04 - cs_loss: 1.7122e-05 - de_accuracy: 0.9998 - cs_accuracy: 1.0000
# Epoch 48/50
# 227/227 [==============================] - 636s 3s/step - loss: 2.4331e-04 - de_loss: 2.3001e-04 - cs_loss: 1.3300e-05 - de_accuracy: 0.9998 - cs_accuracy: 1.0000
# Epoch 49/50
# 227/227 [==============================] - 640s 3s/step - loss: 2.4304e-04 - de_loss: 2.2581e-04 - cs_loss: 1.7236e-05 - de_accuracy: 0.9998 - cs_accuracy: 1.0000
# Epoch 50/50
# 227/227 [==============================] - 630s 3s/step - loss: 2.4762e-04 - de_loss: 2.3164e-04 - cs_loss: 1.5979e-05 - de_accuracy: 0.9998 - cs_accuracy: 1.0000

# %% [markdown]
# Prepare data format for Czech to English
#
# Create the decoder of English.
#
# Freeze encoder of Czech, decoder of Deutsch and decoder of Czech.
#
# Define the translation model of Czech to English.

# %%
#Prepare data format for Czech to English
def format_dataset(cs, en):
    input_cs = cs_vectorization(cs)
    en = en_vectorization(en)
    return ({"encoder_inputs": input_cs, "en_decoder_inputs": en[:, :-1]}, {"en": en[:, 1:]})


def make_dataset(cs_texts, en_texts):
    cs_texts = list(cs_texts)
    en_texts = list(en_texts)
    dataset = tf.data.Dataset.from_tensor_slices((cs_texts, en_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


#Create the decoder of English.
train_ds = make_dataset(train_cs, train_en)
en_decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="en_decoder_inputs")
en_encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="en_decoder_state_inputs")
x = PositionalEmbedding(sequence_length, len_train_en, embed_dim)(en_decoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, en_encoded_seq_inputs)
x = layers.Dropout(0.5)(x)
en_decoder_outputs = layers.Dense(len_train_en, activation="softmax")(x)
en_decoder = keras.Model([en_decoder_inputs, en_encoded_seq_inputs], en_decoder_outputs, name="en")

en_decoder_outputs = en_decoder([en_decoder_inputs, encoder_outputs])


#Freeze encoder of Czech, decoder of Deutsch and decoder of Czech.
encoder.trainable = False
decoder.trainable = False
autodecoder.trainable = False


#Define the translation model of Czech to English.
transformer_2en = keras.Model(
    [encoder_inputs, en_decoder_inputs], [en_decoder_outputs], name="transformer"
)

transformer_2en.summary()
transformer_2en.compile(
    "adam", loss=["sparse_categorical_crossentropy"], metrics=["accuracy"]
)
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding (Position  (None, None, 256)   7736832     ['encoder_inputs[0][0]']
#  alEmbedding)
#
#  en_decoder_inputs (InputLayer)  [(None, None)]      0           []
#
#  transformer_encoder (Transform  (None, None, 256)   3155456     ['positional_embedding[0][0]']
#  erEncoder)
#
#  en (Functional)                (None, None, 15460)  13202020    ['en_decoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
# ==================================================================================================
# Total params: 24,094,308
# Trainable params: 13,202,020
# Non-trainable params: 10,892,288
# __________________________________________________________________________________________________

# %% [markdown]
# Train the translation model of Czech to English.

# %%
epochs = 100
transformer_2en.fit(train_ds, epochs=epochs)
# Out:
# Epoch 1/100
# 227/227 [==============================] - 287s 1s/step - loss: 1.2526 - accuracy: 0.3883
# Epoch 2/100
# 227/227 [==============================] - 286s 1s/step - loss: 0.7944 - accuracy: 0.5550
# Epoch 3/100
# 227/227 [==============================] - 285s 1s/step - loss: 0.6364 - accuracy: 0.6193
# Epoch 4/100
# 227/227 [==============================] - 287s 1s/step - loss: 0.5457 - accuracy: 0.6554
# Epoch 5/100
# 227/227 [==============================] - 286s 1s/step - loss: 0.4821 - accuracy: 0.6806
# Epoch 6/100
# 227/227 [==============================] - 285s 1s/step - loss: 0.4326 - accuracy: 0.7011
# Epoch 7/100
# 227/227 [==============================] - 287s 1s/step - loss: 0.3893 - accuracy: 0.7214
# Epoch 8/100
# 227/227 [==============================] - 294s 1s/step - loss: 0.3533 - accuracy: 0.7394
# Epoch 9/100
# 227/227 [==============================] - 295s 1s/step - loss: 0.3224 - accuracy: 0.7557
# Epoch 10/100
# 227/227 [==============================] - 289s 1s/step - loss: 0.2956 - accuracy: 0.7708
# Epoch 11/100
# 227/227 [==============================] - 230s 1s/step - loss: 0.2720 - accuracy: 0.7841
# Epoch 12/100
# 227/227 [==============================] - 229s 1s/step - loss: 0.2534 - accuracy: 0.7952
# Epoch 13/100
# 227/227 [==============================] - 232s 1s/step - loss: 0.2354 - accuracy: 0.8056
# Epoch 14/100
# 227/227 [==============================] - 232s 1s/step - loss: 0.2199 - accuracy: 0.8161
# Epoch 15/100
# 227/227 [==============================] - 230s 1s/step - loss: 0.2045 - accuracy: 0.8259
# Epoch 16/100
# 227/227 [==============================] - 230s 1s/step - loss: 0.1905 - accuracy: 0.8363
# Epoch 17/100
# 227/227 [==============================] - 230s 1s/step - loss: 0.1776 - accuracy: 0.8449
# Epoch 18/100
# 227/227 [==============================] - 231s 1s/step - loss: 0.1661 - accuracy: 0.8525
# Epoch 19/100
# 227/227 [==============================] - 230s 1s/step - loss: 0.1587 - accuracy: 0.8582
# Epoch 20/100
# 227/227 [==============================] - 229s 1s/step - loss: 0.1493 - accuracy: 0.8655
# Epoch 21/100
# 227/227 [==============================] - 231s 1s/step - loss: 0.1414 - accuracy: 0.8708
# Epoch 22/100
# 227/227 [==============================] - 233s 1s/step - loss: 0.1341 - accuracy: 0.8767
# Epoch 23/100
# 227/227 [==============================] - 230s 1s/step - loss: 0.1276 - accuracy: 0.8813
# Epoch 24/100
# 227/227 [==============================] - 229s 1s/step - loss: 0.1214 - accuracy: 0.8867
# Epoch 25/100
# 227/227 [==============================] - 229s 1s/step - loss: 0.1157 - accuracy: 0.8914
# Epoch 26/100
# 227/227 [==============================] - 229s 1s/step - loss: 0.1098 - accuracy: 0.8962
# Epoch 27/100
# 227/227 [==============================] - 228s 1s/step - loss: 0.1062 - accuracy: 0.8988
# Epoch 28/100
# 227/227 [==============================] - 227s 1s/step - loss: 0.1021 - accuracy: 0.9028
# Epoch 29/100
# 227/227 [==============================] - 229s 1s/step - loss: 0.0993 - accuracy: 0.9048
# Epoch 30/100
# 227/227 [==============================] - 234s 1s/step - loss: 0.0959 - accuracy: 0.9076
# Epoch 31/100
# 227/227 [==============================] - 236s 1s/step - loss: 0.0919 - accuracy: 0.9115
# Epoch 32/100
# 227/227 [==============================] - 234s 1s/step - loss: 0.0897 - accuracy: 0.9134
# Epoch 33/100
# 227/227 [==============================] - 256s 1s/step - loss: 0.0873 - accuracy: 0.9154
# Epoch 34/100
# 227/227 [==============================] - 257s 1s/step - loss: 0.0844 - accuracy: 0.9179
# Epoch 35/100
# 227/227 [==============================] - 261s 1s/step - loss: 0.0814 - accuracy: 0.9208
# Epoch 36/100
# 227/227 [==============================] - 261s 1s/step - loss: 0.0797 - accuracy: 0.9225
# Epoch 37/100
#  14/227 [>.............................] - ETA: 4:07 - loss: 0.0780 - accuracy: 0.9262

# %% [markdown]
# Decrease learning rate to train the translation model of Czech to English.

# %%
epochs = 100

transformer_2en.summary()
opt = keras.optimizers.Adam(learning_rate=0.0001)
transformer_2en.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"], optimizer=opt)
transformer_2en.fit(train_ds, epochs=epochs)

# %% [markdown]
# Prepare data format for aligining French to Czech.
#
# Create the encoder of French.

# %%
def format_dataset(cs, de, fr, zero):
    auto_cs = auto_cs_vectorization(cs)
    input_cs = cs_vectorization(cs)
    input_fr = fr_vectorization(fr)
    de = de_de_vectorization(de)
    return ({"encoder_inputs": input_cs, "frencoder_inputs": input_fr, "decoder_inputs": de[:, :-1], "autodecoder_inputs": auto_cs[:, :-1],}, {"de": de[:, 1:], "cs": auto_cs[:, 1:], "zero": zero})


def make_dataset(cs_texts, de_texts, fr_texts):
    cs_texts = list(cs_texts)
    de_texts = list(de_texts)
    fr_texts = list(fr_texts)
    zero = np.zeros((len(fr_texts), sequence_length, embed_dim))
    dataset = tf.data.Dataset.from_tensor_slices((cs_texts, de_texts, fr_texts, zero))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds_fr = make_dataset(train_cs, train_de, train_fr)


###############Create the encoder of French.##########################################
frencoder_inputs = keras.Input(shape=(None,), dtype="int64", name="frencoder_inputs")
x = PositionalEmbedding(sequence_length, len_train_fr, embed_dim)(frencoder_inputs)
frencoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
frencoder = keras.Model(frencoder_inputs, frencoder_outputs)

subtracted = keras.layers.Subtract(name="zero")([frencoder_outputs, encoder_outputs])
zeroLayer = keras.Model([frencoder_outputs, encoder_outputs], subtracted, name="zero")

# %%
for inputs, targets in train_ds_fr.take(1):
    print(f'inputs["Czech encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["Deutsch decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f'inputs["Czech decoder_inputs"].shape: {inputs["autodecoder_inputs"].shape}')
    print(f'inputs["French encoder_inputs"].shape: {inputs["frencoder_inputs"].shape}')
    print(f"targets.shape: {targets['de'].shape}")
    print(f"targets.shape: {targets['cs'].shape}")
    print(f"targets.shape: {targets['zero'].shape}")

# %% [markdown]
# Define the loss function shown in Equation (1)
#
# Define the model of aligning encoder of French to Czech.
#
# Train the model of aligning encoder of French to Czech.

# %%
epochs = 100

import keras.backend as K


#Define the loss function shown in Equation (1)
def custom_loss(y_true, y_pred):

    loss_square = K.square(y_pred - y_true + K.epsilon())

    loss_sqrt = K.sqrt(K.abs(y_pred - y_true) + K.epsilon())
    
    return loss_square + loss_sqrt

decoder_outputs = decoder([decoder_inputs, frencoder_outputs])
autodecoder_outputs = autodecoder([autodecoder_inputs, frencoder_outputs])

encoder.trainable = False
decoder.trainable = False
autodecoder.trainable = False


#Define the model of aligning encoder of French to Czech.
transformer_stage_1 = keras.Model(
    [encoder_inputs, frencoder_inputs, decoder_inputs, autodecoder_inputs], [subtracted, decoder_outputs, autodecoder_outputs], name="transformer"
)

transformer_stage_1.summary()
transformer_stage_1.compile(
    "adam", loss=[custom_loss, "sparse_categorical_crossentropy", "sparse_categorical_crossentropy"], metrics=["accuracy"]
)


#Train the model of aligning encoder of French to Czech.
transformer_stage_1.fit(train_ds_fr, epochs=epochs)#, validation_data=train_ds

# %% [markdown]
# Decrease learning rate to train the model of aligning encoder of French to Czech.

# %%
epochs = 50

transformer_stage_1.summary()
opt = keras.optimizers.Adam(learning_rate=0.0001)
transformer_stage_1.compile(loss=[custom_loss, "sparse_categorical_crossentropy", "sparse_categorical_crossentropy"], metrics=["accuracy"], optimizer=opt)
transformer_stage_1.fit(train_ds_fr, epochs=epochs)

# %%
epochs = 50

transformer_stage_1.summary()
opt = keras.optimizers.Adam(learning_rate=0.00001)
transformer_stage_1.compile(loss=[custom_loss, "sparse_categorical_crossentropy", "sparse_categorical_crossentropy"], metrics=["accuracy"], optimizer=opt)
transformer_stage_1.fit(train_ds_fr, epochs=epochs)

# %% [markdown]
# Aligning French to Czech without mapping to Deutsch and Czech.

# %%
###############French
def format_dataset(cs, de, fr, zero):
    auto_cs = auto_cs_vectorization(cs)
    input_cs = cs_vectorization(cs)
    input_fr = fr_vectorization(fr)
    de = de_de_vectorization(de)
    return ({"encoder_inputs": input_cs, "frencoder_inputs": input_fr,}, {"zero": zero})


def make_dataset(cs_texts, de_texts, fr_texts):
    cs_texts = list(cs_texts)
    de_texts = list(de_texts)
    fr_texts = list(fr_texts)
    zero = np.zeros((len(fr_texts), sequence_length, embed_dim))
    dataset = tf.data.Dataset.from_tensor_slices((cs_texts, de_texts, fr_texts, zero))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds_fr = make_dataset(train_cs, train_de, train_fr)


epochs = 100

transformer_stage_1 = keras.Model(
    [encoder_inputs, frencoder_inputs], [subtracted], name="transformer"
)

transformer_stage_1.summary()
opt = keras.optimizers.Adam(learning_rate=0.00001)
transformer_stage_1.compile(loss=[custom_loss], metrics=["accuracy"], optimizer=opt)
transformer_stage_1.fit(train_ds_fr, epochs=epochs)#, validation_data=train_ds

# %% [markdown]
# Generate results of French to English.

# %%
en_vocab = en_vectorization.get_vocabulary()
en_index_lookup = dict(zip(range(len(en_vocab)), en_vocab))
max_decoded_sentence_length = sequence_length


decoder_outputs = en_decoder([en_decoder_inputs, frencoder_outputs])
transformer = keras.Model(
    [frencoder_inputs, en_decoder_inputs], [decoder_outputs], name="transformer"
)

def decode_sequence(input_sentence):
    tokenized_input_sentence = fr_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = en_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = en_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence

alltext = []
for i in range(len(val_fr)):
    translated = decode_sequence(val_fr[i])
    alltext.append(translated)
    print(translated)
# Out:
# [start] a group of men are responding to an emergency [end]
# [start] a man in a green tank top is putting up on a stool [end]
# [start] boy wearing a helmet sitting on a bench [end]
# [start] two men are shoveling cement on a skateboard while in a river [end]
# [start] a man with a long vest is sitting in a small childs wagon [end]
# [start] a woman in a red coat is walking with a male facepainted game and the exam [end]
# [start] a brown dog is running a black and white dog [end]
# [start] a young boy clings to the rope of the calf of the opposing of a softball game [end]
# [start] a man in a dark suit is taking a nap in front of a building [end]
# [start] a woman wearing a blue tank top is walking and talking to a pack of the determined sign [end]
# [start] a young child stands in a rock climbing [end]
# [start] a person is riding a piece of iron on the bench [end]
# [start] three young kids stand around a white and light blue [end]
# [start] a woman is sitting at a table with her hair asleep during a fountain [end]
# [start] a woman plays an instrument on a street [end]
# [start] three people are riding longboards down a grass [end]
# [start] a man with a mowhawk holds a large body of water [end]
# [start] a group of people stand in front of a construction site [end]
# [start] a young woman walking in a stream of water [end]
# [start] three girls are talking to each other while sitting on a sunny day [end]
# [start] a man in a black shirt is standing in front of a large pile of people [end]
# [start] a woman and man enjoy a rope of some sort of soda along a trail [end]
# [start] a man in a sleeveless shirt is swinging at a train [end]
# [start] a girl with a black hat and white outfit is deflecting a frozen buffet [end]
# [start] construction workers are standing on a structure that has been set up [end]
# [start] two dogs are playing with a bright colored dog [end]
# [start] a very young african american child is sitting on a rock [end]
# [start] three men walk down a dirt road [end]
# [start] a person is doing a split position on a rock face [end]
# [start] male golfer takes the turn through a turn in the sprinkler room [end]
# [start] a young girl runs on a stream of water [end]
# [start] a person is coming out of the ground with their arms raised [end]
# [start] a child plays on a playground equipment [end]
# [start] a person wearing a red longsleeve shirt and jacket on top of a bicycle that is standing in front of a brickandglass storefront [end]
# [start] a group of people gather around a man and a young boy is climbing in a game [end]
# [start] a woman sitting at a bar wearing a neon coat [end]
# [start] people are walking down a sidewalk with many guards [end]
# [start] a man with a green hat is reading the newspaper in a city street [end]
# [start] a large brown and white dog is being interviewed by the back [end]
# [start] a young boy in a blue shirt stands at a table with a building in the grass [end]
# [start] a young boy is sweeping a patio with a large bonfire [end]
# [start] a person prepares to throw a ball down from a bowling alley [end]
# [start] a band is playing music in a band that is at a concert event [end]
# [start] an elderly man is holding a brown dog with a cane [end]
# [start] a man is driving a crowded area with a bicycle [end]
# [start] young adults wearing blue and black helmets are watching a model airplane meet [end]
# [start] a young boy is throwing a rock at the water [end]
# [start] two women with blondhair are coming while sitting in front of the beach [end]
# [start] a man in a suit hat is standing in front of a row of video games [end]
# [start] a dog is running through a pool with a body of water while he stares [end]
# [start] three little kids having a good time [end]
# [start] two men are kayaking in a large body of water with trees in the background [end]
# [start] two girls walking down the street [end]
# [start] a group of kids are sitting on a back in a warm up site while chocolate are book [end]
# [start] people walking down the street and taking a nap in front of a bike in a back face [end]
# [start] a mexican man in the lot of a child in a bag with warm up and black pants on the front of trash bin [end]
# [start] a man in a restaurant at an outdoor area [end]
# [start] a man wearing a suit and hat is holding a utensil [end]
# [start] a man in a black suit jacket surfing [end]
# [start] a woman with a black purse sitting at a bench [end]
# [start] three smiling people and sitting down [end]
# [start] a yellow block a concert during a parade of onlookers [end]
# [start] a man in a baseball cap getting ready to pry [end]
# [start] two workers toil on a trench coat across a trench building with a surfer [end]
# [start] a woman dressed in a black and white outfit is walking by a man wearing a red and red dress [end]
# [start] a woman in a blue shirt and green knee is being interviewed by a flower market [end]
# [start] a man wearing a beret and tinted hand in the ears of a very in the background [end]
# [start] a baby is looking at the playground toy [end]
# [start] a couple of people are attending a frozen snack [end]
# [start] two young boys are playing with different colored chairs [end]
# [start] a bike rider looks down at night while customer onlookers [end]
# [start] two people are climbing a rock wall [end]
# [start] a man and a woman are having a conversation [end]
# [start] a child does a back flip while in the air on a rock [end]
# [start] children are shown in a gathering with metal parts [end]
# [start] two people with a bicycle showdown as they are in a heavily riot challenge and one is coming in a street [end]
# [start] two men dressed in business attire play the pavement [end]
# [start] a woman in a black dress and carrying a container of yarn is walking down the sidewalk [end]
# [start] a native american girl riding a toy coach [end]
# [start] a man standing on a dock is near a body of water with a lake [end]
# [start] a group of people are performing a routine [end]
# [start] a woman and a girl are sitting on a bench while wearing a white shirt and black walk along a sidewalk at sight [end]
# [start] a fireman going on a burning fire engine with a rake [end]
# [start] a person wearing a purple shirt painting a man on a wall [end]
# [start] a young girl holding a soccer ball that is silhouetted by the cause to the balls [end]
# [start] a young woman and her young males wearing a barely holding on them and a balloon are jumping on the same time at a ground while walking [end]
# [start] a woman walks in the snow covered ground is walking down [end]
# [start] the man was a teaching the class to cut out of his instruments [end]
# [start] a brown dog is running with a white and black ball [end]
# [start] a white and brown dog is running on a dirt hill [end]
# [start] a child is holding a literary classic to play [end]
# [start] an adult attempts to sell a long soda flying by a large light [end]
# [start] a young child and a woman are standing around a rooster with a handheld device [end]
# [start] a child sitting in a rubber outfit is pouring a hole [end]
# [start] a man in a brown outfit is laying down with his work [end]
# [start] a young woman is standing in front of a microphone while one in a crowd looks on [end]
# [start] two children are cutting into a hole [end]
# [start] many individuals are sitting on a bench with each other who is in full of them [end]
# [start] men are sitting around in a body of water with tent admiring their bikes [end]
# [start] a young man is dressed in a blue and white male is holding a cane [end]
# [start] an older man holds up his hands to get a soccer ball [end]
# [start] men dressed in yellow and white uniforms are sitting on a piece of gym floor with fire [end]
# [start] several people are standing around near the side of a body of water [end]
# [start] a black dog in a low budget sweater [end]
# [start] a tourist player is posing for a large wave in the air [end]
# [start] a group of kids playing in the water fountain [end]
# [start] a woman is smiling as she stands at a bar with her heart shaped like she is wearing a balloon [end]
# [start] two women are standing outside a table and talking to each other [end]
# [start] two women are talking to a child by each other wearing a group of teenage [end]
# [start] a person with a hat on and a bent over [end]
# [start] two people walking across a street [end]
# [start] an elderly man brown and white is holding a furry dog on a decorated day [end]
# [start] three children are shown in the stage playing the guitar [end]
# [start] boy laying down to an older white base while jumping off a spring board [end]
# [start] a man trying to walk through a water fountain [end]
# [start] the woman in the black hat is taking a picture of her [end]
# [start] a man is sitting on the floor playing the guitar [end]
# [start] a dog walks in a low tree branch [end]
# [start] a young asian woman is leaping in the air in a jump [end]
# [start] a group of people at a social gathering of people [end]
# [start] four people are using jackhammers by the passersby while standing on the floor [end]
# [start] a man is working on the street using a spatula to be mountain [end]
# [start] a man with a red hat is leaning on a sports equipment [end]
# [start] a young boy in a yellow shirt walks in front of some sort of river and a painting by [end]
# [start] a young child eating a snack and talking out of a rock [end]
# [start] a man and two women dressed in white uniforms walk down the street [end]
# [start] two dogs run through the snow [end]
# [start] a young girl in a green tank top is jumping a horse through a rodeo [end]
# [start] a man in a white shirt is on a lake [end]
# [start] people walking down outside of a lobby [end]
# [start] people are gathering how to make the snack [end]
# [start] several people are swimming in a body of water [end]
# [start] women in bikinis are playing volleyball at the beach [end]
# [start] a man and woman are sitting at a table and is having a conversation with one another man [end]
# [start] a mother and child are shown a picture using play [end]
# [start] a boy is swimming through a body of water with a ball toy in [end]
# [start] four men are standing in front of a yellow car [end]
# [start] a group of men and women who are conversing with their hair on a pole [end]
# [start] a young boy in a field of grass barking [end]
# [start] a little girl is in a superman shirt skates by holding a lamp post [end]
# [start] a dog is jumping up on his head in the air [end]
# [start] a man in a red shirt is standing with a wooden doors [end]
# [start] a man watches as he stands at a bar event [end]
# [start] a band plays in a pool with a snowy day [end]
# [start] two women are conversing in a store [end]
# [start] a woman in a pink sweater is shown with a piece of art wearing a gold and dress shirt [end]
# [start] a child sits on a rock [end]
# [start] a man is sitting on a chair in front of a computer while looking at a handheld electronic device [end]
# [start] a man in a striped shirt is operating a cherry picker [end]
# [start] a man wearing a dark suit is walking along a dirt road with a group of spectators [end]
# [start] a black and white dog is shaking off a spring board [end]
# [start] a band plays music on a stage show [end]
# [start] three people are playing musical instruments and playing the guitar [end]
# [start] a man playing a keyboard wearing a microphone [end]
# [start] a young boy is leaping through the water [end]
# [start] a woman is reading a book the woman sitting at a table with a brick door to drink [end]
# [start] this guys are working on an outdoor platform [end]
# [start] a man is sitting on the beach making a way through a kiss [end]
# [start] a woman wearing a blue sweater makes a funny face [end]
# [start] two men are talking to each other while standing on a bench [end]
# [start] a young man is talking on a cellphone while standing in front of a white male wearing red and yellow [end]
# [start] a tourist cart is taking part of an outback other woman [end]
# [start] a dog in the middle of a ball pit of the nearby [end]
# [start] a band plays music on a cloudy public a crowd [end]
# [start] three dogs are playing around in the snow [end]
# [start] a man and a woman are talking on the phone near a newspaper [end]
# [start] a dog jumps to catch a ball in the air [end]
# [start] an older woman in a red shirt is preparing to serve a meal [end]
# [start] a woman in a suit coat is standing in front of a house [end]
# [start] a woman wearing a woman in a bikini top with her back [end]
# [start] a child is standing next to a guy holding a sword and holding a gun [end]
# [start] a man with curly hair is blowing on his a driving gray gokart [end]
# [start] a man is coming on a rock formations [end]
# [start] a group of people are in a boat in a body of water [end]
# [start] a man in a yellow shirt standing on the sidewalk with a blue laundry room [end]
# [start] a woman in a blue shirt is pointing to a dumpster down with clothes [end]
# [start] a woman wearing a nice dress and a photo shoot [end]
# [start] a person doing a workout on a nail board [end]
# [start] men wearing black uniforms and sitting on a bus [end]
# [start] a mountain biker is shoot out in front of a trash barrel [end]
# [start] a man looks on as he is playing soccer [end]
# [start] a football player wearing a red white and black shirt is getting ready to kick the soccer ball [end]
# [start] two girls are sitting along a street looking at a store [end]
# [start] a man wearing a hairy chest is wearing cement [end]
# [start] this team of boys and wearing red uniforms are walking [end]
# [start] a boy dressed in black and red shirt is jumping off of a ground [end]
# [start] a posing for a picture [end]
# [start] a man wearing a green shirt is kissing while riding a board on the road [end]
# [start] five men are playing a game of tambourine [end]
# [start] three women are sitting on a stool with a and a sit holding a well as one colorful rail [end]
# [start] a man and a girl are playing with some kind of contraption to each other [end]
# [start] a man with glasses playing the instrument in front of a picnic wall [end]
# [start] a dog runs across the water in a grassy area [end]
# [start] a girl with a long pink tutu dances on a mat while a crowd looks at the soccer ball [end]
# [start] two men are trying to get a ball down [end]
# [start] a girl in a red white and blue outfit is kicking a soccer ball in the air [end]
# [start] a man is sitting on his hands [end]
# [start] a brown dog is running across a yard with a stick [end]
# [start] a person rowing a boat in the water [end]
# [start] a man in a white shirt and a man sitting on a sunny day [end]
# [start] a man is giving a presentation while wearing a group of children [end]
# [start] two men are practicing their own a machine talking on a busy outdoor setting [end]
# [start] a man and a boy are playing soccer and the ball with a dog on it [end]
# [start] a male child is holding a balloon with her back on to the guy [end]
# [start] this is a man in a hat and hat who is much tire [end]
# [start] a woman with a black hair putting paint on it [end]
# [start] a young child in a hat is playing in a pile of rubble [end]
# [start] a crowd of people are standing on a street with white umbrellas and a lot of them [end]
# [start] a crowd of people are walking in the park [end]
# [start] a woman with short hair in a blue shirt with glasses and a lip of a group of a heart shaped box [end]
# [start] many children are doing a stunt off a great mess of ice cream [end]
# [start] a cowboy waves a lasso on while on horse [end]
# [start] a bride and groom make their turn in a match [end]
# [start] two construction workers are putting on a green tube [end]
# [start] a man on a train tracks at night [end]
# [start] there are 6 men who are reading sits all the fine print to be a strapped to the side of a st and graffiti mural [end]
# [start] a band plays on the sidewalk [end]
# [start] men dressed in orange robes are shown in some sort of lighting in a newspaper to arrive [end]
# [start] young adults wearing balloon hats are looking at the grass [end]
# [start] the brown dog is running through the water fountain [end]
# [start] a man and woman are crossing a city street [end]
# [start] a man wearing a mustang jacket is getting at the bottom of the gates [end]
# [start] two children wearing yellow and playing in the surf [end]
# [start] there are several people attending to a base while visible [end]
# [start] a woman and a young boy is getting a haircut [end]
# [start] a group of people are standing around on a cement hill with purple steps [end]
# [start] a young girl is swimming in a pool [end]
# [start] boy wearing a blue and yellow shirt smiles as he holds a toy child [end]
# [start] a young girl is standing in water playing pool [end]
# [start] a young girl in a black and yellow chunk of a horn [end]
# [start] four people are using a bicycle in a river [end]
# [start] a brown dog is running through the water [end]
# [start] a dog is running in a field with a ball in its mouth [end]
# [start] a group of people are standing on a stickpole while looking at the same time [end]
# [start] a child in a red top of a container of ice skating and a line [end]
# [start] a news reporter is taking part in being filmed [end]
# [start] a boy smiles as he takes a picture of a large group of children [end]
# [start] two children are sitting at a table on a bar [end]
# [start] a man pulls on a bicycle with a ball in [end]
# [start] an older man is walking with a red and holding a torch [end]
# [start] a young woman is seen from next to a classic rustic looking street [end]
# [start] a young boy is leaping of a chemical a chalkboard [end]
# [start] a young child is about to take a bite of a green ring [end]
# [start] a man on his cellphone is walking in front of a store on a stage [end]
# [start] two artists workers of their faces while the same time [end]
# [start] a woman in a blue shirt is playing an instrument [end]
# [start] this is a busy city scene in the middle of a city intersection [end]
# [start] a man sits down to a hole in a sunny day [end]
# [start] a couple of boys are performing a dance move for their time [end]
# [start] four people are gathering ice skates with trees and the background [end]
# [start] four people are on a bicycle in a park area [end]
# [start] a boy does a trick on his skateboard while playing an outdoor track [end]
# [start] a man at the beach is throwing a water man [end]
# [start] the brown dog is running across the grass [end]
# [start] men dressed in white uniforms are raising their hands [end]
# [start] a woman is throwing a frisbee while holding a dog member jumps a frisbee [end]
# [start] a black dog is chasing a white and is holding a stick in his mouth [end]
# [start] a boat with buildings and them is testing the same time [end]
# [start] a group of hikers are competing in the race [end]
# [start] three people are sitting at a table and making funny faces [end]
# [start] a woman and a woman dressed in the street in white is coming off of her [end]
# [start] a man wearing a white shirt is on the sidewalk near a pile of dirt [end]
# [start] a brown and white dog jumping over a tree branch [end]
# [start] a man in a blue and white shirt is posing with a camera play on a set of while sitting down [end]
# [start] two boys are playing with a game of laser tag [end]
# [start] two men on the roof of a car ride is headed little boy on a small screen [end]
# [start] a boy swings at a pinata [end]
# [start] a man is watching another man play the piano [end]
# [start] a person with a red backpack walking [end]
# [start] a female meditating lays down a pool with a small boat in the beautiful the beautiful of sorts [end]
# [start] a crowd of people are standing on a field with a lot of balloons in the background [end]
# [start] three women with purple hats are walking while a dog and a dog stand by the same time [end]
# [start] a man with a beige suit is walking away from a small businesses on it [end]
# [start] a person with a dark blue shirt and yellow shirt jumps up into the air while holding a conversation [end]
# [start] a man is looking at the bottom of the sidewalk and taking a stroll [end]
# [start] a man wearing a black shirt and tan suit is standing up a white shovel [end]
# [start] a man gives a presentation while talking to the woman [end]
# [start] a child walks in front of a small child [end]
# [start] a young girl does her haircut with a little boy smiles [end]
# [start] a young child dressed in a balloon animal is about to eat an intense [end]
# [start] a closeup of a woman in a white dress with long hair [end]
# [start] a soccer player in a green jersey is walking on the grass [end]
# [start] a girl leading a hurdle as a pole watches [end]
# [start] several children are talking on a cellphone while standing in a dark colored outfit [end]
# [start] military arrest [end]
# [start] a white dog leaps over the water during a short beach [end]
# [start] a man in a gray shirt is getting his picture taken [end]
# [start] a black dog is jumping up in the air while holding a stick [end]
# [start] two black dogs both are coming down the street with greenery [end]
# [start] four people are walking on a bench holding bags of cargo by [end]
# [start] people and shrubs are doing an break from above [end]
# [start] four dogs are playing frisbee in shallow with a bay [end]
# [start] a man in a military uniform is talking on a microphone [end]
# [start] a group of individuals are laid out on a display with children for their partners [end]
# [start] a swimmer doing a dive into a pool [end]
# [start] a woman in a white shirt and pants is lying down in a hole [end]
# [start] a man is talking with his arms near each other [end]
# [start] a girl in a white shirt is playing in a sandpit [end]
# [start] boys and children are shown in a large body of water [end]
# [start] a child in a gray uniform jumps on some old fashion waters [end]
# [start] a boy is doing a stunt on a skateboarding [end]
# [start] a man is holding a large clock device to his side [end]
# [start] a young child sitting at a table eating a meal [end]
# [start] four kids with hands and approach a display in a body of water while they stand in hard hats are in the distance [end]
# [start] a man with safety blondhair is using a leaf blower to do a work site [end]
# [start] many people are spread out of a woman wearing a tank top and a group of other wearing turbans watch [end]
# [start] a dog is jumping up on a dirt with a bus [end]
# [start] a woman and a young man are playing a game of jenga blocks [end]
# [start] four children are sitting on a bench and talking [end]
# [start] a small dog is running among the dogs wearing a number of them [end]
# [start] two men are painting a man in front of a window while the cameraman is outside [end]
# [start] men are watching computer screen in a business [end]
# [start] two women are having a conversation in front of a book [end]
# [start] a blond woman with a guy playing the live performance of the process [end]
# [start] a white and brown dog is running through the grass [end]
# [start] a teenage girl dances a drink with her head while customer at which is giant dish of roses [end]
# [start] two little girls are walking in the air in a game of skiers [end]
# [start] a bride talking to each other on her cellphone while holding a colorful canister sitting up an umbrella [end]
# [start] a woman wearing a pink outfit is walking along side a road with a metal rail [end]
# [start] two women have a conversation with a tennis racket down the court [end]
# [start] four women wearing black and different colored clothes [end]
# [start] an elderly woman uses scissors to enjoy a grand piano [end]
# [start] girls dressed in black are playing volleyball [end]
# [start] a man with glasses and a little girl wearing a bathing suit bottom on a snowy day [end]
# [start] three children wearing white and blue tops with shorts are in the air by the word bamboo [end]
# [start] a woman prepares a game of rubber out of a hole [end]
# [start] a person is carrying many cartons of toe [end]
# [start] a child in a blue and yellow shirt with a light colored jacket [end]
# [start] boy stands behind plant using a rest on a cement structure [end]
# [start] this child is in a classroom setting up the floor all the same time with a one another [end]
# [start] a man is doing a cannon ball [end]
# [start] children are watching the window of a shelter made of sliding [end]
# [start] a man in black and white shirt with sunglasses and a hat on grass [end]
# [start] a woman and two children wearing a red bikini walk across a water [end]
# [start] two men are walking down a street in a city [end]
# [start] a man does a bike trick on a park [end]
# [start] a man wearing a snow mask is matching brightlycolored shirt waves [end]
# [start] a woman in a yellow shirt and glasses is walking on a sidewalk with a yellow is walkway [end]
# [start] two women looking out into the front of a small display [end]
# [start] two large dogs are playing in a yard [end]
# [start] people are gathered around with some sort of chairs [end]
# [start] a group of people are gathered for a meal [end]
# [start] a woman in a black shirt appears to be looking over a newspaper [end]
# [start] a military man and woman sits among piles of fallen poles [end]
# [start] a man and woman are together on a street [end]
# [start] two dogs are playing around in the grass [end]
# [start] a small dog leaps down the street [end]
# [start] a man wearing a black shirt is playing a saxophone and trumpet player [end]
# [start] boy and a man dressed in red and a pants are holding a soda [end]
# [start] a girl in a white shirt and black pants is practicing her [end]
# [start] two men standing in a street with a graffiti covered corner [end]
# [start] boy in shorts and tshirt kicking up a snowy hillside and his mouth [end]
# [start] a college student is to make sits to make a shot with the goalie in the water from his the sidelines [end]
# [start] two men dressed up with their heads facing away from a says wooden states behind its door to the camera [end]
# [start] a dog is running through the snow covered in snow [end]
# [start] a group of people are standing together on a swing at a grand canyon [end]
# [start] a large brown and white dog is sitting on a road that is running through the water [end]
# [start] two teenage boys are performing in an outdoor swing that is a game of onlookers [end]
# [start] a mother and son are jumping through a sand dune [end]
# [start] a man in a black shirt stares at the other women across the counter in a street [end]
# [start] a woman wearing a white robe is playing a black [end]
# [start] a snowboarder is leaping in the air while wearing a red white breath [end]
# [start] several people are standing around in a room [end]
# [start] a man in a hat and a shirt talking to a woman who is wearing the same time out of which says stick [end]
# [start] a man is skiing down a metal structure against a brick building [end]
# [start] a woman in a white shirt and black pants is smiling at the pile of people that are about to pull her cry [end]
# [start] an elderly man is holding a guitar player in a sports outfit [end]
# [start] two men dressed in red shirts are doing some sort of pool [end]
# [start] a young child is jumping up on a motorcycle with a soccer [end]
# [start] a child wearing a cap and green coat is sitting in the air wearing a balloon [end]
# [start] a child sitting on a bench with a few statue [end]
# [start] two men are wearing hats and talking in the rain gear [end]
# [start] two boys are smiling for the camera while wearing stilts [end]
# [start] a woman wearing black and white dress is laying down with a number one large number taken [end]
# [start] two men dressed in clown makeup are all [end]
# [start] a woman with a chinese woman is handing out to some sort of contraption [end]
# [start] a bike rider is in the air while riding his bike [end]
# [start] a young man in a green shirt is reading the newspaper [end]
# [start] a man in a green jacket is smiling [end]
# [start] a man climbs up a rock wall with a protective move on [end]
# [start] a young man is crossing the street using a bicycle to do something [end]
# [start] two brown dogs are playing in a yard [end]
# [start] a person wearing a red coat is walking in front of a building [end]
# [start] a woman who is wearing a white are practicing on a gravel road [end]
# [start] two boys in a water bottle are jumping over a court [end]
# [start] a man with glasses is standing at a microphone looking at a computer screen [end]
# [start] a child in a green shirt is holding a basket on her cellphone [end]
# [start] a man with a tattoo on his arm trying to make a bite [end]
# [start] a group of people are performing a play music while standing in front of a crowd [end]
# [start] a group of men are gathered together in a group of men [end]
# [start] a man is pulling on a cart of sheep [end]
# [start] three large dogs are playing around in the air [end]
# [start] a man is flying through the air in the air [end]
# [start] a group of individuals are sitting at a carnival scene [end]
# [start] a race car is parked on a porch in a paved area [end]
# [start] a group of young people are sitting on playing musical instruments [end]
# [start] a group of adults are sitting around a white pot [end]
# [start] a woman in a green shirt is reading with her camera [end]
# [start] young people participating in a game [end]
# [start] orange and white uniforms and picture are on a sports field [end]
# [start] a woman and two boys looking at a dinner [end]
# [start] a group of people are seen in a dance in a group of store [end]
# [start] two women are standing in the grass trying to get a biker who is a snowcovered area [end]
# [start] people are gathered outside an open field one group of them wearing [end]
# [start] a young skier gets air as he prepares to take a bite [end]
# [start] two young girls are wearing a red white costume with a shaved onto a child [end]
# [start] a woman and a man wearing a seat of a car and a woman are bent over [end]
# [start] a man is smiling in a large body of water with a camera [end]
# [start] the street with many people are coming down from behind [end]
# [start] two men in a country laying and the other on a porch looking on [end]
# [start] a small dog runs across the grass [end]
# [start] a restaurant is taking a meal together on the street [end]
# [start] a snowboarder takes a turn [end]
# [start] an asian woman in a construction outfit is pushing a tent decorated with workers [end]
# [start] a woman in a blue shirt is riding a bike [end]
# [start] a woman wearing a white suit is getting ready to hit the ball [end]
# [start] a young woman is playing with an instrument at a social gathering [end]
# [start] a bride and groom are getting their picture taken from each other on a cloudy day [end]
# [start] a woman holding a black and white dog [end]
# [start] boy in red shirt trying to play guitar [end]
# [start] a young boy clings to the stem of a baseball game [end]
# [start] three women are at a diner overlooking the booths located on the sink [end]
# [start] a white and brown dog is jumping with a leaf blower [end]
# [start] a string quartet of a man in a field [end]
# [start] children are coming up water from inside a large canyon [end]
# [start] a white and brown dog jumping with a blue ball in its mouth [end]
# [start] a group of people in blue shirts taking a variety of work [end]
# [start] a baseball player in a green and white shirt is balancing a class [end]
# [start] two little girls in blue shirts smiling [end]
# [start] a young girl in a pink outfit is in a gym with clown makeup applied [end]
# [start] two people are jumping over a rocky mound [end]
# [start] a group of women are dressed up and wearing black attire and they are practicing for a cause [end]
# [start] a cyclist is performing a jump over a snowy mountain [end]
# [start] several people walk by a mural on a tank top of an outdoor area [end]
# [start] a woman stands on a wall of a projected painting of a mural [end]
# [start] a woman in a white shirt and yellow shorts holding a pair of goggles while she is starring [end]
# [start] a person riding a motorcycle [end]
# [start] a young girl with a black and yellow balloon is smiling at the other red tank top of some sort of himself and a small screen [end]
# [start] two dogs one has a back to each other in a jump [end]
# [start] a young boy wearing a red and blue shirt is holding a breath fountain [end]
# [start] a boy performs a bike trick on a dirt hill [end]
# [start] an elderly man wearing a black coat is looking at a table [end]
# [start] a man in a blue shirt walking a sidewalk [end]
# [start] a woman is putting up a ball in a necklace at the bottom of the water [end]
# [start] a young girl wearing a tank top hat is walking on a gravel square paneled [end]
# [start] a black dog leaps over a hurdle [end]
# [start] boy in blue and yellow a red ball in the surf [end]
# [start] a group of people go in a race [end]
# [start] a man is walking a bull by a man [end]
# [start] boy in red and yellow hat is getting married in a park [end]
# [start] a small white and brown dog is walking on a sidewalk [end]
# [start] two children are using spray paint while walking on a wall [end]
# [start] two men dressed in white shirts are married [end]
# [start] a male drummer meet with another one waist on a field [end]
# [start] several people are walking along a scenic view on a sunny day [end]
# [start] a white dog with brown spots is looking through the water [end]
# [start] a photographer is photographer make a disc with an open to takes a picture that is on top of a large sky [end]
# [start] a young girl in a black and white dress shirt is reading a conversation on a grand dealer [end]
# [start] a man wearing safety gloves [end]
# [start] a group of young adults rest on a beach [end]
# [start] a woman is holding a violin player in a [end]
# [start] military personnel with brass their ear at salon [end]
# [start] a man wearing a gray shirt is doing a wheelie on the rock [end]
# [start] three men are walking along a side of a small child with a striped back [end]
# [start] a young girl stands on a lawn [end]
# [start] boy in a green shirt getting his arm around a league [end]
# [start] a man and a woman are playing with a black and a woman outside [end]
# [start] a young girl in a flower print shirt and white shorts [end]
# [start] a woman with purple hair and a man dressed in a work site [end]
# [start] people dancing and and cheering [end]
# [start] a man is looking at a cellphone while walking down the street where there are walking [end]
# [start] a man in a white shirt and jeans plays the instrument as he looks on [end]
# [start] a large group of people are watching a performance [end]
# [start] a car is sniffing a trail while the top of chasing after the surf [end]
# [start] a group of people are listening to a man talk [end]
# [start] a man wearing a white shirt is stomped by a man wearing a brown shirt [end]
# [start] a boy is getting ready to cut into a hoop [end]
# [start] a bike rider is riding his bike along a dirt hill with a snow covered up [end]
# [start] a man with long hair is trying to get in the air on the street [end]
# [start] boy and man dressed in black clothing is jumping as he looks at laundry full of the same in a large sky [end]
# [start] a young girl is throwing a split position on her knees with one finger walks away [end]
# [start] a man in a blue helmet is riding a bike on a trail [end]
# [start] a person is doing a split position in front of a rock wall [end]
# [start] a woman standing at a carnival is being interviewed by the press [end]
# [start] two bicyclists ride along a road using spray from a wall [end]
# [start] a group of people are performing a dance [end]
# [start] two people are playing in a game of soccer [end]
# [start] a man is setting up a set of next to an orange wall with a brightly colored sign [end]
# [start] boy grabbing another boy while throwing the ball [end]
# [start] a woman is using a camera large snake by the side [end]
# [start] a girl wearing a red hat and blue outfit is a large balloon [end]
# [start] a woman is applying black face to a child with a flowered dress and a walking to a man [end]
# [start] a group of adults ride around a piece of gym as they act out and black pants is being interviewed by the aid of him [end]
# [start] a man in a blue shirt and white rollerskating as he holds a bunch of grass [end]
# [start] a young child plays tugofwar with a bubble [end]
# [start] four children are playing and looking at toys in a jump [end]
# [start] a man is holding a piece of iron a chair while sitting in front of her [end]
# [start] a woman with purple balloons tied to her back a few news [end]
# [start] the men are wrestling [end]
# [start] two girls of them are talking to each other one is using her in a red and blue ball [end]
# [start] a woman is putting a star on top of a small girl [end]
# [start] a crowd is outside of people looking at lingerie in [end]
# [start] boy in blue and black a boat with colorful clothing [end]
# [start] a young girl in a flower print shirt sits on a field with her eyes [end]
# [start] a man is singing into a microphone while holding a sandwich [end]
# [start] a man with a hairy chest is wearing a typical man walking by a group of them [end]
# [start] a man wearing a green and black dress are talking to each other [end]
# [start] a man is doing a kick trick with two other sparring on his picture while on his hand [end]
# [start] a man is performing some kind of contraption in a red shirt [end]
# [start] a large brown dog is running through the grass [end]
# [start] a tractor with a shovel arm in front of a attempting to jump in a competition [end]
# [start] there are many people walking down the street and going to a bike [end]
# [start] the black dog is leaping to the water in the air in the front of a body of water while wrapped in mower [end]
# [start] a man in a black and white hat playing a game of lacrosse [end]
# [start] a man wearing a green vest is on a bicycle bench [end]
# [start] a man is sitting at a table set up in front of a classroom [end]
# [start] three men in white uniforms are having a conversation [end]
# [start] a small dog is playing in a yard and he is about to catch some sort of lens [end]
# [start] a man is walking down a hill [end]
# [start] a man in a bucket with his arm and a woman sitting under a [end]
# [start] people walk down a busy city street with a meal is serving them [end]
# [start] a large brown and white dog leaps through a field of them wearing a plastic jacket [end]
# [start] a man on a motorcycle is wearing a white shirt and yellow pants [end]
# [start] two men are outside of a beautiful day to are shoveling water while in a lake [end]
# [start] a man is standing on a scaffold with one of the electric instruments [end]
# [start] a man standing on a pile of rubble from a reads a book [end]
# [start] two people wearing white shirts walking on a sidewalk on cellphones [end]
# [start] the little girl in the green is attempting to run a ball [end]
# [start] a artist is painting a scene outside [end]
# [start] two asian children and a girl are standing on the floor and there is a smiling [end]
# [start] people are in line about to get into a distance [end]
# [start] two teams of guys one is wearing black uniforms and one boy are playing baseball in the field [end]
# [start] a woman wearing a yellow hat is getting a picture taken from a container [end]
# [start] a black dog is splashing in the water with a ball [end]
# [start] three men dressed in a blue and white uniforms are [end]
# [start] a woman who is wearing a matching mask while holding a teddy bear in a snack [end]
# [start] a man in a blue shirt is playing a model dressed in a blue field [end]
# [start] a man doing some sort of suit with his hands a in the air force show on the shape of newspapers to the newspapers is almost trip [end]
# [start] many people are standing together under a umbrella wearing a snowy day [end]
# [start] a woman is applying mascara to her left eye [end]
# [start] a sports player is walking down selling goods [end]
# [start] three men are standing around a bike with their motorcycle drawn [end]
# [start] a news man stands at a line of a grocery store [end]
# [start] a man in a red longsleeve shirt and wearing black pants is standing with a striped shirt [end]
# [start] a man is watching a portrait of a man [end]
# [start] two people are riding bikes along a dirt path [end]
# [start] a young girl in a green tank top with a star on top of children [end]
# [start] a child is inside a green shirt and is near a body of water [end]
# [start] a teenage boy plays the guitar [end]
# [start] a man wearing a white shirt and khakis is on a cement truck [end]
# [start] two boys are making a funny face while standing toward the camera while holding the soccer ball [end]
# [start] an older man wearing a hijab holds a sled over a hill [end]
# [start] three people are on the beach on the water looking out at the same time [end]
# [start] a man with a yellow shirt is standing up in front of a small child who is on a lively smiling [end]
# [start] a child is hiding behind a cardboard container of food [end]
# [start] two women wearing white tops and shorts are standing at a diner [end]
# [start] a police officer is putting on a horse with a rodeo on it [end]
# [start] a large brown and white dog is digging for a stick [end]
# [start] a man takes a nap on the top of a large rock formation in the background [end]
# [start] a woman in a gray dress shirt is putting out a wooden [end]
# [start] people are completing some type of activity are in the east asian country [end]
# [start] two young boys are playing basketball in a game while the other team member of the opposing team [end]
# [start] a woman in a bikini top is using a small child [end]
# [start] a man with a brown hair wearing a shirt and hat is playing a saxophone [end]
# [start] a blond woman is putting a drink [end]
# [start] a young boy is lying down with his leg held by his camera [end]
# [start] two men in an outdoor venue talking to the grass [end]
# [start] a dog runs over the top of a stick with his mouth [end]
# [start] an indian man is bathing a bath in a tent [end]
# [start] a man wearing a red hat is resting on a wooden post [end]
# [start] a young girl is getting her back for a photo shoot [end]
# [start] a woman with black hair and wearing a red shirt and knee is holding a music player looking at a show [end]
# [start] a man in a wearing a kimono is working with a piece of water [end]
# [start] two dogs chase and facing each other with held up in the air [end]
# [start] a woman in a blue shirt is being interviewed by the flower screen [end]
# [start] two hockey players competing for the ball to be in a field with no nets [end]
# [start] runners compete on a snowy day [end]
# [start] a group of people in costumes making a halloween costume at a meal at a party [end]
# [start] two children are getting ready to fight over a firetruck [end]
# [start] young adult wears a white shirt and blue jeans and a play with a guitar [end]
# [start] a person dressed in a yellow suit at a crowded public place [end]
# [start] swimmers stroke diving dive over a walk against a sleeping match [end]
# [start] a group of people at a group of a public place that are wearing an asian party [end]
# [start] a dog is jumping up in the air with a tree branch [end]
# [start] a group of people are in a desert game [end]
# [start] an action shot of a man in a black and white collides [end]
# [start] boy has bent over on something over another little boy [end]
# [start] here is a picture of a young boy with long hair trying to make a call in a truck [end]
# [start] tourists taking a picture in front of a building [end]
# [start] a group of people with their heads down a street with a few people walking down shielding their hands from the background [end]
# [start] two men in a bar drinking around a large mess of him [end]
# [start] men and women waiting in front of a dinner [end]
# [start] children are having fun while enjoying themselves by a concert [end]
# [start] a man is singing into a microphone as a crowd watches [end]
# [start] a singer sings while the man watches [end]
# [start] an elderly woman wearing a blue hat sits on a sidewalk waiting for them [end]
# [start] a construction worker in a hat and jeans is putting up a vegetable that she is an similar to his next to the wares [end]
# [start] a person in a white shirt is pouring a clay beautiful table [end]
# [start] a man wearing a yellow hat is serving a crowded market [end]
# [start] a gymnast is making a clay pot on a spinning wheel [end]
# [start] an artist is working on a craft pot [end]
# [start] a man in a blue shirt is being interviewed by a flower [end]
# [start] this is a good time lapse photography display box [end]
# [start] two people playing a game and a woman [end]
# [start] several girls are playing and wearing matching mask [end]
# [start] a young girl plays an instrument while singing [end]
# [start] a man is playing a live with the drums while piece of paper [end]
# [start] a man is shown in the process of having himself from top [end]
# [start] a photographer walks with a lot of balloons in the distance on a cloudy day [end]
# [start] a group of people wearing black shirts wearing bright colored shorts and one another is playing the french [end]
# [start] a woman wearing a red outfit is hitting a hockey ball [end]
# [start] a group of people are walking in a mostly black event [end]
# [start] a woman and a boy wearing a bathing suit are smiling at the large group of people in the background [end]
# [start] a man wearing a black jacket and a shirt jumps around his man wearing black funny face [end]
# [start] a young girl is walking in a small blue and white dress [end]
# [start] a man in a brown suit jacket is walking by an event with a red guitar [end]
# [start] two children in a gym are dancing [end]
# [start] here is a picture of a woman and a child who is on a sunny day [end]
# [start] a horse race is performing a dance at a gym [end]
# [start] a man and woman are sitting on a bench looking at a window [end]
# [start] a city street has multiple shades drawn during a dark [end]
# [start] several people are walking and talking to each other in a group [end]
# [start] a group of men play music in a group of together [end]
# [start] this is a man who is bent over working on a snowy mountainous area [end]
# [start] two children play with long hair and standing [end]
# [start] a man is sitting on the steps of a house [end]
# [start] a man in a dark suit jacket is walking along a street in a cold setting [end]
# [start] a man in a black hat and tan shirt is leaning against a street [end]
# [start] a woman is standing in a building with a white scarf [end]
# [start] an elderly woman wearing a hat and blue jeans skirts a light with a light blue scarf behind her [end]
# [start] people are walking by some sort of people while a little girl is in front of him [end]
# [start] a man and a woman are dressed up working by a great satchel [end]
# [start] two people look into a speaker dressed in a store [end]
# [start] a man with a backpack sitting down while standing on the side of a road that are making a photograph [end]
# [start] two men are sitting down with a rail [end]
# [start] a woman in a yellow jacket is seen from the other man [end]
# [start] a man in a suit is talking on the phone while sitting in a street [end]
# [start] boy in a green shirt with a red and white shirt is located on a nets [end]
# [start] a little girl is going across a wall [end]
# [start] a young man is buying a marketplace with a beautiful sunny day [end]
# [start] an older man is sitting on a floor with a guitar handles [end]
# [start] a man with a hat and a wearing a hat is standing at a painting of a woman [end]
# [start] three men are talking on a street in front of a store [end]
# [start] people watching black city workers at a food establishment [end]
# [start] a man and a woman are walking along a road [end]
# [start] a man in a suit is eating a newspaper while walking down a street [end]
# [start] a group of people playing music in a band [end]
# [start] a dog leaps through the air after taking a bite of a green patch of green [end]
# [start] several people are standing on a platform underground [end]
# [start] three children are shown in a house [end]
# [start] two people stand outside a building [end]
# [start] an elderly woman stands under a group of a speaker [end]
# [start] a baseball player is sliding into the ocean off a diving board [end]
# ...
# [start] an older man dressed in a blue and white male sitting on a street corner while walking down [end]
# [start] a woman is taking a picture with her camera [end]
# [start] an older man wearing a white jacket while sitting in a white shirt is suspended [end]
# [start] a man is holding a partially of a trash bull person who is yawning [end]
# [start] two women sitting on a street inside a store [end]
# [start] a man in a white shirt sitting on a rectangular escalator [end]
# [start] an old man wearing a sombrero and khakis sitting on an outdoor area [end]
# [start] a man is sitting on a rock climbing [end]
# [start] an older man is sitting on a bench in a mobile a newspaper outside displaying his desert [end]
# [start] a man wearing a gray shirt jumps a small wagon [end]
# [start] boy wearing a red shirt wearing a yellow shirt is standing on a grass [end]
# [start] two men are walking on a dirt road [end]
# [start] a woman wearing a beret and black hats put out her notebook [end]
# [start] two dogs are playing with a ball but blue in [end]
# [start] a man wearing a helmet rides a toy bike [end]
# [start] a man is standing on a bench in front of a white billboard [end]
# [start] firemen are getting their purchase out of the firetruck with they are not have their way to take a bite [end]
# [start] a young boy in a blue shirt with a woman who is wearing sunglasses [end]
# [start] a man with a white shirt is looking at a brochure on young child wearing black and sitting [end]
# [start] people are playing tennis in a yard [end]
# [start] four boys are playing and one has paper [end]
# [start] a man walking down a street with a group of people in front of his on it [end]
# [start] a male performer in a orange safety vest and a motorcycle are looking at a piece of paper plate [end]
# [start] a person is sitting on a stool in front of a crowd [end]
# [start] a man is waiting for a train to be sold [end]
# [start] three white males wearing straw hats are jumping [end]
# [start] a singer sings at the man during a performance [end]
# [start] a restaurant getting ready to take a picture of a large balloon [end]
# [start] a woman in a black and yellow shirt holds a pair of goggles on the frame [end]
# [start] a rally car taking pictures with his right [end]
# [start] several people are waiting for a subway shop near an outdoor platform [end]
# [start] two girls are playing volleyball and one ball [end]
# [start] an older man is holding a pair of his in the water looking at a beer [end]
# [start] six people are in a gymnasium working on fire [end]
# [start] two young boys are competing by one another playing [end]
# [start] a woman is preparing a meal to put a glass case [end]
# [start] two men wearing shorts are biking through a blue boat [end]
# [start] a man and woman are doing a cannon ball in a patch of nongrassy tile [end]
# [start] a man wearing a field of pumpkins with some kind of contraption that is about to hit [end]
# [start] a man and woman enjoy a drink while onlookers watch [end]
# [start] a military man stands at a military flight attendant is serving the doors at a conference [end]
# [start] two young men are walking down a street chasing a ball [end]
# [start] a woman in a restaurant setting up a string band consisting of a guitar player painted with paving stones [end]
# [start] a woman in a blue shirt is looking up at a mess on it and the side [end]
# [start] a man in shorts is talking to a woman in a microphone [end]
# [start] a man is putting up a baby in a highchair [end]
# [start] a young boy wearing a blue and yellow helmet runs in a pool with their respective [end]
# [start] a small baby boy in a stroller with a hat [end]
# [start] two children are laying in the water on a cold winter time [end]
# [start] two people are at a pile of seaweed one behind it by it on it [end]
# [start] woman cleans out with large needles on a snack [end]
# [start] children run in a ball away in a game [end]
# [start] two children are jumping over a model airplane are in the grass and the trees [end]
# [start] two dogs run around in a grassy field [end]
# [start] a man and a chef in public square [end]
# [start] three people are walking on a dirt road [end]
# [start] a group of people are standing outside near a river [end]
# [start] a woman looking at a window display of a horse through a ring [end]
# [start] a little girl with a stuffed animal is teenage boy who is being lifted by an adult [end]
# [start] a young man wearing a beret and testing a variety of some sort of foods [end]
# [start] a skier gets air as they go by a pitcher watches [end]
# [start] three girls are having a good time while jumping with one another [end]
# [start] a woman carrying a nice day up to take a photo of a sports bar [end]
# [start] a man is working with a rubber bin [end]
# [start] a man is receiving a younger man as he looks at the same time with the man [end]
# [start] a woman sings at a park while a man plays guitar player [end]
# [start] a man wearing a hat is loading a portrait of his woman [end]
# [start] a worker is leaning on a tree [end]
# [start] several people are standing around a piece of metal in a wooded area [end]
# [start] a student is shown with craft supplies to take to take off of a bite [end]
# [start] a woman with sunglasses and a blue bikini top is being interviewed a candle lit on a dining room with a dining room [end]
# [start] an old man is sweeping the floor while a child looks down [end]
# [start] a man in midswing playing green playing atop with a violin is sitting along a road [end]
# [start] a man is working on a construction site [end]
# [start] a man is walking a ball while a girl is playing basketball [end]
# [start] a man stands at the back of a sip of his hands [end]
# [start] a baseball player wearing a red and white uniform is hitting a hit a softball as she walks with a second van that looks on [end]
# [start] a man dressed in an orange suit is inspecting an animal [end]
# [start] a man in a purple shirt is working on a tiled restaurant [end]
# [start] a man is walking through a field with a green tent [end]
# [start] two girls on a porch ball horses in a tournament that are [end]
# [start] a man and woman are standing on a bench [end]
# [start] a man and woman are sitting on the floor next to a store window [end]
# [start] a mustachioed man plays the out of a piece of mural [end]
# [start] two girls are sitting on a bench looking for sale [end]
# [start] a man is running through the sand with a few people [end]
# [start] a female dancer in a red uniform jumps in the air [end]
# [start] a man is lying down with a light shining in a sports car [end]
# [start] a man with a beard in a jacket sits down with a spatula and reads to lift [end]
# [start] a man is using a leaf blower to clean the water at a skate park [end]
# [start] a man with a beard and wearing a hat is posed in a big city [end]
# [start] a closeup of a white and woman swimming is drinking a soda cup [end]
# [start] a man and woman are at a fair in a boxing match [end]
# [start] a young boy wearing a brown costume and white wings is sitting [end]
# [start] a man wearing a gray shirt is getting ready to cut out of a country area with a female [end]
# [start] a woman stands in front of a group of people smiling [end]
# [start] someone dressed in a cook is with has a drink [end]
# [start] a young football player is sniffing a football player [end]
# [start] a man wearing a gray shirt is crossing a green st car left on a truck [end]
# [start] a young man is getting ready to throw a ball in a jump [end]
# [start] a soccer player jumping a ball past during a girls volleyball game [end]
# [start] two men are dressed in blue and white uniforms with a sports coat are competing in a latin american attire [end]
# [start] a group of friends in a fun back of a small chef are well [end]
# [start] a man is standing girl is holding up in front of a microphone while holding a cameraman [end]
# [start] a girl is performing gymnastics with her horse [end]
# [start] a woman is blowing a bubble with her after he [end]
# [start] two motorcyclists are watching through a street tennis players [end]
# [start] a man on a sidewalk with his hat on his head [end]
# [start] an indian man is praying by a mans abs [end]
# [start] several men are riding longboards through a mud [end]
# [start] two people in costume with a black and yellow plastic bag in a sparse line up line in a city [end]
# [start] three firefighters are having a conversation [end]
# [start] a man wearing a white shirt and blue jeans is being lifted by a top of male high jump while jumping in the air by a snow covered with a partlycloudy sky [end]
# [start] a man in a sweater with a shirt is sitting down on a street corner looking at the camera [end]
# [start] swimmers gather at a starting line to run a beginning of water which is a drink from the animal as he walks [end]
# [start] a young boy is enjoying some kind of gardening tools [end]
# [start] boy in blue and white shirt getting air is getting his picture taken from a drainage [end]
# [start] men dressed in costumes getting married [end]
# [start] two teams are playing at a horse while all into him watch [end]
# [start] kids are playing on a playground [end]
# [start] an accordion plays the guitar in front of a group of the men and tie [end]
# [start] boys swimming in a native american outfit men [end]
# [start] a group of people in black clothing stop in a city scene [end]
# [start] people dressed in costumes making a play on a piece of gym as they are in a crowd area [end]
# [start] a man is putting together a computer screen with a brush [end]
# [start] the boy does a kick trick while trying to make a header [end]
# [start] a baby boy in a toy room with a blanket [end]
# [start] this is a small people walking at an outdoor carnival [end]
# [start] i am looking very older man is held by a food bag [end]
# [start] a young man skateboarding on a bench [end]
# [start] people going to a boat on a sunny day in the middle of the road [end]
# [start] two men wearing reflective gear fight over a toy [end]
# [start] a white and blue cheerleading outfit rides headlong flexing for the camera [end]
# [start] a group of competing cyclists are riding in a track with all over the cyclone [end]
# [start] a person dressed in winter clothes is posing with a wooden stake on top of a tree [end]
# [start] a man is working on the street in front of a toll building [end]
# [start] a man is being walked along a bull to older boy who is sitting in the evening with a another man [end]
# [start] a man in a superman shirt reads a camera at a piece of paper [end]
# [start] a young girl wearing a red white and blue outfit is arguing with a great satchel while closing written on [end]
# [start] a man wearing a bicycle helmet rides his bikes [end]
# [start] a group of adults come across a while outdoors sitting in conversation with one group of other riders [end]
# [start] a young boy in a green tank top is jumping through the air on a sunny day [end]
# [start] a young girl in a running suit looks at a game of coke [end]
# [start] a man is lifting a large group of the water in front of a tent [end]
# [start] a band is playing on a bright colored balloon with odd goods [end]
# [start] a child is jumping with his head in the air time [end]
# [start] a soccer game is played and guarding the soccer ball [end]
# [start] young women and children having a conversation in a martial arts match [end]
# [start] a young child wearing a red white and blue outfit is playing with her tongue out [end]
# [start] a man wearing a suit hat wearing a red superman plaid shirt is putting on a [end]
# [start] a son and having a good time as they get for a crowd [end]
# [start] three men are participating in a race [end]
# [start] two men are looking out at the same time while grabbing for each other [end]
# [start] a soldier is looking at the scenery through the scenery [end]
# [start] a group of young boys in a race is walking across the goal [end]
# [start] a man jumping over man in the air as he looks at him [end]
# [start] a young boy and girl smiling as she laughs in his hand [end]
# [start] two men are fighting over some rates of the ball [end]
# [start] a bike rider is going down a jump as he climbs in a field [end]
# [start] two women wearing fancy dresses and playing in a social gathering [end]
# [start] two men riding bicycles down a sunny day [end]
# [start] two men are engaged in a rock climbing during a jump [end]
# [start] a man is being walked down the set of the electric hill as he is on a brown and white top of his black road by [end]
# [start] a group of men dressed in are playing music [end]
# [start] a man and woman looking at some sort of tabletop objects as talk to each other [end]
# [start] a team of teenage boy sliding into an outdoor slide [end]
# [start] a group of people walking down a street with flags and numbers in the same time [end]
# [start] a man holds a rope device to take a bite [end]
# [start] a man on stage playing a concert with trees in the background [end]
# [start] four young kids playing and sitting on a toy railroad [end]
# [start] a group of people at a work site to clean up [end]
# [start] a restaurant clerk is eating a messy unusual team is in the background [end]
# [start] three dogs are playing in the water [end]
# [start] a man playing a set of drums while riding a small child does the big outside [end]
# [start] a group of young girls play a horse [end]
# [start] a man looking at a craft of it looks on as a child in it [end]
# [start] a muzzled rider suspended by the has his side of a steel beam including starfish [end]
# [start] a team of soccer players the field all dressed up and one another is about to go by [end]
# [start] a group of people dressed in black and white pants are running in a field [end]
# [start] a man in a blue and yellow shirt plays the trumpet [end]
# [start] this is a guy wearing shorts gear and a number on the motorcycle is flipping off [end]
# [start] a young girl dressed in a hat is taking care for the picture is outside [end]
# [start] a young boy using a drill doing some type of gardening work [end]
# [start] two bicyclists racing along a road [end]
# [start] an animal is being pulled by horses while one girl watches [end]
# [start] a mountain lion spray are held off by a building [end]
# [start] two people are playing on a carpeted floor all dressed up with one of those in their luggage carts [end]
# [start] two bicyclists ride along a road carrying many individuals [end]
# [start] a baseball player a grass field is wearing a baseball uniform and sliding to a base while on the side of the sidelines [end]
# [start] two men dressed in black and white uniforms with lights going off the back of them [end]
# [start] two men and black pants are playing with bicycles while on fire hydrant [end]
# [start] an upset man who is posed with the on a baseball mitt [end]
# [start] three people are running in a race through the course [end]
# [start] the football players from the field meet [end]
# [start] several men are praying that he is sitting down on top of a grill [end]
# [start] two indian men are practicing formal event putting together [end]
# [start] three children stand by a large handbags stand in the side of a large group [end]
# [start] a group of people are running a field of grass [end]
# [start] two women are walking along the beach with garbage bags [end]
# [start] boy sitting on the playground looking at the button up is looking at the lens [end]
# [start] a woman standing on a piece of water looking over a fountain [end]
# [start] a woman with long hair is looking at the sidewalk [end]
# [start] a group of people at a fun swimming pool [end]
# [start] two women dressed up with their hand cans [end]
# [start] a person wearing a bicycle hat and a blue bike is walking on a trail [end]
# [start] a college football player is serving up during a day [end]
# [start] there are two men practicing as he fight on a tiled floor [end]
# [start] a group of people stand in front of a bright colored group [end]
# [start] an elderly woman with her hair is looking for a family of coke [end]
# [start] two men are working on a rainy street [end]
# [start] two women one in a red shirt are doing work [end]

# %% [markdown]
# Generate results of translation model of Czech to English.

# %%
en_vocab = en_vectorization.get_vocabulary()
en_index_lookup = dict(zip(range(len(en_vocab)), en_vocab))
max_decoded_sentence_length = sequence_length


decoder_outputs = en_decoder([en_decoder_inputs, encoder_outputs])
transformer = keras.Model(
    [encoder_inputs, en_decoder_inputs], [decoder_outputs], name="transformer"
)

def decode_sequence(input_sentence):
    tokenized_input_sentence = cs_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = en_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = en_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence

alltext = []
for i in range(len(val_cs)):
    translated = decode_sequence(val_cs[i])
    alltext.append(translated)
    print(str(i)+translated)
# Out:
# 0[start] a group of men are loading on a truck [end]
# 1[start] a man asleep on a couch in a green room [end]
# 2[start] a boy wearing a headset is sitting a woman on his shoulders [end]
# 3[start] two men are using a blue fishing net on a shore of an ocean [end]
# 4[start] a balding man is wearing a red life vest and sitting on a small rowboat [end]
# 5[start] a lady in a red coat holds a pair of a bag as they swing day traveling along a city lane on a diner [end]
# 6[start] a brown dog runs behind a black dog [end]
# 7[start] a young boy wearing a bandanna swings a baseball bat at a baseball [end]
# 8[start] a man in a crowded office is talking on a cellphone [end]
# 9[start] a smiling woman in a walkway of by a mountain bike [end]
# 10[start] a young child stands alone on to a hot rock [end]
# 11[start] a person on a ski slope in the middle of snowboarding [end]
# 12[start] three young children are standing around a metal barrel [end]
# 13[start] a woman sitting at a wedding flower market in a outdoor market [end]
# 14[start] a woman is playing a song on a blanket [end]
# 15[start] three people are riding bikes on two dirty and one wears a grassy field [end]
# 16[start] a shirtless man sleeps outside in a chair [end]
# 17[start] a group of people in a parking lot standing in front of a tripod [end]
# 18[start] a young woman is getting bathed in a train [end]
# 19[start] three girls with hair and one is making a funny face the street while standing on a busy street [end]
# 20[start] a man in a black shirt standing over a crowd of people [end]
# 21[start] a woman and man hiking across a wooden bridge wearing a lens green sign [end]
# 22[start] a man wearing a skirt jumps up while jumping in a stroller [end]
# 23[start] an asian woman in a green hat and apron is scooping up on a messy mans blood [end]
# 24[start] workers are standing on a lift [end]
# 25[start] two dogs with orange toy in tall grass [end]
# 26[start] a blondhaired baby is laughing at a another kid [end]
# 27[start] three men are walking down a road in the mountains [end]
# 28[start] a person is standing in a large body of water [end]
# 29[start] a construction worker rides dirt structure among the rail of a construction wall [end]
# 30[start] a little girl runs in a park [end]
# 31[start] a person is crossing the road carrying a sack ride [end]
# 32[start] a child plays on a playground hangs off a pole [end]
# 33[start] a person wearing a red tshirt and a pink trick with a long white dog in front of a light blue case [end]
# 34[start] a group of people gather around a man in a suit and small boy [end]
# 35[start] a woman is sitting in a dark bar [end]
# 36[start] people are walking down the sidewalk outside in an outdoor market [end]
# 37[start] a man with a blue backpack is reading a newspaper while waiting for a subway [end]
# 38[start] the large brown dog is sticking out front of the bathroom [end]
# 39[start] a blondhaired boy in a blue shirt smiles as he stands in front of a green store with a green cloth [end]
# 40[start] a small construction worker sweeping steps with a large broom [end]
# 41[start] a person about to throw a green bowling ball down a aisle [end]
# 42[start] a group playing basketball bars having a good time [end]
# 43[start] an elderly man walks with a dog on a red leash [end]
# 44[start] a man riding a red black and white race car [end]
# 45[start] young adults in red yellow and black shirts browsing in a line for his number [end]
# 46[start] a young boy throwing a rock into a body of water [end]
# 47[start] two women with short hair are in ready to reach the other is talking with her a camera [end]
# 48[start] a workers in a diverse tube top in front of a bright structure [end]
# 49[start] a dog is walking to a small waterfall in the mouth [end]
# 50[start] three small dogs at something [end]
# 51[start] two men paddle their kayak on a boat with green trees on either side of through both terrain [end]
# 52[start] two girls walking down a street [end]
# 53[start] a group of children sit in back of a van and woman look at a book [end]
# 54[start] people at the beach watching a painting of a metal box [end]
# 55[start] a girl is seated in a public area reading chairs and a missing her arm is held up by a bird in the same teeth [end]
# 56[start] a man has a lunch in a restaurant [end]
# 57[start] a man is wearing a suit and glasses is wearing a drink in his hands [end]
# 58[start] a man in a black bodysuit is surfing a wave [end]
# 59[start] a woman with a pink purse sitting on a bench [end]
# 60[start] three women are smiling and sitting [end]
# 61[start] a red plane jumps over a boat and canoe in front of a bunch of pink cloud [end]
# 62[start] a man in athletic gear climbs up a rock [end]
# 63[start] two construction workers help a pick up truck in a city [end]
# 64[start] a woman in colorful clothing walks past a white van with a white van [end]
# 65[start] a woman in a blue shirt and yellow skirt jumps by a water slide [end]
# 66[start] a man in gold clothes standing by his old bicycle [end]
# 67[start] a baby is looking at the leaves on a branch [end]
# 68[start] a woman is about to go on a train station [end]
# 69[start] two small black boys are playing with green and white tiger with each other [end]
# 70[start] on a traffic display of green and people looking at a motorcycle [end]
# 71[start] two people climbing on a rock wall [end]
# 72[start] a guy and a woman on a beach [end]
# 73[start] a child does a flip in the trampoline as he jumps [end]
# 74[start] children riding on a toy motorcycle [end]
# 75[start] two people hold up their feet giant blue and while four on a small child look like they are jumping wire [end]
# 76[start] two men out of the school play baseball [end]
# 77[start] a woman in a black dress is pushing a cart with a sleeping bag [end]
# 78[start] a police officer holds a car on the side of the road [end]
# 79[start] a man standing on a pier next to a boat on a calm peaceful lake [end]
# 80[start] a group of medical professionals performing a parade [end]
# 81[start] a woman and a child sit on a bus stop by a gray and a man walk past [end]
# 82[start] a lone fireman dressed in a big fire [end]
# 83[start] a person in a purple shirt is painting a picture of a woman [end]
# 84[start] a young girl are laying on the floor on on while her friend prepares for a moment [end]
# 85[start] the older and one woman in traditional dresses are in traditional dresses appear to be gathered for a picture with there is under the background [end]
# 86[start] a woman is walking through deep snow covered hill [end]
# 87[start] the rider listens to a vests are working with a life shovel and lifted up by a beautiful day [end]
# 88[start] the brown dog is wearing a black collar [end]
# 89[start] a brown and white dog runs down a ramp covered in tow [end]
# 90[start] a child is about to take a book [end]
# 91[start] an older light colored shirt attempting to repair a large machine [end]
# 92[start] a young child and female standing next to a rooster in a cage [end]
# 93[start] a child sitting behind a makeshift boy on a door [end]
# 94[start] a man in a brown is holding a sword [end]
# 95[start] a young woman stands and sings into a microphone while a man holds a guitar behind her [end]
# 96[start] two kids pull a wooden javelin in the dirt [end]
# 97[start] there are two dogs a empty and laying on them in a loaded cart looking focused [end]
# 98[start] some men are sitting on a boat next to a beach with a bemused and patch and patch of sticks [end]
# 99[start] a young man carries something in a large black splashed on a display [end]
# 100[start] an older man with a large black and white uniform is focused on his hands [end]
# 101[start] a man in a yellow suit on stage with a piano and another man playing the bass [end]
# 102[start] several people stand near some trees for the drums [end]
# 103[start] a brown dog is biting a large piece of wood [end]
# 104[start] a male performer poses in a holiday puddle [end]
# 105[start] a group of children play around in water below a bridge [end]
# 106[start] a woman laughs next to a man who is smiling and holding bagpipes [end]
# 107[start] two women stand in front of a classroom talking to an art gallery [end]
# 108[start] two brunette women with colorful christmas kids are children in a classroom [end]
# 109[start] an individual is wearing a hat and a scarf and looking to the right [end]
# 110[start] two people are walking across a street [end]
# 111[start] an old man is holding a yellow and the other dog is climbing into broken oven [end]
# 112[start] three children watching the men play on the guitar [end]
# 113[start] a boy takes his board from a photograph in a competition [end]
# 114[start] a blue jeep is riding a ravine with blue jeep [end]
# 115[start] a lady with a black hat taking a picture while outside of the ground [end]
# 116[start] a man sits on the floor and playing a guitar [end]
# 117[start] a dog treads the shallow water in the waters of a mountainous mountains [end]
# 118[start] a young asian girl jumps in the air in a crowded town [end]
# 119[start] three men are performing on stage [end]
# 120[start] four people are protesting against a ipad while wearing a young choir work [end]
# 121[start] a man does work in a black grill [end]
# 122[start] a man in a hat leaning against a piece of art [end]
# 123[start] a little boy in a yellow shirt is hanging by two dogs in a circle [end]
# 124[start] a little kid eating fruit and drinking a glass of soda [end]
# 125[start] one man and two women in shorts walk down a street [end]
# 126[start] two runners run through the snow [end]
# 127[start] a young redhaired girl wearing a wetsuit rides a bucking bronco and rides a toy [end]
# 128[start] a man in white a buttondown holds a pond [end]
# 129[start] skiers getting skiers gear and on the side of a cabin [end]
# 130[start] people are congregated outside a rock or a school [end]
# 131[start] several people swimming in the water [end]
# 132[start] women in swimsuits playing in a games [end]
# 133[start] a man and woman sit at a table in a restaurant [end]
# 134[start] a mother and two children posing while doing a picture out of her face [end]
# 135[start] a golden dog is paddling in the water with a red toy in its mouth [end]
# 136[start] four men are standing near a yellow car [end]
# 137[start] a group of men women wearing hats and children who are having a conversation on a beach [end]
# 138[start] a little boy in a onesie hat is climbing [end]
# 139[start] a little girl putting up as she comes next to an electric container of a plastic container [end]
# 140[start] a yellow dog carries a ball in its mouth on the beach [end]
# 141[start] a man in a red shirt and two children are standing in front of a old building [end]
# 142[start] a man is looking at a woman while well as the woman is in the bar [end]
# 143[start] a band playing outside on a river by a river [end]
# 144[start] two women smile at the social gathering for the event [end]
# 145[start] a woman is wearing a pink shirt and a man in a striped sweater watching some sort of pipe to be doing work [end]
# 146[start] a child sitting on a rock [end]
# 147[start] a man sitting in a chair in is using a beer and grills something to his stick [end]
# 148[start] a officer in uniform is wearing a uniform [end]
# 149[start] a man wearing a paved clothing passes in the middle of a red tree while a red truck [end]
# 150[start] a black and white dog is swimming in a mouth [end]
# 151[start] the band is playing on stage at a concert [end]
# 152[start] three people are playing musical instruments and one person appears to be singing [end]
# 153[start] a man playing a keyboard and singing into a microphone [end]
# 154[start] a little boy jumping into the water [end]
# 155[start] a woman reads her baby while sitting on the end of a woman stands next to her and is holding a glass case with drinks [end]
# 156[start] construction workers work on a construction site [end]
# 157[start] a man is shaving and at the beach in the ocean [end]
# 158[start] a blond woman in a blue shirt unwrapping a hat [end]
# 159[start] two men stand in a protest and a female male female are standing for their right side [end]
# 160[start] a young blond man is speaking into a microphone [end]
# 161[start] a child in a cape is pushing a plastic bag [end]
# 162[start] the man crouches between the plants and are looking in the camera [end]
# 163[start] there are a band performing on stage in front of a crowd of people [end]
# 164[start] three dogs are playing around in the snow [end]
# 165[start] a man and a woman stand near a tree talking to each other [end]
# 166[start] a dog jumps to a ball in front of a hot ball [end]
# 167[start] older woman in gray and red sweater cooking a meal [end]
# 168[start] a woman in a coat walks in front of a house [end]
# 169[start] a woman carries a younger woman wearing tank top looking at the same time [end]
# 170[start] a child is standing next to a stroller and holding a sword [end]
# 171[start] a young man with curly hair skateboarding down a ramp [end]
# 172[start] a man is running down a beam with his hand of the ground [end]
# 173[start] a group of people in a boat on the sea [end]
# 174[start] a a man in a yellow shirt is standing on the sidewalk and drinking something [end]
# 175[start] a woman in a blue shirt and jeans is throwing something into a dumpster [end]
# 176[start] a woman with a mask on her cellphone is being held at a party [end]
# 177[start] a person is staring at the crest of a wave [end]
# 178[start] men dressed in blue uniforms sitting on a bus [end]
# 179[start] a car carefully attempting to get off a ditch next to the hole [end]
# 180[start] a man is shorter from the other as she is playing soccer [end]
# 181[start] a soccer player in red and white is with the coach [end]
# 182[start] two girls are sitting by a wall and looking at a match [end]
# 183[start] a coach bakery wearing sunglasses is wearing a sporting the sunglasses during a game [end]
# 184[start] the yellow team is wearing red and blue shirts and red helmets [end]
# 185[start] a boy in black clothes does a cartwheel on the beach [end]
# 186[start] posing for a photo [end]
# 187[start] man in green shirt putting his mouth while a black officer looks on a track [end]
# 188[start] five students are performing a song [end]
# 189[start] three women are sitting on the floor with a child and talking on something [end]
# 190[start] a man and a boy are sitting along holding a pizza room [end]
# 191[start] a man in sunglasses helps a child in sunglasses is riding a down a slide [end]
# 192[start] a dog running in a field towards a photographer [end]
# 193[start] a girl with long hair is set up the ball with another player on the field [end]
# 194[start] two men wrestle at a mans ground [end]
# 195[start] a girl in a red and blue suit is cheer her a ball on the baseball field [end]
# 196[start] a man sits with his hands [end]
# 197[start] a brown dog running on the beach and carrying a stick [end]
# 198[start] a person is rowing in the water [end]
# 199[start] a man in a red and white striped shirt is sitting on a stool in the background [end]
# 200[start] a man is taking a picture with a yellow room [end]
# 201[start] two men in business talk while standing on an outdoor market [end]
# 202[start] a man and a young boy are playing with the dog at sunset on a beach [end]
# 203[start] a hot air balloon is parachuting in the background [end]
# 204[start] the man is wearing the hat and a hat [end]
# 205[start] a woman with a red ukulele dress face paint and crafts [end]
# 206[start] a toddler boy in a denim hat plays in a tire [end]
# 207[start] a crowd of people is standing on a street in front of white tents [end]
# 208[start] a crowd of people are walk through a park [end]
# 209[start] a woman with dark hair and a blue shirt is wearing a blue blouse and a little girl holding a sign to help a closeup [end]
# 210[start] a camera is doing a painting with graffiti under a sign [end]
# 211[start] a cowboy doing cowboy on a horse back kicking up fruit [end]
# 212[start] a bride and groom make their way a kiss next to sit [end]
# 213[start] two emergency responders are at the train [end]
# 214[start] a man works at an entrance to a train station [end]
# 215[start] a couple of men messy concrete being watched by construction workers completing repair one next to their someone [end]
# 216[start] a band playing on the sidewalk [end]
# 217[start] men in orange suits are cleaning a machine as a surfer opposite something going on the street [end]
# 218[start] young adults in casual dress walking on grass [end]
# 219[start] the large brown dog is running through the shallow water [end]
# 220[start] a man and woman are walking across a empty street [end]
# 221[start] a man wearing the water in front of a crosswalk which is working on the plastic company [end]
# 222[start] two children in yellow coats play with air in mud [end]
# 223[start] several people are riding down a roller coaster [end]
# 224[start] a woman sits with a young boy on a chair [end]
# 225[start] a group of people are standing around on a cement brick floor [end]
# 226[start] a little girl swimming in a pool [end]
# 227[start] boy in orange shirt getting laughing and a guy in a blue shirt [end]
# 228[start] a young girl is standing outside in a puddle [end]
# 229[start] a little girl holds a sandwich a sandwich [end]
# 230[start] four people are trying to fix a wheel bike in the park [end]
# 231[start] a brown dog is getting a and climbing out of the water [end]
# 232[start] a soccer player runs across the grass carrying a ball in its mouth [end]
# 233[start] a group of people wait behind sack waiting for something [end]
# 234[start] a child wearing a hoodie and yellow shirt hangs upside down from a tree [end]
# 235[start] the childrens rock carnival game is being played from two others on a sunny day [end]
# 236[start] a boy smiles as he sits at a group of seated children in a group [end]
# 237[start] two shirtless children sitting on the edge of a fountain [end]
# 238[start] a man is reaching out of a fire hose on his legs [end]
# 239[start] an old man is walking his ice skater in his hand [end]
# 240[start] a young woman and an older man standing by a bar [end]
# 241[start] a young blond boy is jumping off a bed on a bed [end]
# 242[start] a young child swings a red baseball bat [end]
# 243[start] a man is talking on the phone in front of a sports store [end]
# 244[start] two belly listening to a small child [end]
# 245[start] a woman in a blue shirt playing an instrument [end]
# 246[start] this is a busy city street workers are in the nighttime [end]
# 247[start] a man is sitting in shallow water next to a large rock face [end]
# 248[start] a couple of tourists taking a break to photograph [end]
# 249[start] four people in asian winter walking down a street with trees in the background [end]
# 250[start] 4 people are part in front of a riding suit in an amusement park [end]
# 251[start] a young boy is performing a trick off a skateboard bar [end]
# 252[start] a man is building a sand castle on the beach [end]
# 253[start] a big brown dog chases a small brown dog [end]
# 254[start] men in white suits dough with their hands [end]
# 255[start] a woman is throwing a frisbee next to her dog wearing a jersey and the baseball [end]
# 256[start] a black dog stands in the grass carrying a plastic toy shop in its mouth [end]
# 257[start] a boat with people and their belongings is in the water [end]
# 258[start] a group of a peloton bicycle riding down a carnival ride in the meadow [end]
# 259[start] three people sit outside at a table that are displayed have passed walking [end]
# 260[start] a white female and a black man are down a street [end]
# 261[start] a man in a white shirt rides a sleeping wave in the middle of his ground [end]
# 262[start] a husky dog rough debris at a tree [end]
# 263[start] a man with a painted face poses for a woman [end]
# 264[start] two boys playing a game with toy [end]
# 265[start] two people wait on their car seat in the car and driver at their kind of contraption [end]
# 266[start] a boy swings on a swing set [end]
# 267[start] a black male is looking at another man who is playing under a waterfall [end]
# 268[start] a person with a red backpack on a mountain bike [end]
# 269[start] an asian european belt with vegetables and her new york gas melon and other on his image [end]
# 270[start] a large crowd standing with large buildings in the background [end]
# 271[start] three women with dark hats cleaning up near brown cup on them talking a brick street while a dog sits on them [end]
# 272[start] a man in white plays with his hand [end]
# 273[start] a person with a large maroon pink shirt looking at the beach [end]
# 274[start] a man is looking at a woman made of stone smoking [end]
# 275[start] a man wearing a black shirt white husky holding a shovel holding a shovel [end]
# 276[start] a man is blocking a woman with glasses [end]
# 277[start] a child walks in front of another [end]
# 278[start] a little boy in the background is making a funny face as the young boy stands in front of him [end]
# 279[start] a baby in pink shirt is laying in a dry leaves and talking [end]
# 280[start] a closeup of women with short red hair [end]
# 281[start] a soccer player in a green uniform runs down the field [end]
# 282[start] a girl is leading her dog over a hurdle [end]
# 283[start] several children are sitting in a room with colorful sheet on colorful equipment [end]
# 284[start] a red and jumps in the air on a large boat [end]
# 285[start] a mid sized brown and white puppy jumps up to catch a frisbee [end]
# 286[start] a man in a gray shirt taking a nap [end]
# 287[start] a black dog jumps through the water while holding a stick in its mouth [end]
# 288[start] two black dogs run next to a pile of clothes which are also wearing each other [end]
# 289[start] four people in casual dress standing outside one holding bags [end]
# 290[start] people and camels pillars in the desert [end]
# 291[start] four dogs are playing around in a circle and one black dog is walking [end]
# 292[start] man in army uniform speaking to a microphone [end]
# 293[start] a group of asian men on display for a toy car during a christmas tree [end]
# 294[start] a swimmer swimming in a pool [end]
# 295[start] a woman in a white shirt is playing on a couch inside a house [end]
# 296[start] a man next to two young girls giving the hands a drink [end]
# 297[start] a girl in a white shirt in a dark room eating at a bright red [end]
# 298[start] boys and girls from other stage are smiling for something in a field [end]
# 299[start] a child in an orange shirt is jumping off of an concrete as other children watch [end]
# 300[start] a boy doing skateboard tricks on a skateboard [end]
# 301[start] a man reaching out to throw the toy over a table [end]
# 302[start] a toddler is sitting at a table and snacks [end]
# 303[start] four kids with hands stop to look back towards the camera as they cross a water [end]
# 304[start] a man with dreadlocks runs across the street to make a turn [end]
# 305[start] a man is putting up a large marble to a toy structure in a mustard while another man looks on [end]
# 306[start] a dog looks at a grassy tree [end]
# 307[start] a woman and a young child play on a log game of hockey [end]
# 308[start] 4 children are sitting on a ledge talking [end]
# 309[start] a small brown dog in the structure in a blanket and arm [end]
# 310[start] two men are painting a white and third walking by a third man a phone in the back [end]
# 311[start] some people are in an office are looking at a computer screen [end]
# 312[start] two females are looking up at the camera [end]
# 313[start] a blond woman in a brown cowboy hat does a routine on a camera [end]
# 314[start] a white and tan dog is running on the grass [end]
# 315[start] a teenage girl reads a book at a table outside while looking away looks upon the table [end]
# 316[start] two little girls are walking in foliage [end]
# 317[start] a bride adjusts her umbrella on his gear while holding the paper under a bouquet [end]
# 318[start] a woman pulls a orange piece of flower in a sit at a person [end]
# 319[start] two women with a stroller down the street all wearing a path [end]
# 320[start] four women are wearing a fake tattoo [end]
# 321[start] this young asian woman rests kneeling down making a very fenced in an orange day [end]
# 322[start] girls in bikinis are playing beach volleyball [end]
# 323[start] a man with glasses and a little girl in a life jacket swimming in a pool [end]
# 324[start] three children wearing brown shirts and jeans jumping on a busy outside where leaves are on the ground [end]
# 325[start] a woman swings at a pinata [end]
# 326[start] a person is carrying a load of trees [end]
# 327[start] a baby with a blue roof covers that are standing on hot strobe glass [end]
# 328[start] a young man with a cane is standing between cement buildings [end]
# 329[start] a child in a school is performing some kind of contraption involving a drink [end]
# 330[start] a man is on a wakeboard in the water [end]
# 331[start] children are staring out windows from a blue building with red doors [end]
# 332[start] a man with braided hair and a beard wearing glasses and wearing black is sitting on the grass [end]
# 333[start] a mother and her two children are on the beach run leaps high in the air [end]
# 334[start] a couple men walking on a city street [end]
# 335[start] a guy doing a trick on his bike in a park [end]
# 336[start] a man in a bright colored jacket at a holiday bar with other people [end]
# 337[start] a woman in a yellow shirt and sunglasses is walking on the sidewalk [end]
# 338[start] two women are looking at many houses [end]
# 339[start] two large dogs are biting each other in the grass [end]
# 340[start] people dressed in sport clothes together warming up [end]
# 341[start] a group of people are eating at a restaurant [end]
# 342[start] a woman in a black shirt appears to be going up the escalator [end]
# 343[start] a room full of four people with eight bamboo houses are dressed in vibrant guards [end]
# 344[start] a man and a woman pose together on a paved street [end]
# 345[start] two dogs are running while playing in the snow [end]
# 346[start] a small dog jumping in the street [end]
# 347[start] a man wearing a black shirt plays the bass on stage [end]
# 348[start] a boy and an old man in a cane talking [end]
# 349[start] a girl in a white shirt black shorts and pajamas playing volleyball [end]
# 350[start] two men standing on a street that is covered in graffiti [end]
# 351[start] a boy wearing a shirt and shorts is holding a podium while slope on a snowy hill [end]
# 352[start] a man is hanging thread in a sea [end]
# 353[start] two girls in gold clothing are wearing a attire holding up a sword and holding the reins of a snake her left hand [end]
# 354[start] a dog running through deep snow [end]
# 355[start] a medium sized mixed big a camera in front of a camera [end]
# 356[start] a large black and white dog is laying on a jacket on the street [end]
# 357[start] two teenage girls are holding up at a set of beer and smiling [end]
# 358[start] a mother and son are riding on a sled smiling [end]
# 359[start] a man in a black shirt cooks as a camping inside a messy kitchen [end]
# 360[start] a woman dressed in white plays a black guitar [end]
# 361[start] a snowboarder is jumping in the air by a mulch machine [end]
# 362[start] a few people standing in a room eating [end]
# 363[start] a man with a hat is playing a instrument at a subway station [end]
# 364[start] a guy is slope at his a third man lining up [end]
# 365[start] a woman in a white shirt and black pants is dancing on a line while on [end]
# 366[start] an older man puts on a large white are in a racing jersey [end]
# 367[start] two men in red uniforms are performing martial arts [end]
# 368[start] small child riding through the mud on a motorcycle [end]
# 369[start] a child wearing a hat and jacket on a stone surface outside [end]
# 370[start] a child sitting in a crowd on their shoulders of her dad [end]
# 371[start] two old men in hats on fire gear are inside an industrial [end]
# 372[start] two young boys in a tent smile for the photographer [end]
# 373[start] a warmly dressed in black kneeling with a small tan colored dog in front of a crowd [end]
# 374[start] two men are at some type of equipment [end]
# 375[start] a woman carrying a bag of storage ties the garb is holding a bag in a train [end]
# 376[start] a cyclist is doing a trick in the air [end]
# 377[start] a young man in a green sweatshirt reading a newspaper on the beach [end]
# 378[start] a hold man in a green jacket smiles [end]
# 379[start] the man is climbing up a wooden rock with a balloon [end]
# 380[start] a young man is riding his skateboard through a city street [end]
# 381[start] two brown dogs wrestle at a grassy hillside [end]
# 382[start] a person wearing a long red coat walks in front of a building [end]
# 383[start] foreign woman sitting with a very colorful cloth [end]
# 384[start] two men fence a are jumping in the air holding a basketball [end]
# 385[start] a man with glasses at a microphone looking at papers in his hand [end]
# 386[start] a child in a green shirt that has a red balloon over his mouth [end]
# 387[start] a man with tattoos is ordering his what he looks at him [end]
# 388[start] a group of play the arcade of the screen [end]
# 389[start] group of young asians running an marathon [end]
# 390[start] a man pulls items in a cart [end]
# 391[start] three large dogs are enjoying the slopes in the snow [end]
# 392[start] a bird flies through the water [end]
# 393[start] a group of individuals are sitting at an outdoor gathering [end]
# 394[start] a yellow car zips by in through the snowy field [end]
# 395[start] a group of children are playing instruments and playing instruments [end]
# 396[start] a group of adults are sitting at a table listening to the presentation [end]
# 397[start] a woman wearing a green tshirt is reading a newspaper [end]
# 398[start] young people are being watched by people [end]
# 399[start] baseball players in blue and white jerseys playing baseball in a field [end]
# 400[start] a woman and two boys look on top of blue and green and white emergency subway station [end]
# 401[start] a group of people are running a marathon for being washed [end]
# 402[start] two women stand with a holding wearing a snow [end]
# 403[start] people are standing together in front of the statue of a display in winter clothes [end]
# 404[start] a young skier looking at the camera [end]
# 405[start] two young girls dressed in pink pajamas are sitting on the floor near a large windows playing with small hats and a small carnival [end]
# 406[start] a woman and a child ride a camel in the ocean [end]
# 407[start] a man with his hand on a stage smiling in a crowded bar [end]
# 408[start] a street is full of people in coats [end]
# 409[start] two men in a foreign country with a redhaired girl standing and one standing with his heads [end]
# 410[start] a small brown dog is gallopsing through the grass [end]
# 411[start] street vendor in the street at night [end]
# 412[start] a snowboarder is in the air [end]
# 413[start] an asian woman in a blue and red uniform pulls a big pile of yarn [end]
# 414[start] a woman in a blue shirt is riding a bicycle [end]
# 415[start] the woman in white tennis outfit jumping to hit the ball [end]
# 416[start] a young woman exercising on a play an instrument [end]
# 417[start] a bride and groom take pictures with a picture of two men [end]
# 418[start] a woman holding a black and white dog [end]
# 419[start] a boy in a red shirt tries to play a guitar [end]
# 420[start] a young female speaker in a doorway that is testing a christmas tree [end]
# 421[start] three kayakers one woman and one a other women are standing in and a line in the middle of him [end]
# 422[start] a white furry dog is jumping and catching a toy in the back [end]
# 423[start] a matador in colorful clothing riding a bucking bull [end]
# 424[start] children are swimming in water from inside a pile of inflatable boats [end]
# 425[start] a light brown dog jumps with a yellow ball in its mouth [end]
# 426[start] a group of people wearing blue shirts taking a sporting event [end]
# 427[start] a tennis player in a blue and blue headband and blue a yellow shirt [end]
# 428[start] two little girls in blue water are smiling [end]
# 429[start] a little girl in a pink toy trying to cross [end]
# 430[start] two people are running on a mountain [end]
# 431[start] a group of women dancing and wearing colorful costumes and a fired [end]
# 432[start] a cyclist is jumping in the woods [end]
# 433[start] several people walk along a white fence in a foreign country [end]
# 434[start] a woman is standing on a brick wall taking a picture [end]
# 435[start] a woman in a yellow short shirt with white sandals appears to be throwing a stick [end]
# 436[start] a person is riding a dirt bike [end]
# 437[start] a young asian girl reading a black smile sitting in her flower shop bent over her face [end]
# 438[start] two terriers jumping after a hardwood floor a house [end]
# 439[start] a toddler with a closed blue tent wearing a red shirt [end]
# 440[start] a teenage boy in the skiing in the front of a boy [end]
# 441[start] an old man is wearing a black jacket and looking at a table [end]
# 442[start] a man in a blue shirt walking next to a man in a red [end]
# 443[start] the woman was plates of the tree for their feet are being held [end]
# 444[start] a little a boy riding a helmet is walking along a fallen tree trunk with a tennis tree [end]
# 445[start] a black dog leaping over a bright hurdle [end]
# 446[start] a boy in blue is playing soccer with the ball of his [end]
# 447[start] a group of bike riders are getting ready to racing in a race [end]
# 448[start] a man runs out in front of a black bull [end]
# 449[start] a boy of a red tank top and waters sits in a park [end]
# 450[start] a small brown and white dog runs along a walkway [end]
# 451[start] two small women are putting their hair into a birthday princess castle [end]
# 452[start] a passenger seat of two men and interacting [end]
# 453[start] a black poodle is playing with another dog and a brown field [end]
# 454[start] several people are enjoying an wine near a map [end]
# 455[start] a white dog with a brown landscape jumps from the shore in the water [end]
# 456[start] a photographer taking a picture of a building with an assortment of him [end]
# 457[start] a little girl in a green and a large blue ball along side a fence [end]
# 458[start] a man is training some sort of material [end]
# 459[start] a group of young people pose for a sandy beach [end]
# 460[start] a woman is holding a violin [end]
# 461[start] a store is outside of a very short the day [end]
# 462[start] a guy in a gray shirt doing a trick on his skateboard [end]
# 463[start] three men are walking near a tent with billboard [end]
# 464[start] a little girl is standing in a field [end]
# 465[start] a boy in a blue and yellow jersey is learning [end]
# 466[start] a man and a woman play a game outside [end]
# 467[start] a little girl wearing a dress and sandals runs across the grass [end]
# 468[start] a woman with purple hair and a man in an older uniform [end]
# 469[start] people dancing and clapping their hands [end]
# 470[start] a man walking along the street as a passerby looks passer while spinning the escalator [end]
# 471[start] a man in a white shirt and striped shorts is playing the surfer while looking at them [end]
# 472[start] a large group of people watch a performance on a stage [end]
# 473[start] a car is riding down a dirt and leaving behind the field practicing hospital [end]
# 474[start] a group of people listening to a man speaking outdoors [end]
# 475[start] a bearded man in a striped shirt is making a on his shoulder mans shoulder [end]
# 476[start] a boy is getting ready to kick the ball past the goal [end]
# 477[start] a bicyclist riding a bicycle down the road past a stones that pond over the snow [end]
# 478[start] a longhaired man in the ocean waves [end]
# 479[start] a boy and a man dressed as a girl stand in the sand [end]
# 480[start] a young blond girl smiles and points to someone as she poses in front of a fashion [end]
# 481[start] a man in a blue is riding a motorcycle on a track [end]
# 482[start] a person tries a parachute in a parachute with his sun [end]
# 483[start] a waitress stands in a a a man with a crab [end]
# 484[start] two bikers moving down a street on a cold winter day [end]
# 485[start] a group of musicians perform music [end]
# 486[start] two people play in a volleyball pool [end]
# 487[start] a subway station climb onto a few men outside of a building [end]
# 488[start] a boy has just another boy on his back [end]
# 489[start] a woman is using a camera are walking on the street while wearing a large camera [end]
# 490[start] a woman wears a large tank top and water [end]
# 491[start] a woman is pushing a covering her face with a pen [end]
# 492[start] a man of adults with tattoos is throwing something [end]
# 493[start] a man wearing a blue shirt riding a unicycle while standing umbrella holds a burning fire [end]
# 494[start] a small child is playing with and the sprinkler [end]
# 495[start] four children are playing the mud in front of a cart while their father watches [end]
# 496[start] a man is holding a baby and leaning on a building [end]
# 497[start] a woman with two light sweater is leading a newborn baby [end]
# 498[start] the two men are fighting while playing in a game of soccer [end]
# 499[start] two girls eating cake one is holding a blue mop with blue ear [end]
# 500[start] a woman is putting bikini [end]
# 501[start] the crowd watches someone in the distance [end]
# 502[start] a boy in a park plays with two orange ball [end]
# 503[start] a young blond girl stands on a pillow smiling with her eyes closed [end]
# 504[start] a man with a guitar sings into a microphone [end]
# 505[start] a man with the group of climbers covered around his neck is holding a pole [end]
# 506[start] a man in green and white is bending over plants [end]
# 507[start] a man takes a picture of another man and his two dogs in a grassy field [end]
# 508[start] a man doing some public area with fire [end]
# 509[start] a large black dog runs along a fence on the grass [end]
# 510[start] a dirt bike has the air in a race is about to hit the surf [end]
# 511[start] a woman riding a bike down the road carrying an outdoor side of the front of a bike [end]
# 512[start] a black dog jumps over a water show while they pool [end]
# 513[start] a man in a black jacket and black hat playing a trumpet [end]
# 514[start] a man in black rides a snowboard on a fountain [end]
# 515[start] an indian man sitting outside at a table in a restaurant [end]
# 516[start] three men in a suit are swinging hand [end]
# 517[start] a small dog in a outfit standing on its hind legs to face covered with flowers [end]
# 518[start] a man rides down the stairs [end]
# 519[start] a man wearing a bucket and a girl are in the top of a girl are in a top of the beach [end]
# 520[start] people walk down a city sidewalk in front of a bar [end]
# 521[start] a large dog jumping in a fountain with a man wearing a black shirt and vest [end]
# 522[start] a man on a boat wearing orange pants and a leash [end]
# 523[start] two men outside on a bright sunny day video games to try some fish on a lake [end]
# 524[start] a man is standing on scaffolding carrying an alley [end]
# 525[start] a vendor in a white teeshirt shines on a asian in a crowded floor [end]
# 526[start] two people in white shirts walking on a sidewalk and talking on their cellphones [end]
# 527[start] a little girl with a green necklace runs from a [end]
# 528[start] artist are painting a outside [end]
# 529[start] two asian children a boy and a girl are standing on the floor near a tree [end]
# 530[start] people in line of the store preparing to run [end]
# 531[start] two hockey players one wearing pink and one wearing white is playing a game on a field [end]
# 532[start] a woman in a yellow helmet and blue helmet is riding a rope [end]
# 533[start] a black dog swimming in the water with a tennis ball in its mouth [end]
# 534[start] three men are wearing a gold car [end]
# 535[start] a woman wearing a number is going across a sports field of supermarket with international flags [end]
# 536[start] a man in blue shirt plays the trumpet [end]
# 537[start] an indian woman stands among piles of gardening or coffee while he holds the protest in right hand and in the left hand [end]
# 538[start] many people are standing by a fountain under a blue and white umbrella [end]
# 539[start] a woman is knitting to fight with a rolling hills [end]
# 540[start] a street vendor offering gathering windows [end]
# 541[start] three men standing around a cart near several motorcycles [end]
# 542[start] a crouching donkey is sitting behind a counter [end]
# 543[start] a man in a red jacket with a glass and white striped outfit are standing in front of a wall [end]
# 544[start] a man is looking at a computer screen of his 4 people [end]
# 545[start] two people riding on a dirt road on a dirt path [end]
# 546[start] a young asian girl with the dirty face is carrying a pillow [end]
# 547[start] a child at the edge of a lake pointing at something in the sky [end]
# 548[start] a bunch of elderly boys are playing the guitar [end]
# 549[start] a man in a white shirt and khaki pants kneels on a tree branch [end]
# 550[start] two boys are preparing a little boat and two girls on the beach [end]
# 551[start] an old man in medieval clothing holds on a tree and standing on a hill [end]
# 552[start] three people are sitting on a beach sitting and kneeling in the water [end]
# 553[start] a view through a european outfit on a man in yellow standing near a small tub [end]
# 554[start] a child is shirtless black and mosaic covered in a barber [end]
# 555[start] two women in pink shirts and blue jeans are talking in front of a store that is at a store [end]
# 556[start] a policeman is practicing while riding a bucking horse plays in a crowd [end]
# 557[start] a big black dog is catching a flying in the snow [end]
# 558[start] a man is taking a photo of a lake with mountains in the background [end]
# 559[start] a brunette woman in a blue apron motor animal [end]
# 560[start] people are protesting by a topic of a parade [end]
# 561[start] two young girls are playing basketball dressed in white and the other children trying to get control him [end]
# 562[start] a lady in a bikini is doing a a cartwheel on the beach [end]
# 563[start] a man in a brown shirt and black vest and black vest playing a bass guitar [end]
# 564[start] a woman with blondhair drinking from a glass [end]
# 565[start] a little boy is laying on an hospital in has a stroller his leg [end]
# 566[start] two men are playing laptops while opening musical performers [end]
# 567[start] a dog has his mouth very closely followed by his cart [end]
# 568[start] an elderly man blew up to craft to yarn [end]
# 569[start] a man is laying in a pile of snow covered in front of a window [end]
# 570[start] a little girl is reaching out to get a lens [end]
# 571[start] a woman with black hair and a black hair shirt with a red skirt and red skirt runs tapestry [end]
# 572[start] a man pushes a log through a library across the library [end]
# 573[start] two dogs play at a snow and has a slightly pancake of bed [end]
# 574[start] a woman with her face dressed in a living room wearing an office [end]
# 575[start] two hockey players are about to fight when they possibly to be pulling a team drives the puck [end]
# 576[start] runners passing through a skating in a city [end]
# 577[start] a group of people dancing in a club or in costumes [end]
# 578[start] two children are preparing a board in a position [end]
# 579[start] a teenage boy in jeans and a tshirt plays a black electric guitar [end]
# 580[start] a person dressed in a yellow costume crowd in a public place [end]
# 581[start] a swimmer in a lake watching a boy is sitting on a wall [end]
# 582[start] a crowd of people at a city streets with smoke and officers [end]
# 583[start] a dog on a leash strolls in the snow near the country [end]
# 584[start] a group of female racers are picking up home [end]
# 585[start] a woman in a black sweater trying to give a pick up on a bush [end]
# 586[start] a boy gets his picture taken by another boy being taken by another boy [end]
# 587[start] a picture of an artist shaving their head of the apple [end]
# 588[start] tourists taking a picture of a building in china [end]
# 589[start] a hard and a car on a parking lot with a man with a white car on the side of the car [end]
# 590[start] two men behind a bar with a man in a room full of people [end]
# 591[start] a man and woman waiting for the train is waiting to pass [end]
# 592[start] children are having a conversation while practice in an office [end]
# 593[start] a man is singing into a microphone toward a band playing his guitar [end]
# 594[start] a singer singing together with a crowd [end]
# 595[start] an elderly woman wearing a blue hat sits on a sidewalk and cuts each their yellow [end]
# 596[start] a construction worker in a black shirt and jeans is setting up a ladder to be resting by [end]
# 597[start] a waitress in a white shirt takes a haircut at a restaurant [end]
# 598[start] a blond man in a black and white jacket using a paper woman [end]
# 599[start] a girl is being riding a skateboard of are in the middle of a midair while spectators [end]
# 600[start] an artist is working on a ice create [end]
# 601[start] a man in a blue jacket riding a bike with two dogs [end]
# 602[start] a and be things or orchestra [end]
# 603[start] two people play a game talking to each other [end]
# 604[start] a group of girls are playing with toys [end]
# 605[start] a little girl playing a musical instrument and singing into a microphone [end]
# 606[start] a man is playing a live with the computer [end]
# 607[start] a man who appears to be a jumping her face off of a dirt ground by brick tree [end]
# 608[start] a street scene with a person and fireman in winter clothes and fire [end]
# 609[start] a group of people wearing plaid skirts with shirts and white belts are playing drums and white drum drum [end]
# 610[start] a woman wearing a red practicing her motion [end]
# 611[start] a group of people running a marathon in the winter time [end]
# 612[start] a woman and a boy are smiling and facing each other in the music stand by side [end]
# 613[start] a man in a leather jacket watching two other men in aprons talks to the phone [end]
# 614[start] a little girl is walking across a small stream juggling [end]
# 615[start] a brunette man in a tan blazer jumps onto a midair on a half pipe [end]
# 616[start] two children dancing at a large display [end]
# 617[start] a picture of a woman and her man sitting down the parking lot [end]
# 618[start] a female dancer on a concert [end]
# 619[start] a man and a woman are sitting on a bench watching a boat [end]
# 620[start] a city street with a lot of chinese characters [end]
# 621[start] several people together [end]
# 622[start] a group of musicians play music on the street [end]
# 623[start] this man seems to be looking over the lens against a busy street [end]
# 624[start] two children are playing on a outdoor playground [end]
# 625[start] a man is sitting on the steps of a homes doorway [end]
# 626[start] a man in a suit suit is walking down a busy city street [end]
# 627[start] a man in a white apron and santa is selling meat on a busy street [end]
# 628[start] a woman is standing in a room with a name badge [end]
# 629[start] an older asian woman wearing a red hat and black shawl walking baseball is waving [end]
# 630[start] people are sitting between some columns and pictures on a wall [end]
# 631[start] a muzzled and dog are being serve through the ground [end]
# 632[start] two people looking at a a street window [end]
# 633[start] a man with a backpack sitting down on a dirt court points to his range [end]
# 634[start] two men sitting at a grill that has been way [end]
# 635[start] a woman in a yellow jacket is walking with two women in front of other women [end]
# 636[start] a man in a coat is talking on the street [end]
# 637[start] the person is on the bike in a green shirt in the window [end]
# 638[start] a little girl looks out over the wall [end]
# 639[start] a young man is putting something up to a coffee at a stand [end]
# 640[start] an old man sits in a fur in lap [end]
# 641[start] an african american man wearing a suit and sunglasses is standing against a brick wall [end]
# ...
# 808[start] a man in a white shirt is sitting on a bicycle [end]
# 809[start] an older brunette woman wearing a fur is walking down the street [end]
# 810[start] a man is sitting alone on the shore [end]
# 811[start] an older man is sitting on a bench in front of a protest sign that says service workers [end]
# 812[start] a man on a bike in a gray jacket [end]
# 813[start] a boy with glasses in a yellow the rain shirt standing on a parking lot [end]
# 814[start] two men are atop two dirt road [end]
# 815[start] a mother wearing a blue beret and tinted shoes reads a staring with her chest [end]
# 816[start] two dogs are is playing with the beach volleyball [end]
# 817[start] a man in unusual rock pulls on a motorcycle [end]
# 818[start] a man crouches by a yellow wall [end]
# 819[start] this appears to be a marketplace with several tables selling stuff [end]
# 820[start] a blondhaired boy in a blue shirt sitting with a woman in glasses [end]
# 821[start] a man in a maroon shirt looks on as a woman with eyes and arms on the back [end]
# 822[start] people are playing soccer at the canyon in the fountain [end]
# 823[start] four boys are posing while one looks at a beer [end]
# 824[start] a lady carries her head on a busy street [end]
# 825[start] a street performer dressed in orange jumpsuit rides a tall unicycle by a crowd of people [end]
# 826[start] person on a in a chair facing a crowd of people [end]
# 827[start] a man waits for subway on a train [end]
# 828[start] three white males wearing tshirts jump into the air [end]
# 829[start] a singer makes a daring leap to play [end]
# 830[start] a class takes place as he snaps teenage in a hospital [end]
# 831[start] a woman in a striped shirt has his arms and blue all on a grocery store [end]
# 832[start] a number of people around a stand trying to get into a car [end]
# 833[start] several people waiting for traffic in a in a store where a train game in a warehouse [end]
# 834[start] two girls play volleyball one player with the camera [end]
# 835[start] an elderly man adjusts something [end]
# 836[start] six people are standing in a gym fixing a bicycle [end]
# 837[start] two young asian boys are sitting a box [end]
# 838[start] a woman is preparing a snack with a pay phone [end]
# 839[start] two men in shorts are working on a blue bike [end]
# 840[start] a man and a woman are having fun ballet in an wheelchairs [end]
# 841[start] a man in athletic clothing passes a ball off a hill of snow [end]
# 842[start] a man and woman are enjoying themselves at a party [end]
# 843[start] a soldier he is singing with other men lined up a sailing frame [end]
# 844[start] two teenagers walking down a street [end]
# 845[start] a woman at a restaurant drinking from a cloud of smoke [end]
# 846[start] a woman in a blue uniform is standing and look down [end]
# 847[start] a man in shorts talking to another man in blue jeans in blue jeans in front of him [end]
# 848[start] a man is feeding a small child in a highchair [end]
# 849[start] a young bike rider is wearing a blue suit jumps in the air as she rides off a small hill [end]
# 850[start] a baby with a pink hat and sleeping carefully [end]
# 851[start] two children lay on their stomachs under a walkway [end]
# 852[start] two men are talking on a cellphone next to a telephone booth [end]
# 853[start] a woman is interacting with the bathroom [end]
# 854[start] children chasing ball as they play soccer [end]
# 855[start] two children jumping that are on a set of trampoline surrounded by trees [end]
# 856[start] two dogs in a field the frisbee is looking at the ball [end]
# 857[start] a drummer and a male guitar player in a dark outside a dark environment [end]
# 858[start] street people marching down a snowy snow filled with snow [end]
# 859[start] a group of people next to a small river during a city [end]
# 860[start] a woman looking through a telescope into a staring [end]
# 861[start] a little blond girl in a polka dot shirt takes a via sink in an sink [end]
# 862[start] a youth youth looking at a cardboard ball in a shallow beautiful scenery [end]
# 863[start] skiers jump through the air while others fight as they are looking out at a zoo [end]
# 864[start] three girls riding horses are blowing a structure [end]
# 865[start] a blond woman is blowing a bubble and happily [end]
# 866[start] a chef in a kitchen is weaving with knife [end]
# 867[start] a man is scooping flowers and a woman with a guy pointing in it [end]
# 868[start] a woman is singing into a microphone as a man in the background playing the drums [end]
# 869[start] man with bike helmet handing out of a store in a purple hat [end]
# 870[start] a worker is holding a tree [end]
# 871[start] several people are standing around a bowl playing like one post with a brown tool [end]
# 872[start] a monk wearing his rollerblades is both with his sunglasses is ironing the sort of his wires [end]
# 873[start] a woman wearing sunglasses and a flowered hat and a blue shirt sells carhartt and browsing at a man in a black shirt [end]
# 874[start] an old man is sweeping the floor while a woman goes to the camera [end]
# 875[start] a man with dreadlocks plays on his cellphone standing to a woman sitting on a sidewalk [end]
# 876[start] a man works on a construction site [end]
# 877[start] a man in the middle of a spectacular dunk by [end]
# 878[start] a man stands at the sunshine with food and watches stand [end]
# 879[start] a baseball player with a red helmet and white pants is chasing a catcher left while running from a baseball watches to the home base [end]
# 880[start] a man in an orange outfit is sweeping outside [end]
# 881[start] a man in a purple shirt working in a laboratory [end]
# 882[start] a man leads two little boys walk down the beach in a park [end]
# 883[start] two women one of the same and one girl are trying to be wrestling at a competition [end]
# 884[start] a man and woman are asleep on a bench [end]
# 885[start] a man and woman are sitting on the floor in front of luggage [end]
# 886[start] the statue of an accident involving women waiting for a shoes [end]
# 887[start] two girls are sitting at a table working on some sort of rubber and working [end]
# 888[start] a man running in the snow with a pole [end]
# 889[start] the street worker in red suits is jumping in the air [end]
# 890[start] a man sits on a trash truck [end]
# 891[start] a bearded man in a heavy coat sits at a cup down from a cup [end]
# 892[start] a man is using a hose using a pond as he walks on a ramp on a sunny day [end]
# 893[start] a man with a large hat in bushes [end]
# 894[start] a closeup of that looks on blue framed a lecture to home [end]
# 895[start] a man and a woman work on a bicycle tire while at a bicycle [end]
# 896[start] a little boy is showing his favorite necklace [end]
# 897[start] a man in a gray tshirt is working with a piece of fire in a routine at the oven [end]
# 898[start] a woman is front of trees and smiling [end]
# 899[start] someone wearing a asian costume is sitting and holding a sword [end]
# 900[start] a young football player prepares to kick the ball towards some player [end]
# 901[start] a guy is a bright green jacket and a white jacket and a sidewalk looking at a bicycle car [end]
# 902[start] young boy prepares to kick a soccer ball [end]
# 903[start] race runner jogs his team is running in a competition [end]
# 904[start] two men one wearing blue and one wearing a red boxing [end]
# 905[start] a group of friends are having a conversation and chatting with one another [end]
# 906[start] a man is holding a microphone in front of a man holding a guitar [end]
# 907[start] a girl on rollerblades is skating with other men [end]
# 908[start] a woman splashing on a store the ice [end]
# 909[start] two motorcyclist racing around a bend in this carnival is in the event [end]
# 910[start] a man standing alone on the sidewalk and rolling a hat [end]
# 911[start] a man walking with another man who is walking on winning a man [end]
# 912[start] several people are having a conversation in a soccer game [end]
# 913[start] two people one dressed in a native american in a shirt and the other wearing swim trunks run by an suv in a wooded area [end]
# 914[start] three men on horses in a race [end]
# 915[start] a darkskinned man with a white short white tshirt and a black outfit is floating on a concrete surface with palm trees and palm trees [end]
# 916[start] a man wearing a hoodie and jacket is sitting at a fountain that is looking down at a river in the city [end]
# 917[start] swimmers in a different races over the sun lined of an oil pot and a we are painting on the walls [end]
# 918[start] a young indian boy sits and to get the cap the audience [end]
# 919[start] a boy man in a hood throwing a object into a beautiful pool [end]
# 920[start] men in colorful costumes act at a performance [end]
# 921[start] two boxers girls are landing in a ring with a watched by a crowd [end]
# 922[start] children are playing a sport on a playground [end]
# 923[start] a performer singing and playing guitar in front of a microphone [end]
# 924[start] boys are competing in martial arts event [end]
# 925[start] a group of black shirts performing in an bright park digging game [end]
# 926[start] school girls in uniforms cheer on men in a parade with instruments be like hes playing the football [end]
# 927[start] a red white male shop making face [end]
# 928[start] a boy is jumping from a bed in a pool to take something [end]
# 929[start] a baby in a purple and standing boy is surrounded by toys [end]
# 930[start] people are having a conversation at a table at a game of jenga [end]
# 931[start] a man with a beard and an elderly woman is eating from a bowl [end]
# 932[start] a young man skateboarding on a concrete wall [end]
# 933[start] people riding a boat on a lake with stadium waves and clouds in the distance [end]
# 934[start] two men are in the practicing martial arts in the office [end]
# 935[start] a male band and female have which has just released a ski gear on the street [end]
# 936[start] a group of riders are riding the track in action doing construction [end]
# 937[start] a person dressed in winter clothes poses with a snowman bars a snowy as [end]
# 938[start] a man is performing in front of a crowd [end]
# 939[start] a man is in the yard throwing a football player to him from a is sitting on a bicycle [end]
# 940[start] a tattooed man in a suit holds a microphone on stage [end]
# 941[start] a little girl is playing with the sprinkler toy shops with three paper [end]
# 942[start] a man with a blue helmet is in his shirt that has cards [end]
# 943[start] lots of young adult intently staring at computers while a football discuss their computer [end]
# 944[start] a little boy in green is juggling in a parking lot [end]
# 945[start] a little girl in a polka dot dress spins on a woman in a black dress [end]
# 946[start] a man fixing the engine of the water out of a boat [end]
# 947[start] a tennis game being played in a stadium [end]
# 948[start] a child on a snowboard holds onto a rope [end]
# 949[start] playing golf with a two men with two men attempt to reach the ball [end]
# 950[start] young women and children in a village in the village a boy is ready to an audience [end]
# 951[start] a toddler in a green shirt is brushing his teeth and yellow and the other bride [end]
# 952[start] a man is in red running a atv over a rubber gloves [end]
# 953[start] a son and his parents get in a church [end]
# 954[start] three men are racing in a running competition over hurdles [end]
# 955[start] two men observe the other black drum are landing from cold wood [end]
# 956[start] a military man is looking at a homes airplane [end]
# 957[start] a group of college guys building a gathering at canoes from the day [end]
# 958[start] a man jumps rope in the street looking at him in the crowd [end]
# 959[start] a young boy and girl smiling together as the girl points to the peace [end]
# 960[start] two men from different teams chasing a football [end]
# 961[start] a bicyclist in a yellow shirt performs in midair performing [end]
# 962[start] two women one in purple sports bra are fighting each other in an arena [end]
# 963[start] two men on a bright motorcycles are heading in a rural area [end]
# 964[start] two men are inspecting another man playing a basketball at the skate [end]
# 965[start] a man in midswing and a helmet riding a white horse riding a horse jumps over a hurdle during a horse [end]
# 966[start] a group of men in costumes playing instruments [end]
# 967[start] a man and women walking down a set of tools for sale to sale [end]
# 968[start] a racing catamaran has closed in the water [end]
# 969[start] a group of worshipers hold flags and other people decorations [end]
# 970[start] a man is holding a glass in front of a net [end]
# 971[start] one man is playing a guitar on a stage with lights on the background [end]
# 972[start] four kids with play with empty guns [end]
# 973[start] a group of men are listening to their wife [end]
# 974[start] a yellow surface driving a large green tractor in a parade down a road [end]
# 975[start] three dogs play in the water [end]
# 976[start] a man playing a drum and a small boy on his guitar [end]
# 977[start] a group of girls playing a game on horses [end]
# 978[start] a man looks at a woman while is doing the out of a shooting range [end]
# 979[start] a full of the factory bike takes coconuts while the end are about to their own number them [end]
# 980[start] a team of players in white and yellow are participating in a sparse purchase [end]
# 981[start] a group of people in purple shirts and bright blue pants are walking in shallow water [end]
# 982[start] a man in a light blue shirt plays a trumpet [end]
# 983[start] a guy with his stomach tricks in a skate park on a bike [end]
# 984[start] mother and daughter wearing their dresses walk out of the wearing a bib and posing in an evening [end]
# 985[start] a little boy is drilling a hole into a piece of wood [end]
# 986[start] two female cyclists are racing together to a dirt track [end]
# 987[start] someone throws a frisbee as another kid watches to him and a little girl [end]
# 988[start] a student working with tools and man is holding a light [end]
# 989[start] two people eating meat on concrete bench and a third drinking out of a newspaper [end]
# 990[start] two cyclists are riding down the street around talking to each other [end]
# 991[start] a man is holding a man in a black shirt bowling with a black shirt down at the bowling alley [end]
# 992[start] two men in black clothing with a blue and red bowtie perform in front of people [end]
# 993[start] two men one black one white standing outside and playing guitar and one play microphone while singing into a microphones [end]
# 994[start] a teenage boy is laying down to his face off [end]
# 995[start] three people are running in a race on a track [end]
# 996[start] soccer players all before their races through the hydraulic hoses [end]
# 997[start] several men are praying while standing in front the table full of food [end]
# 998[start] two indian young in dance number matching clothing dance as children perform [end]
# 999[start] three children are standing by a tall blue wooden post [end]
# 1000[start] a group of people are running a field [end]
# 1001[start] women are on the beach walk a a boat with tropical boat [end]
# 1002[start] a boy is sitting in a rock looking at the valley from a river [end]
# 1003[start] a woman stands on a high rock cliff with her head on the river [end]
# 1004[start] a brunette girl is standing on a sidewalk looking at the street [end]
# 1005[start] a group of three friends are taking showers pool [end]
# 1006[start] two kayaks standing near a photograph site [end]
# 1007[start] person with blue jeans and a red hoodie walking in front of a brick wall on [end]
# 1008[start] an emergency exit map in a area [end]
# 1009[start] a chef riding a piece of stone looking up next to each [end]
# 1010[start] many police officers stand outside a bus [end]
# 1011[start] an older whitehaired lady is looking up her favorite while looking [end]
# 1012[start] two men stand in a fountain with water cones [end]
# 1013[start] two women in red outfits and a man walking out of a subway car [end]

# %% [markdown]
# The following steps repeated the same way as French encoder to train a encoder of Deutsch.

# %%
###############Deutsch
de_encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="de_encoder_inputs")
x = PositionalEmbedding(sequence_length, len_train_de, embed_dim)(de_encoder_inputs)
de_encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
de_encoder = keras.Model(de_encoder_inputs, de_encoder_outputs)

subtracted = keras.layers.Subtract(name="zero")([de_encoder_outputs, encoder_outputs])
zeroLayer = keras.Model([de_encoder_outputs, encoder_outputs], subtracted, name="zero")

def format_dataset(cs, de, fr, zero):
    auto_cs = auto_cs_vectorization(cs)
    input_cs = cs_vectorization(cs)
    input_de = de_vectorization(de)
    de = de_de_vectorization(de)
    return ({"encoder_inputs": input_cs, "de_encoder_inputs": input_de, "decoder_inputs": de[:, :-1], "autodecoder_inputs": auto_cs[:, :-1],}, {"de": de[:, 1:], "cs": auto_cs[:, 1:], "zero": zero})


def make_dataset(cs_texts, de_texts, fr_texts):
    cs_texts = list(cs_texts)
    de_texts = list(de_texts)
    fr_texts = list(fr_texts)
    zero = np.zeros((len(fr_texts), sequence_length, embed_dim))
    dataset = tf.data.Dataset.from_tensor_slices((cs_texts, de_texts, fr_texts, zero))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds_de = make_dataset(train_cs, train_de, train_fr)

# %%
for inputs, targets in train_ds_de.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["de_encoder_inputs"].shape: {inputs["de_encoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f'inputs["autodecoder_inputs"].shape: {inputs["autodecoder_inputs"].shape}')
    print(f"targets.shape: {targets['de'].shape}")
    print(f"targets.shape: {targets['cs'].shape}")
    print(f"targets.shape: {targets['zero'].shape}")

# %%
epochs = 100  # This should be at least 30 for convergence

import keras.backend as K

def custom_loss(y_true, y_pred):
 
    loss_square = K.square(y_pred - y_true + K.epsilon())

    loss_sqrt = K.sqrt(K.abs(y_pred - y_true) + K.epsilon())
    
    return loss_square + loss_sqrt

decoder_outputs = decoder([decoder_inputs, de_encoder_outputs])
autodecoder_outputs = autodecoder([autodecoder_inputs, de_encoder_outputs])

encoder.trainable = False
decoder.trainable = False
autodecoder.trainable = False

transformer_stage_1 = keras.Model(
    [encoder_inputs, de_encoder_inputs, decoder_inputs, autodecoder_inputs], [subtracted, decoder_outputs, autodecoder_outputs], name="transformer"
)

transformer_stage_1.summary()
transformer_stage_1.compile(
    "adam", loss=[custom_loss, "sparse_categorical_crossentropy", "sparse_categorical_crossentropy"], metrics=["accuracy"]
)
transformer_stage_1.fit(train_ds_de, epochs=epochs)#, validation_data=train_ds

# %%
epochs = 50  # This should be at least 30 for convergence

transformer_stage_1.summary()
opt = keras.optimizers.Adam(learning_rate=0.0001)
transformer_stage_1.compile(loss=[custom_loss, "sparse_categorical_crossentropy", "sparse_categorical_crossentropy"], metrics=["accuracy"], optimizer=opt)
transformer_stage_1.fit(train_ds_de, epochs=epochs)#, validation_data=train_ds

# %%
epochs = 50  # This should be at least 30 for convergence

transformer_stage_1.summary()
opt = keras.optimizers.Adam(learning_rate=0.00001)
transformer_stage_1.compile(loss=[custom_loss, "sparse_categorical_crossentropy", "sparse_categorical_crossentropy"], metrics=["accuracy"], optimizer=opt)
transformer_stage_1.fit(train_ds_de, epochs=epochs)#, validation_data=train_ds

# %%
###############French
def format_dataset(cs, de, fr, zero):
    auto_cs = auto_cs_vectorization(cs)
    input_cs = cs_vectorization(cs)
    input_de = de_vectorization(de)
    de = de_de_vectorization(de)
    return ({"encoder_inputs": input_cs, "de_encoder_inputs": input_de,}, {"zero": zero})


def make_dataset(cs_texts, de_texts, fr_texts):
    cs_texts = list(cs_texts)
    de_texts = list(de_texts)
    fr_texts = list(fr_texts)
    zero = np.zeros((len(fr_texts), sequence_length, embed_dim))
    dataset = tf.data.Dataset.from_tensor_slices((cs_texts, de_texts, fr_texts, zero))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds_de = make_dataset(train_cs, train_de, train_fr)

de_encoder.load_weights('/content/drive/My Drive/de_encoder_clip.h5')

epochs = 100

transformer_stage_1 = keras.Model(
    [encoder_inputs, de_encoder_inputs], [subtracted], name="transformer"
)

transformer_stage_1.summary()
opt = keras.optimizers.Adam(learning_rate=0.00001)
transformer_stage_1.compile(loss=[custom_loss], metrics=["accuracy"], optimizer=opt)
transformer_stage_1.fit(train_ds_de, epochs=epochs)#, validation_data=train_ds

# %%
en_vocab = en_vectorization.get_vocabulary()
en_index_lookup = dict(zip(range(len(en_vocab)), en_vocab))
max_decoded_sentence_length = sequence_length


decoder_outputs = en_decoder([en_decoder_inputs, de_encoder_outputs])
transformer = keras.Model(
    [de_encoder_inputs, en_decoder_inputs], [decoder_outputs], name="transformer"
)

def decode_sequence(input_sentence):
    tokenized_input_sentence = de_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = en_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = en_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence

alltext = []
for i in range(len(val_de)):
    #input_sentence = random.choice(train_fr)
    translated = decode_sequence(val_de[i])
    alltext.append(translated)
    print(str(i)+translated)
# Out:
# 0[start] a group of adults are finishing a dance floor place [end]
# 1[start] a man is sleeping in a green tank top of a book [end]
# 2[start] a young boy in sandals is sitting down on a bench [end]
# 3[start] two men are building gingerbread house on a cement car [end]
# 4[start] a man with a shirt is tossed in the air by a rubber bowl a green shirt [end]
# 5[start] a woman in a red coat is seen from a distance that has a down while an outdoor pole with spectators are being held by [end]
# 6[start] a brown dog runs over the white and white dog is running [end]
# 7[start] a young boy with a red white and yellow shirt is getting ready to cut down a ball [end]
# 8[start] a man is walking in an art gallery [end]
# 9[start] a smiling woman with a mural on a tank top of an ornate coffin [end]
# 10[start] a little girl walks by a large trampoline [end]
# 11[start] a person is driving a snowmobile the air [end]
# 12[start] three little kids standing around a wheel barrel [end]
# 13[start] a woman sits at an outdoor fair on a lounge chair [end]
# 14[start] a woman plays a guitar with a mural [end]
# 15[start] three people two men are riding bicycles through a grassy field [end]
# 16[start] a child sitting in the middle of a seat on his bed [end]
# 17[start] a group of people are standing in front of a toll store [end]
# 18[start] a young woman is putting onto a toy train [end]
# 19[start] three girls are in white and one in a dance floor with a group of each other for tips [end]
# 20[start] a man in a black shirt jumping into a group of other people in a crowded game [end]
# 21[start] woman and knee pads passing a clear leader walking down into the tropical [end]
# 22[start] a man wearing a red and a hat is painting with a girls [end]
# 23[start] an asian girl in a hat and yellow dress shirt engaged in a shot [end]
# 24[start] construction workers are standing on a piece of machinery [end]
# 25[start] two dogs play with a tall green toy in the grass [end]
# 26[start] a baby in a blue and yellow dog toy [end]
# 27[start] three men are walking on a street of a city [end]
# 28[start] a person gets bare feet taken from a large body of water [end]
# 29[start] a tractor drives down a steep vehicle with a college campus [end]
# 30[start] a young girl is walking in the air while wearing a red sled [end]
# 31[start] a person is crossing the street and putting up onto the bottom of a gallery [end]
# 32[start] child playing on a playground piece of art in an iron [end]
# 33[start] a person in a red shirt on a nail gun in a field [end]
# 34[start] a group of people gathering at a circle of blouse looking men [end]
# 35[start] a woman sits at a table with a meal together [end]
# 36[start] people walk on a sidewalk in front of a body of water [end]
# 37[start] a man in a blue shirt is reading a newspaper while waiting for the subway [end]
# 38[start] a large brown dog is holding his teeth at a painting [end]
# 39[start] a blond boy in a blue shirt stands at a table with a building under a bike [end]
# 40[start] a white male holding a cane covering over a large window [end]
# 41[start] a person gets wet bowl of a city street [end]
# 42[start] a band is performing a concert at a restaurant in front of some sort of art gallery [end]
# 43[start] an older man walks by a brown dog while a dog watches [end]
# 44[start] a man driving a full of the fair are very strange [end]
# 45[start] young adults in a row of red and black outfits are leading an motorcycles owned by onlookers [end]
# 46[start] a little boy is throwing a ball at the top of a small child [end]
# 47[start] two women stand outside wearing matching clothing and sunglasses [end]
# 48[start] a military man stands at a conference that says luggage [end]
# 49[start] a dog walks with a chunk of dirt and through a wooded area [end]
# 50[start] three little boys are squatting to each other [end]
# 51[start] two men are kayaking in some water [end]
# 52[start] two girls walking down a street [end]
# 53[start] a group of kids are sitting in a back in a warehouse store [end]
# 54[start] emergency personnel and grabbing a star of their bikes across the water [end]
# 55[start] a girl sits outside a building rings up the street and a both with his arm it are smiling as they are wearing a ahead of the same hall [end]
# 56[start] a man is eating a meal on a restaurant [end]
# 57[start] a man wearing a suit mask while holding a cake [end]
# 58[start] a man in a black wetsuit rides a wave [end]
# 59[start] a woman with a pink outfit is sitting on a bench [end]
# 60[start] three women are sitting down and smiling [end]
# 61[start] a red race car is cloud of dust and he is smoke away from it [end]
# 62[start] a man in a dark suit climbs at a dock [end]
# 63[start] two construction workers toil in a trench coat [end]
# 64[start] a woman in a beige costume is walking a man who is outside in a parade [end]
# 65[start] a woman in a blue shirt and jeans is juggling a little yellow tennis ball [end]
# 66[start] a man wearing a load of his head down [end]
# 67[start] baby looking at sort of carnival toy sharks [end]
# 68[start] a woman who is in a bathing suit have gathered on a cloudy day [end]
# 69[start] two little boys are playing with each other with backpacks on it [end]
# 70[start] many people wearing green groups of them are on a sideways [end]
# 71[start] two people are climbing a rope and that are on a rock [end]
# 72[start] a man and a woman are sky looking at a beach [end]
# 73[start] a child does a back flip while preparing to throw in a skateboard [end]
# 74[start] children in mud relaxing atop a rainy day [end]
# 75[start] two people are smiling while wearing a blue and orange shirt is being interviewed with the getting ready to the same time out of the same time of the ground while sitting [end]
# 76[start] two men practicing in a school gym [end]
# 77[start] a woman in a black dress carrying a container of yarn bag is walking and barriers [end]
# 78[start] a police officer holds a stop sign at the bottom of the aisle [end]
# 79[start] man standing on the pier next to a rock person climbing [end]
# 80[start] a group of performers feather people festive [end]
# 81[start] a woman and a child are sitting down the street on a cold while the other men pass by [end]
# 82[start] a fireman is putting out of a burning fire at a flight [end]
# 83[start] a person in a purple shirt draws a cut a ribbon in the middle of a car is doing [end]
# 84[start] little girl lying on the floor to her smiling while she cleans her same time [end]
# 85[start] a young woman and man dressed in black dress pants maneuvering some or him from some sort of barrier tape [end]
# 86[start] a woman is walking through the snowy area with a tire rings [end]
# 87[start] the man is listening to the hard hat with the same time as he remodels his space [end]
# 88[start] the brown dog is carrying a black and white collar [end]
# 89[start] a white and brown dog is running through a some sort of snow covered with snow [end]
# 90[start] a child does the same time while taking a picture with his hand [end]
# 91[start] an older white man trying to get a fourth machine [end]
# 92[start] little kid and a woman are standing in front of a sheep on a dirt tree [end]
# 93[start] a man in a burgundy father is cooking on a counter at a street [end]
# 94[start] a man in a white outfit is use a fire [end]
# 95[start] a young woman is singing into a microphone as a man stands on a pole [end]
# 96[start] two children are digging up dirt [end]
# 97[start] many instruments as if they are walking around in a are performing and down [end]
# 98[start] some men are sitting in a boat at an outdoor pole that is interacting with kitchenaid [end]
# 99[start] a young man is wearing a black and yellow shirt makes a conversation [end]
# 100[start] an older man is putting up a stunt while he snowboards down a event [end]
# 101[start] men dressed in yellow and black vest is sitting on a piece of gym [end]
# 102[start] several people are in the air near a street with greenery [end]
# 103[start] a brown dog chases a laugh [end]
# 104[start] a tourist is posing for a photo shoot with a large body of water [end]
# 105[start] a group of kids playing with a green bay [end]
# 106[start] a woman smiles as she stands at a woman who is smiling [end]
# 107[start] two women are standing and talking to each other in front of the window [end]
# 108[start] two brunette women are talking to each other in front of an audience [end]
# 109[start] a person in a hat and looks back at a sporting event [end]
# 110[start] two people walking across a street [end]
# 111[start] a old man is holding a ball in smaller dog while his back [end]
# 112[start] three children watching wearing a group that are playing an guitar [end]
# 113[start] a young boy is doing a wheelie on a diving board [end]
# 114[start] a blue and white male biker riding on the shore [end]
# 115[start] the woman with a black hat is doing a routine at the same time [end]
# 116[start] a man is sitting on the floor playing the guitar [end]
# 117[start] a dog walks through a grassy field while a flock of it [end]
# 118[start] a young asian woman jumps a trick on a busy city street [end]
# 119[start] a female gymnast is performing on a stage [end]
# 120[start] four people are using jackhammers by the large group of people while sitting in front of the same time [end]
# 121[start] a man is organizing an activity on a grill on fire [end]
# 122[start] a man with a red cap on a fallen tree that has a bicycle [end]
# 123[start] a little boy in a yellow shirt is hanging out of the frame around other goes [end]
# 124[start] a young child is eating a meal with one glass case [end]
# 125[start] a man and two women walking down the street [end]
# 126[start] two poodles is running through the snow [end]
# 127[start] a young girl in a pink outfit is riding a horse that is on a bucking bronco [end]
# 128[start] man in white shirt and cap on a lake [end]
# 129[start] the action shot of a tree a pastor [end]
# 130[start] people having fun contraption while having fun photo taken [end]
# 131[start] some people are swimming in a body of water [end]
# 132[start] women in tennis uniforms are playing at a wedding [end]
# 133[start] a man and woman are sitting at a table and smiling [end]
# 134[start] a mother and two young children are posing with a lens cap on a metallic [end]
# 135[start] a golden retriever rider grass a dog toy in green grass [end]
# 136[start] four men are standing in a yellow car [end]
# 137[start] a group of men in red and talking to each other wearing hats [end]
# 138[start] young boy in blue and white wearing is kneeling on the grass [end]
# 139[start] a little girl is sniffing a set of south carolina with an umbrella [end]
# 140[start] a yellow dog is jumping up on the beach [end]
# 141[start] a man wearing a red shirt is standing with two groups of a building [end]
# 142[start] man staring at the woman with a woman at the desk [end]
# 143[start] a band plays on a cloudy day [end]
# 144[start] two women are smiling at a set of young women in a concert [end]
# 145[start] a woman in a pink shirt is pointing to a man who is in a purple shirt made of rubber [end]
# 146[start] a child sitting on a rock [end]
# 147[start] a man is sitting at a computer screen with a group of the instruments looking at a diner [end]
# 148[start] a police officer in a rundown looking area [end]
# 149[start] a man in a military uniform walks down the street while on a rainy day [end]
# 150[start] a black and white dog leaps in the water [end]
# 151[start] a band plays music in a band playing on a stage [end]
# 152[start] three people are playing musical instruments and one another one is wearing black [end]
# 153[start] a woman plays the keyboard while standing at a microphone [end]
# 154[start] a little boy is jumping into the water fountain [end]
# 155[start] a woman is reading a book while sitting on the sidewalk and being contested by a st woman both face [end]
# 156[start] construction workers work to repair a new invention [end]
# 157[start] a man is shaving off the beach while looking at the ocean [end]
# 158[start] a blond woman in a blue shirt ls drinking a glass [end]
# 159[start] two men are conversing with the camera while riding on a bicycle [end]
# 160[start] a young man with blondhair is talking on a cellphone while wearing a group of each other [end]
# 161[start] a male child in a coat is pushing a bicycle laden with a wooden box [end]
# 162[start] a fluffy dog kissing in the city [end]
# 163[start] a group of band members are performing at a crowd of people in front of the pueblo [end]
# 164[start] three dogs are playing around in the grass [end]
# 165[start] a man and woman are talking while standing together as she walks down [end]
# 166[start] a dog is jumping at a basketball game [end]
# 167[start] an older woman in a sweater is cooking on a newspaper [end]
# 168[start] woman sitting in the middle of a few the match is line by a man [end]
# 169[start] a woman is carrying a black and white roller derby girl is being splashed by the same time [end]
# 170[start] a child stands next to a child who is standing in the middle of a is holding a balloon with her on [end]
# 171[start] guy with long hair on holding a bicycle wearing a green cap over some sort of soda [end]
# 172[start] a man is shaking a bubble bath along the walkway [end]
# 173[start] a group of people are in a boat in a body of water [end]
# 174[start] a man in a yellow shirt standing at a sidewalk with a red shirt is going his [end]
# 175[start] a woman in a blue shirt and jeans is tossing a shower in the blue shirt and yellow bag [end]
# 176[start] a woman with a ponytail rides a bucket putting together on it [end]
# 177[start] a person is catching an open air on the swimming pool [end]
# 178[start] men in blue and white uniforms are sitting down [end]
# 179[start] a chelsea soccer player takes place on a cutting board [end]
# 180[start] a man is getting his ball at a sporting event [end]
# 181[start] a military man at a lively table [end]
# 182[start] two girls are sitting along a street corner while looking at sunset [end]
# 183[start] a man standing up the top of a telephone line as he plays his guitar [end]
# 184[start] this football players wearing red and white is flying [end]
# 185[start] a boy in black wearing a red shirt is on the beach [end]
# 186[start] she is posing for a photo opportunity [end]
# 187[start] a man in a green shirt is being interviewed by a line while looking at the same time [end]
# 188[start] five male instruments performing a concert [end]
# 189[start] three women are sitting on a stool and one on the floor and talking to each other [end]
# 190[start] a man and a girl are sitting down with a mess on one painting on it [end]
# 191[start] a man with sunglasses hugs his gun on makes a good [end]
# 192[start] a dog runs through the grass [end]
# 193[start] the girl wearing a red hat is about to hit the ball with a group of grass [end]
# 194[start] two men are wrestling and are in a beautiful day [end]
# 195[start] a girl in a white shirt and blue shorts is trying to hit the ball [end]
# 196[start] a man is working with his hand out [end]
# 197[start] a brown dog is running across a stick in the grass [end]
# 198[start] a person rowing in the boat [end]
# 199[start] a man wearing a striped shirt is sitting in front of a large group of peoples marker [end]
# 200[start] a man is taking a picture of a crowd of girls wearing black and white dress [end]
# 201[start] two men in front of a farm equipment [end]
# 202[start] man and young boy playing with sunset [end]
# 203[start] a photographer is parachuting with his water in the background [end]
# 204[start] this is a man is wearing a hat and hat that is an unidentified down [end]
# 205[start] a woman is getting her picture taken out of a shot in the dish of sorts [end]
# 206[start] a young child playing with a toy room [end]
# 207[start] a crowd of people in the street with a lot of green grass [end]
# 208[start] a woman walks through the park with her walk [end]
# 209[start] a woman with a pretty blue shirt and walking down with a bicycle kissing while walking down a sidewalk in front of a small girl is making a sign [end]
# 210[start] many children are standing up a fountain that is high in the air [end]
# 211[start] a cowboy is attempting to complete a race while riding a horse drawn carriage [end]
# 212[start] a bride and groom make their turn in a match [end]
# 213[start] two men are organizing an activity outside of a container [end]
# 214[start] man working on the railroad is resting the side of the notebook [end]
# 215[start] a couple of men in a country setting up a tuba with a hood making opening [end]
# 216[start] a band plays on the sidewalk [end]
# 217[start] men in orange uniforms are shown in a piece of water as they have just around [end]
# 218[start] young adults in back walking on a grass field [end]
# 219[start] the large brown dog is running through water looking at a park [end]
# 220[start] a man and woman are crossing a street in a marketplace [end]
# 221[start] a man is doing work on a project involving a ball in the middle of a sort of region by a bike [end]
# 222[start] two children in blue uniforms are playing in the mud [end]
# 223[start] several people are picking up a snowball in the edge of an arena [end]
# 224[start] a woman and a young boy is getting on a picture of a small child [end]
# 225[start] a group of people stand about to go in a festival [end]
# 226[start] a little girl is swimming in a pool [end]
# 227[start] a boy in a orange shirt smiles as he looks on a young boy in his blue jean [end]
# 228[start] a young girl is standing outside in water fountain [end]
# 229[start] little girl smiling is holding a chicken [end]
# 230[start] four people are trying to get a karate in a public place [end]
# 231[start] a very happy dog is leaping through the water [end]
# 232[start] a dog is running with a ball in the grass field of grass [end]
# 233[start] a group of people waiting for a cause to the same time [end]
# 234[start] a child in a red hoodie is hanging out of a fence [end]
# 235[start] the first man gets out of a shot near a water sized water [end]
# 236[start] a young boy in a crowd of people smile at the camera [end]
# 237[start] two children wearing straw hats are standing outside of a hole [end]
# 238[start] a man pulls on his neck to what appears to be doing work [end]
# 239[start] an old man is walking along with a pole that has a conversation [end]
# 240[start] a young woman and man are having a conversation while another looks at a line [end]
# 241[start] a small boy in the air is catching a butterfly [end]
# 242[start] a young child swinging a red ball [end]
# 243[start] the man is doing a stunt on a bicycle shop window [end]
# 244[start] cars are looking at each other with a group of young child [end]
# 245[start] a woman in a blue shirt is playing a game of instrument [end]
# 246[start] the car is parked at the top of the statue of a troll [end]
# 247[start] a man sits in a body of water with a water rock on [end]
# 248[start] two hikers are taking a picture of a book about to take a bite of her [end]
# 249[start] four people are walking down a city street with a few people riding in the back [end]
# 250[start] four people are in a river in a rural area [end]
# 251[start] a young boy does a stunt on his skateboard [end]
# 252[start] a man at a beach fighting batman match [end]
# 253[start] the large brown dog is chasing the brown and white dog [end]
# 254[start] white in black men hand up and yellow work [end]
# 255[start] a woman throws a dog up to a frisbee while an audience watches [end]
# 256[start] a black dog is standing on the grass holding a white polka dot outfit [end]
# 257[start] a boat with a large number of instruments and wearing a group [end]
# 258[start] a group of racers are rounding a turn in a course [end]
# 259[start] three people sit outside of a table with their instruments [end]
# 260[start] a white woman and black male walking down a street [end]
# 261[start] a man in a white shirt is shown on a tree that has multiple fishing [end]
# 262[start] a flock of seagulls is taking off a bar [end]
# 263[start] a man with a face paint is dressed up with a group of singing [end]
# 264[start] two young boys are playing with backpacks [end]
# 265[start] two men are waiting in front of a car that sells bicycles [end]
# 266[start] a young boy is sitting on a bench [end]
# 267[start] a black man is receiving a haircut by a little boy in a barber shop [end]
# 268[start] person with a red backpack walking down the stairs [end]
# 269[start] the girls is using training the police officer to the police officer a beautiful street [end]
# 270[start] a large group of people are gathering with many tents in the large up [end]
# 271[start] three women with dark hair and goggles at a convention center a talk while sitting on the other [end]
# 272[start] a man in a white shirt is doing some sort of material [end]
# 273[start] a person with hair and a blue shirt is looking at a beach [end]
# 274[start] man staring down at the sidewalk with a woman [end]
# 275[start] a man in a black shirt and tan pants is carrying a telescope [end]
# 276[start] a man is shaking a friend with a girl [end]
# 277[start] a child is walking by another kid [end]
# 278[start] this is a young girl wearing a red and white dress leaps over the stone archway [end]
# 279[start] little girl in a frilly pink bathrobe wrapped in a gym [end]
# 280[start] the closeup of a woman with a redhair [end]
# 281[start] a soccer player in a green jersey is running by the soccer ball [end]
# 282[start] a girl doing a back flip [end]
# 283[start] several children hold up as they are sitting in a circle at a classroom [end]
# 284[start] row of kitchen trees staring at an older persons bike [end]
# 285[start] a male entertainer on the warehouse of pipe to catch a man [end]
# 286[start] a man in a gray shirt is getting ready to cut [end]
# 287[start] a black dog is jumping over water that is in the air with a stick [end]
# 288[start] two black dogs running down a path lined by [end]
# 289[start] four people are walking down with metal near a pile of instruments [end]
# 290[start] people and both in red jackets are going up the canyon [end]
# 291[start] four dogs are playing frisbee in the grass [end]
# 292[start] a man wearing a white shirt is shown in a microphone [end]
# 293[start] a group of people are performing a play string instrument at a theater [end]
# 294[start] a swimmer comes in an indoor uniform [end]
# 295[start] woman in a white shirt and shoes rests on a lawn while next to a blazer sits on his head [end]
# 296[start] a man is doing a picture of a child standing on a hug [end]
# 297[start] girls wearing white tshirt performing dance in a room [end]
# 298[start] boys and girls fight on a body of water in a field [end]
# 299[start] a child in a orange shirt is jumping with a model airplane while others look on [end]
# 300[start] young boy does a trick on his skateboard [end]
# 301[start] a man is reaching out to his way through equipment on a attempting to work [end]
# 302[start] a young child sitting at a table eating a meal [end]
# 303[start] four children are using a water bottle and a large wave while a man observes them [end]
# 304[start] a man with a hairy holding a child looks out at a craft [end]
# 305[start] in an urban area one couple pride gathered with a variety of those in the streets as he fills up [end]
# 306[start] a dog is on a grassy field looks at the camera [end]
# 307[start] a woman and a little girl are having a conversation in a group of children [end]
# 308[start] four guys sitting on a bench talking to each other [end]
# 309[start] the small brown dog is in the middle of a french lot of young and white dog [end]
# 310[start] two men in front of a store window while a male looks at a movie theater [end]
# 311[start] some men are trying to sell at a desk in a grocery store [end]
# 312[start] two women are looking at a camera in a street [end]
# 313[start] a blond woman with a man wearing a blue and white shirt is looking up at the camera [end]
# 314[start] the white and brown dog is running through the grass [end]
# 315[start] a teenage boy gives part his skill with an art that looks at a computer screen [end]
# 316[start] two little girls walk across a mountain [end]
# 317[start] a bride talks on her cellphone while getting her coach looks at a flower shop [end]
# 318[start] the woman is pushing a light colored shirt while riding a clay road [end]
# 319[start] two women are walking while wearing an outdoor poles [end]
# 320[start] four women are having a good time while wearing a blue and black shirt [end]
# 321[start] these old women are relaxing in the daylight and covering its foot in front of an newspapers to a canal [end]
# 322[start] girls wearing black pants is playing pool [end]
# 323[start] a man with glasses and a little girl wearing a toy train goggles [end]
# 324[start] three children in white and blue shorts are on the ground with grass [end]
# 325[start] a woman is swinging her and the game of her in a opportunity [end]
# 326[start] a person is carrying many bags of their bikes [end]
# 327[start] a child on a blue and yellow set of which has a large blanket on top of a stature [end]
# 328[start] a boy stands on the street barriers with a monoboard being kite behind a car [end]
# 329[start] this child is in a balloon fight over some kind of contraption [end]
# 330[start] a man is working on the same time down with some water [end]
# 331[start] children are moving the window of a storage building with green stalks [end]
# 332[start] a man dressed in black and red hat is sitting on a tree [end]
# 333[start] a woman and two children wearing stilts walking by a girls hand [end]
# 334[start] some men are walking on a city street [end]
# 335[start] guy doing a stunt on a park [end]
# 336[start] a man in a bright colored jacket and yellow clothing stands on a road [end]
# 337[start] a woman in a yellow shirt and sunglasses is walking on the sidewalk [end]
# 338[start] two women looking at many clothes are getting air balloons [end]
# 339[start] two large dogs are jumping up at a grassy field [end]
# 340[start] people are busy eating while wearing summer clothes and putting their certificates [end]
# 341[start] a group of people are gathered at a restaurant [end]
# 342[start] a woman in a black shirt appears to be setting up the dance [end]
# 343[start] a room full of people and a girl with tall couple dressed in black boots are walking by falling [end]
# 344[start] a man and woman are posing on a stage [end]
# 345[start] two dogs playing with each other in the snow [end]
# 346[start] a small dog leaps on a road [end]
# 347[start] a man in a black shirt is playing a bass guitar player in a black and white shirt does [end]
# 348[start] a boy and a man and a man with a beard is gathering [end]
# 349[start] a girl with a white shirt and black pants is playing with a red ball [end]
# 350[start] two men standing on the street with graffiti covered doors [end]
# 351[start] a boy in a blue shirt and shorts is holding a snow covered hill [end]
# 352[start] a person is doing a back flip while near the ocean [end]
# 353[start] two men are sitting on the side of a piece of lace as the road wearing focus helmet and taking a crowd [end]
# 354[start] a dog runs through a grassy field [end]
# 355[start] a high jumper is in front of a group of people smiling [end]
# 356[start] a large brown and white dog is laying on a grass field of them [end]
# 357[start] two young ladies are having a good time while rock while enjoying the picture [end]
# 358[start] a mother and her son happily riding the mound [end]
# 359[start] a man in a black shirt cooking in a messy kitchen at the grocery store [end]
# 360[start] a woman in a white outfit is playing with black guitar [end]
# 361[start] a snowboarder flies off of a jump into the air [end]
# 362[start] several people are standing around in a room [end]
# 363[start] a man in a hat is playing a game of instruments at a zombie on a stone archway [end]
# 364[start] little guy taking a nap by the side of a wooden structure [end]
# 365[start] a woman in a white shirt and black pants is playing a trick with some people watching [end]
# 366[start] an older man is putting up a mixer on some sort of him [end]
# 367[start] two men dressed in red robes are bringing [end]
# 368[start] a young child is riding a bucking horse through a mountain [end]
# 369[start] a child wearing a hat is running through the water in a pile of seaweed [end]
# 370[start] a child sitting in a small motorbike jacket in the hand of mountain [end]
# 371[start] two old men wearing hats and hat on a railroad tracks [end]
# 372[start] two boys in a classroom are making funny faces [end]
# 373[start] a woman dressed in black and white is kneeling down with a long forest in the background [end]
# 374[start] two men are applying mascara to her left [end]
# 375[start] a woman carrying a grocery store is being interviewed by a bag standing strapped into a grocery store [end]
# 376[start] a bicycle rider doing a trick off a jump [end]
# 377[start] a young man in a green shirt is reading a newspaper [end]
# 378[start] a man in a green jacket is smiling [end]
# 379[start] a man climbs a rock wall with his on it [end]
# 380[start] a young man is riding a bike through a wooded area [end]
# 381[start] two brown dogs are jumping up to each other in the front of an outback [end]
# 382[start] person in a long green coat walking in front of a building [end]
# 383[start] they are all walks over a new cloth wrapped in a lot of cloth [end]
# 384[start] two men are making funny hands while holding the air hold as they jump [end]
# 385[start] a man with glasses is inside the air holding a rubber while standing in front of a body of water [end]
# 386[start] a child wearing a green shirt holds a red ball with a leg [end]
# 387[start] a man with a hand on his arm in a warehouse store [end]
# 388[start] a band members are using a light colored mask [end]
# 389[start] a group of young asian men walk along a street in a marathon [end]
# 390[start] a man pulls on a bicycle [end]
# 391[start] three large dogs are playing around the sand in the woods [end]
# 392[start] a bird flies through the water [end]
# 393[start] a group of people are sitting around a brick store [end]
# 394[start] a yellow car speeds through a race through the grass [end]
# 395[start] a group of kids are jumping and having a conversation on a light of young kids [end]
# 396[start] group of adults sitting around a table eating [end]
# 397[start] a woman in a green shirt is reading the newspaper to a man [end]
# 398[start] young people together with a sword [end]
# 399[start] in an orange jersey is holding on the football field [end]
# 400[start] a woman and two guys looking at a large straight ahead [end]
# 401[start] a group of people walk through a race [end]
# 402[start] two women are standing in the grass with their mouths [end]
# 403[start] people are standing together at a grand canyon in discussion on his portable toilets [end]
# 404[start] a young male looks at the camera in the middle of a street [end]
# 405[start] two little girls dressed in pink shirts are playing items in the front of the store [end]
# 406[start] a woman and a child ride her skateboard in the front of her [end]
# 407[start] a man with a lot of machinery in his chairs and the same time [end]
# 408[start] the street is lined up in the air [end]
# 409[start] two men in a white jersey and the other one is wearing a beret and using his shoes sitting along smiling [end]
# 410[start] a small brown dog runs through the grass [end]
# 411[start] a view of a city worker is serving looking at a fountain [end]
# 412[start] a snowboarder performs a stunt [end]
# 413[start] asian woman in blue and white clothes is cleaning a hug [end]
# 414[start] a woman in a blue shirt is riding a bike across a [end]
# 415[start] a woman in white is doing gymnastics while her ball [end]
# 416[start] a young woman plays a tripod in an arcade [end]
# 417[start] a bride and groom make their turn on a stage while two are doing work [end]
# 418[start] a woman holds a black and white dog [end]
# 419[start] a boy in a red shirt is playing a game of soccer [end]
# 420[start] a young boy is getting his picture taken at the selections from the cooking in the routine [end]
# 421[start] three older women are in a classic european style dragon standing in the middle of a country [end]
# 422[start] a fluffy dog jumping up a jump while holding a snow [end]
# 423[start] a band member is shown in a blue and white rodeo [end]
# 424[start] children playing in a red ball pit cooking in front of an all [end]
# 425[start] a dog is jumping over a ball with a stick in his mouth [end]
# 426[start] a group of people in blue uniforms are in a crowd of onlookers [end]
# 427[start] the tennis player is wearing a green and blue shirt and white headband [end]
# 428[start] two little girls in blue dresses are swinging [end]
# 429[start] a little girl in a toy room with tattoos on his skateboard [end]
# 430[start] two people are riding on the ground by the green and white swimming [end]
# 431[start] a group of guys and dancing with black flags in an outdoor rink [end]
# 432[start] a cyclist is performing a jump on a snowy mountain [end]
# 433[start] several people are walking in a city with a white tent line [end]
# 434[start] woman standing at a brick wall taking pictures [end]
# 435[start] a woman in a white shirt and denim wearing a white dress with a pole that is smiling [end]
# 436[start] a person is riding a motorcycle on her head [end]
# 437[start] a young girl wearing a black and white dress shirt holds a pair of redhair and it at the same time [end]
# 438[start] two dogs run each other in the water flow out [end]
# 439[start] a young boy with a balloon and a red shirt is playing with a guitar [end]
# 440[start] a teenage boy does tricks with his skateboard [end]
# 441[start] an old man wearing a black jacket and hat is looking at the camera [end]
# 442[start] the man in the blue shirt is on the middle of the east asian [end]
# 443[start] a woman in a large tank top is wearing a spoon to serve a ball [end]
# 444[start] little girl wearing a helmet riding on the course are soldier [end]
# 445[start] a black dog jumping over a hurdle [end]
# 446[start] a boy wearing blue and white jersey is about to throw a ball [end]
# 447[start] the band is taking pictures of a shot of a volleyball team [end]
# 448[start] guy takes a nap by a black ball [end]
# 449[start] a boy wearing a red and yellow tank top of water in a park [end]
# 450[start] little brown and white dog is running on the sidewalk [end]
# 451[start] two children are using spray while standing on a wall of ice cream with a man [end]
# 452[start] the children next to be a man who is shown [end]
# 453[start] a black dog is playing with a white and red ball in a field of grass [end]
# 454[start] several people are enjoying some sort of tabletop snack with a few talking [end]
# 455[start] a white dog with a stick playing in the water [end]
# 456[start] a photographer is being pulled by a little girl a bicycle eating a sport [end]
# 457[start] a young girl in a plaid shirt plays in a picture with a blue ball [end]
# 458[start] a man is pushing a toy baskets of teammates [end]
# 459[start] a group of young adults pose for a picture with a bunch of sand dune [end]
# 460[start] the woman is holding a violin player [end]
# 461[start] construction workers pass the famous a very busy outdoor station [end]
# 462[start] a man wearing a gray shirt performs a stunt over his skateboard [end]
# 463[start] three men are walking in front of a tent city with workers on it [end]
# 464[start] a young girl stands in a grassy field [end]
# 465[start] a young boy dressed in blue and white clothing are dueling [end]
# 466[start] a man and a woman play a game of soccer [end]
# 467[start] a little girl in a dress and sandals is running through the grass [end]
# 468[start] a woman in a purple shirt and a man in a white shirt who is sitting on a sunny day [end]
# 469[start] people dancing and wear stands on the same time [end]
# 470[start] a man looks down while sitting at a pile of seaweed [end]
# 471[start] man in white shirt and jeans playing soccer [end]
# 472[start] a large group of people are performing a photo of themselves at a party [end]
# 473[start] the car is forming the top of a dirt trail in the sunlight coming down [end]
# 474[start] a group of people at a group of people talking [end]
# 475[start] a man in a beard rides a motorcycle using a wheelie to his head [end]
# 476[start] a young boy is getting a barbecue by an indoor gym [end]
# 477[start] a bike rider is riding his bike along a rocky hill with fog [end]
# 478[start] a man with his hair trying to make a turn through the water [end]
# 479[start] a young boy and a man standing on a railroad crossing the camera [end]
# 480[start] a little girl smiling her arm in the air to take a picture [end]
# 481[start] a man in blue and white shirt is riding a bicycle on a dirt road [end]
# 482[start] a person is flying through a mound of hay which has fallen leaves in the air [end]
# 483[start] a person stands in the middle of a younger woman is eating a steak [end]
# 484[start] two bicyclists racing along a road on a cold street during the day [end]
# 485[start] a group of people are performing a dance move that has [end]
# 486[start] two people are playing golf with a house in a gym [end]
# 487[start] there are many people at a cafe on a street corner who is all over the other one is painted with a framed restaurant [end]
# 488[start] a young boy is catching a toy boy who is being tackled [end]
# 489[start] a woman gives a bath from a glass bridge while a woman watches [end]
# 490[start] a girl is wearing a white sweater and riding a toy zone [end]
# 491[start] a woman is carrying a friend walks for a concert with an orange shirt [end]
# 492[start] a group of hikers take a nice fencing team is on a piece of stairs [end]
# 493[start] a man in a blue shirt with a bike helmet is being held up by a person on a sunny day [end]
# 494[start] a young child plays in a sprinkler [end]
# 495[start] four children are playing on the grass with their instruments [end]
# 496[start] a man is holding a toddler wearing to take a picture of a large screen [end]
# 497[start] woman with two men holding their heads facing each other [end]
# 498[start] the men are fighting for the match [end]
# 499[start] two girls are cake and one a blue team on their faces [end]
# 500[start] a woman pulls a child along with a helmet [end]
# 501[start] a crowd of people at night and a large metal person dressed in the middle of the action [end]
# 502[start] a young boy in a green outfit is playing with two of water balls [end]
# 503[start] a little girl stands on a stool while sitting on a couch with her arms and smiles [end]
# 504[start] a man is singing into a microphone while holding a sandwich [end]
# 505[start] man with a tshirt on his face covered in brush [end]
# 506[start] a man in a green and white shirt swims on road [end]
# 507[start] a man is paddling a yellow object while a little man is on a bicycle pool with a snowy hill [end]
# 508[start] a man is taking a nap in a piece of metal of machinery [end]
# 509[start] a large black dog is running through the grass on a fence [end]
# 510[start] a motocross rider is being pulled by a race while racing across the tow pole [end]
# 511[start] there are two women walking by a man riding a bicycle down the street [end]
# 512[start] the black dog is jumping over the water in a grassy area [end]
# 513[start] a man in a black jacket and black hat is playing a saxophone [end]
# 514[start] a male riding a bike rider is on a bench [end]
# 515[start] an indian man is sitting at a table with some sort of restaurant [end]
# 516[start] three men in matching clothing are holding cameras [end]
# 517[start] little tan clothes at a brochure in costume on a back [end]
# 518[start] man riding his bike on the floor of a staircase [end]
# 519[start] a man in a bucket with a little girl on his head [end]
# 520[start] people walk down a busy city street with a corner [end]
# 521[start] a large dog is jumping a fountain in a metropolitan area with a cloudy day [end]
# 522[start] a man with an orange shirt is holding up a rope [end]
# 523[start] two men are workers at a bike with a few hanging from a few the same time [end]
# 524[start] a man stands on a scaffold and smokes a accordion with a light [end]
# 525[start] a restaurant worker is sitting off a bicycle reading from a newspaper at a food market [end]
# 526[start] two people wearing white tshirts and carrying bags are walking down the beach [end]
# 527[start] the little girl in the green top is crawling through a rock [end]
# 528[start] a artist is outside drawing in a dining room [end]
# 529[start] two asian children and a girl are standing next to a man who is smiling [end]
# 530[start] people in a line of a dancers preparing to run [end]
# 531[start] two men are dressed in red and white uniforms is on a sports field while wearing soccer uniforms and yellow walking [end]
# 532[start] a woman with a yellow hat is holding a plastic bag branch [end]
# 533[start] a black dog swims in a shallow water [end]
# 534[start] three men are riding wearing a red and yellow longsleeve blue kayaks [end]
# 535[start] wearing a beret and brooms at a back wearing a black vehicle [end]
# 536[start] a man in a blue shirt is helping a model airplane [end]
# 537[start] a man in a multicolored hat is being interviewed a objects down a bowl bottle and a lot of him is walking up and a newspaper in the city [end]
# 538[start] many people are standing on a fountain under a umbrella [end]
# 539[start] a woman is taking her picture in an open air market sideways [end]
# 540[start] street vendors uses food on a busy street [end]
# 541[start] three men are standing near a bike with their number 63 over the fence [end]
# 542[start] a female tennis player stands at a school gym [end]
# 543[start] a man in a red hoodie and a white puppy is asians [end]
# 544[start] a man looks at a well while four darkhaired net [end]
# 545[start] two people riding bicycles down a dirt road [end]
# 546[start] a young asian girl in a toy shop screaming [end]
# 547[start] a child looks at the edge of a stream that are in water [end]
# 548[start] two older men playing guitar [end]
# 549[start] a man in a white shirt and khakis is putting under a wheelbarrow [end]
# 550[start] two boys are making their way whilst a picture while a other young boy watches [end]
# 551[start] a man wearing black outfit is walking along side a hill carrying a black coat [end]
# 552[start] three people are standing on the side of a body of water while they are at the same time [end]
# 553[start] a man in a yellow shirt is doing a photo of a child in a big piece of machinery [end]
# 554[start] a child is thrown in the air while holding a toy jumper [end]
# 555[start] two women wearing white and blue shirts chat [end]
# 556[start] a man riding a bucking bull is in the center of two people [end]
# 557[start] a large black dog in the air with fake antlers on its mouth [end]
# 558[start] a man is taking a nap in the background of a large rock on it [end]
# 559[start] a woman with tattoos from a blue and yellow tube that is on her the other wearing a group of teammates [end]
# 560[start] people are wearing the same time down a paved road while watching [end]
# 561[start] two young girls are playing basketball while the other wearing red and one watches [end]
# 562[start] a lady in a bikini top is jumping in the water [end]
# 563[start] a man with a brown shirt and black pants playing a saxophone [end]
# 564[start] a woman with blondhair is drinking from a cup [end]
# 565[start] a young boy is laying on a toy train set with a camera [end]
# 566[start] two men yard work on a ground to examine [end]
# 567[start] the dog is shaking the rope of stones that his companion are [end]
# 568[start] an older man in a hat and women are in a small tub [end]
# 569[start] a man is laying on a piece of pottery that he is all his on his face off a set of his next to him [end]
# 570[start] a little girl is sticking her hand out of her while walking smile [end]
# 571[start] a woman with black hair and a red shirt is pointing to a flute while next to his coach holding a soda [end]
# 572[start] a man is being pulled through the air by a worker [end]
# 573[start] two dogs jogging with the snow in the water [end]
# 574[start] a woman with a flowered top is putting laundry up to her hand on her arm [end]
# 575[start] two hockey players try to perform what he has fallen asleep while the ball [end]
# 576[start] runner has fallen players in the air on a beautiful city [end]
# 577[start] group of people dancing in a classroom at a room with a lot of fire [end]
# 578[start] two children are getting ready to take a picture of a wood shot [end]
# 579[start] a young adult male wearing jeans and playing a card game [end]
# 580[start] a person in a yellow shirt is in a public area [end]
# 581[start] swimmers in a lake scene by the child who is sitting on a sunny day [end]
# 582[start] a crowd of people at a cement car with it [end]
# 583[start] a dog jumps through the field on its mouth [end]
# 584[start] a group of women are in an area happily with tourist [end]
# 585[start] a native american in a red and blue outfit swings at a craft [end]
# 586[start] a young boy is being pulled by another boy by a boat [end]
# 587[start] the picture is of a young child who is getting his head done coming out of her [end]
# 588[start] from about to jump into a light rail in a latin american area [end]
# 589[start] the picture of a car along with a mural of an orange and white shirt the right side of the sidewalk to it with its on the right is in the right is going train tracks [end]
# 590[start] two men behind a bar are using a sweater of them in a rural area [end]
# 591[start] men and women waiting for their cue card to walk [end]
# 592[start] children are busy talking to each other [end]
# 593[start] a man is singing into a microphone while playing a live game [end]
# 594[start] a singer singing with a band playing drums [end]
# 595[start] an older woman with a blue hat on sitting on a railroad tracks and is flipping over her [end]
# 596[start] a man in a black shirt and khaki shorts his matching shirt [end]
# 597[start] a person in a white shirt is holding a loaf of bread in a band [end]
# 598[start] blond man in black pants serving the backwards [end]
# 599[start] a girl is at a karate tournament that is held down with a group of spectators [end]
# 600[start] an artist is working on a craft pot of an aircraft [end]
# 601[start] a man in a blue jacket is jumping up on a horse with a bunch of grass [end]
# 602[start] the child is dressed up at the house party pitching motion [end]
# 603[start] two teams playing ball are in a game of soccer [end]
# 604[start] several young women with fur jacket [end]
# 605[start] a young girl is playing a toy while wearing a pink tutu [end]
# 606[start] a man is playing a live with the balance beam in his hand [end]
# 607[start] a man who is partly wave has reacting to is caught each other in the air over a shoelaces [end]
# 608[start] end of a girls game helping paper plate in the background are participating in a play [end]
# 609[start] a group of people in black and white clothing twirl sticks on the ends of a woman with a line [end]
# 610[start] a female tennis player in a red jacket is practicing her form with at [end]
# 611[start] a group of people are walking in a marathon [end]
# 612[start] a woman and a young girl are at a desk with a tent in front of them [end]
# 613[start] a black man in a superman shirt looks on as another man wearing sunglasses [end]
# 614[start] a little girl is walking by a small child [end]
# 615[start] a man with a brown hair in front of a brick building with a british [end]
# 616[start] two children are engaged in a gymnasium together [end]
# 617[start] the woman is in the picture of a man and a woman in the picture of a couple are using her [end]
# 618[start] a team of young children doing a routine at a concert [end]
# 619[start] a man and a woman are sitting down on a bench while looking at a passenger is seen from behind a small package [end]
# 620[start] on a street corner using teal colored houses are painted in a white setting [end]
# 621[start] several people are conversing in an outdoor festival [end]
# 622[start] a group of people playing music on a stage [end]
# 623[start] this is a man who is bent over working on a public square [end]
# 624[start] two children play on a playground [end]
# ...
# 816[start] two dogs are playing with a ball in the surf [end]
# 817[start] a man with a bright colored helmet is sitting on top of a motorcycle [end]
# 818[start] a man is standing on a wall with a yellow bag in front of a large group [end]
# 819[start] looking out the frame of a wooden structure in green and white knee [end]
# 820[start] a blond boy with a blue shirt sitting at a table [end]
# 821[start] a man in a white shirt and blue jeans looks on as he stands at the same time with another man wearing a to him [end]
# 822[start] people are playing golf at the water in a public area [end]
# 823[start] four young boys are posing with a man in the back of a drink [end]
# 824[start] a street scene with bicycle all over her head [end]
# 825[start] a street performer dressed in a construction outfit riding a bike with one is going to the other where [end]
# 826[start] a person sitting in front of a crowd of people [end]
# 827[start] a man is waiting for the train to arrive [end]
# 828[start] three white men jumping into the air in a group [end]
# 829[start] a singer sings at the man in the middle of his car [end]
# 830[start] the gymnast is taken at the teenage kids making the air [end]
# 831[start] a woman in a striped shirt and carrying a large orange shirt is at a museum of plastic sheets [end]
# 832[start] a rally car drivers on its starting team of a crowd [end]
# 833[start] several people are waiting to buy a customer at a display of wood [end]
# 834[start] two girls are playing soccer ball that is attempt to hit the ball [end]
# 835[start] an older man is pouring a container of ice cream with his hand [end]
# 836[start] six people dressed in some sort of river fix [end]
# 837[start] two little boys are playing fetch [end]
# 838[start] a woman is preparing to serve the ball [end]
# 839[start] two men wearing shorts are working on a bright blue loom [end]
# 840[start] a man and woman are doing a routine at a small boat [end]
# 841[start] there is a man getting his way through a event carrying a telescope [end]
# 842[start] a man and woman are enjoying a drink in the sprinkler [end]
# 843[start] a soldier is standing up a group of young people at work to [end]
# 844[start] two teenage boys are walking down a street with greenery [end]
# 845[start] a woman in a restaurant is drinking a soda that is a man are at a restaurant of shoppers [end]
# 846[start] a woman in a blue uniform stands on a cloudy day [end]
# 847[start] a man wearing shorts is gathering in front of a man wearing a blue shirt and jeans [end]
# 848[start] a man is feeding a baby in a large body of water [end]
# 849[start] a young boy jumping in the air in blue and yellow on a bicycle race [end]
# 850[start] a little baby wearing a black and toy is sleeping on a tree [end]
# 851[start] two children are lying down on the floor and are underneath a large group [end]
# 852[start] two people converse on a cloudy blue jeans and a group of onlookers [end]
# 853[start] a native american woman working on a cloudy day [end]
# 854[start] children are running a soccer ball during a game [end]
# 855[start] two children are shown in a clear blue and white below a set of trees [end]
# 856[start] two dogs run through a field looking at each other [end]
# 857[start] a drummer and a younger man in a dark outfit [end]
# 858[start] three people are walking on a busy area with a shaved [end]
# 859[start] a group of people at a large group of people are gathering [end]
# 860[start] a woman is peeking through a tank top of water in a transit station [end]
# 861[start] little girl jumping in a white and blue toy firetruck at the space with a pink frame [end]
# 862[start] a young man jumping up a serve those in his purple [end]
# 863[start] a skier flies through the air as he tries to throw the ball down during a game [end]
# 864[start] three girls are riding horses to the kid of teen in a back of himself [end]
# 865[start] a woman in an elaborate tank top is singing at a fun while posing with a woman watches [end]
# 866[start] a man is working on a kitchen of cheese in a piece of art [end]
# 867[start] a man is pushing a lady a mime in her peers [end]
# 868[start] a woman sings at a book while a man plays a guitar player [end]
# 869[start] the man in the center of a person wearing a helmet is blond house with a black and is loading poles [end]
# 870[start] a worker is holding on to a grim [end]
# 871[start] several people are standing around a pot and a woman dressed in a white and black pants [end]
# 872[start] a mountain biker wearing glasses is sitting in front of a piece of art that says singing [end]
# 873[start] a woman with sunglasses and a blue cheerleading outfit performs on one man with a striped shirt passes in the top of him [end]
# 874[start] an old man examining a snack and reading [end]
# 875[start] a man with a beard is playing a violin while a women sits at a park bench [end]
# 876[start] a man is working on a construction site [end]
# 877[start] a man is hitting a baseball game of basketball [end]
# 878[start] a man stands in a beautiful flower pot looking to his left [end]
# 879[start] a baseball player wearing a red and white uniform is hitting a baseball with a baseball game while riding on it to the right [end]
# 880[start] a man in an orange outfit is sweeping up picking up a mound [end]
# 881[start] man in a purple shirt working on a ranchstyle house [end]
# 882[start] a man is leading an adult through a haircut with a small boy [end]
# 883[start] two women are making a funny face while standing for monkey a camera at a fight [end]
# 884[start] a man and woman are asleep on a bench [end]
# 885[start] a man and woman are sitting on a stool [end]
# 886[start] an outdoor platform driver kicking his next to be some sort of material [end]
# 887[start] two girls are sitting at a table while wearing womens lifestyle blankets [end]
# 888[start] a man running through some sand covered in the air [end]
# 889[start] a male dancer in a black suit jumps in the air [end]
# 890[start] a man is sitting on a suitcase beside him [end]
# 891[start] a bearded man in a suit jacket sits at a log jacket is high boots [end]
# 892[start] man on a skateboarding from a well coming table on a clear sunny day [end]
# 893[start] a man with a large hat on is attending an operation [end]
# 894[start] the closeup of the bartender is of a woman while holding a happily make he eats [end]
# 895[start] a man and a woman are getting on a cellphone while pushing a rock [end]
# 896[start] a young boy showing off the skills [end]
# 897[start] a man wearing a gray shirt is browsing a karate tournament that approaches in a bowling alley [end]
# 898[start] a woman stands in front of a group of smiling [end]
# 899[start] someone in a suit sits at a hotel proclaim they stand [end]
# 900[start] a young boy trying to get his picture at a sporting event [end]
# 901[start] a man with a bright green jacket and a bicycle is walking along a car that has a large cruise ship [end]
# 902[start] a young man is getting ready to kick a soccer ball [end]
# 903[start] a female runner prepares to take a ride in a studio [end]
# 904[start] two men one in a blue and white uniforms are dressed in red and black pants are sparring with the same time [end]
# 905[start] a group of friends lay on a bench [end]
# 906[start] a man is seen while holding a microphone from a man [end]
# 907[start] tourists on a hillside with has closed blue equipment [end]
# 908[start] a woman is getting her haircut by a woman in a grand canyon [end]
# 909[start] two bicyclists ride their heads down a bowling alley [end]
# 910[start] a man is standing alone on a sidewalk overlooking a music [end]
# 911[start] a man with a hand raised with a top of a black and yellow shirt that is older of a bicycle [end]
# 912[start] several hikers are competing for the soccer ball to each other [end]
# 913[start] two people on a street the one trying to hold the aim their wearing white and is going to a white spots during a field [end]
# 914[start] three men are riding horses in a race [end]
# 915[start] a black man wearing a white shirt and blue shorts is shown with only his walking hand in the sunlight coming down from atop a large canyon [end]
# 916[start] a man with a beard is standing underneath a red and holding a piece of art in the same time [end]
# 917[start] swimmers gather for a different dry ice cream cone in an urban environment [end]
# 918[start] a young boy smiles while he is miniature socks and some sort of pipe to sell [end]
# 919[start] a young boy in a burgundy hat is throwing a game in a pool of water [end]
# 920[start] five individuals in a military uniform [end]
# 921[start] two girls are about to play a softball while the others watch [end]
# 922[start] children playing in a field [end]
# 923[start] a female performer is playing a guitar with a light colored sheet [end]
# 924[start] boys are competing in a fencing competition [end]
# 925[start] a group of black people in white uniforms riding on a sunny day [end]
# 926[start] a group of people are preparing to dance in a band who are playing their instruments [end]
# 927[start] a man is filling a bunch of clay equipment in a blue and a tie [end]
# 928[start] the boy jumps with the name tag at the camera [end]
# 929[start] a baby in a swing and a living room with a bunch of grass [end]
# 930[start] these people are having a good time while enjoying the day [end]
# 931[start] i am looking a man surrounded by a screen little lady with a tattoo [end]
# 932[start] a young man rides his skateboard on a set of which is a small sons [end]
# 933[start] people riding the boat on the ground in a cold winter day along the suspended by a sunset [end]
# 934[start] two men dressed in a act out scene of them [end]
# 935[start] a woman is taking pictures using their zoom lenses at a diner [end]
# 936[start] a group of people begin a evening race [end]
# 937[start] a person in winter clothes poses with a group of float in the air around a fountain [end]
# 938[start] a man is holding a presentation in front of a circle [end]
# 939[start] a man in an outdoor clothing is sitting at a man that is sitting on a sunny day [end]
# 940[start] a man with a hand on in a microphone and a fisherman is on it is at a street [end]
# 941[start] a young girl is playing with a pink and yellow balloon animal prizes [end]
# 942[start] man in a helmet blue shirt riding his bike on a dirt road [end]
# 943[start] several young adults staring at a model home while wearing summer dresses [end]
# 944[start] a young boy dressed in black and yellow is floating on the lap [end]
# 945[start] a little girl in a dress and she is looking at another one dog wearing a black coat [end]
# 946[start] a man is adjusting a standing near a body of water while his in [end]
# 947[start] there is a man putting up a turkey on the project [end]
# 948[start] a child is coming down from atop a blanket [end]
# 949[start] while doing this a back tries outside cutting into their steel container [end]
# 950[start] young women and children are in a gym of the same direction in a net [end]
# 951[start] small child in a green shirt is playing with some air mattresses in a american flag [end]
# 952[start] a man in a wheelchair is measuring a large gray day [end]
# 953[start] a son and his pet student are on a playground equipment [end]
# 954[start] three men are competing in a motorcycle run [end]
# 955[start] two men watch a brick ball and the other jump over the stone surface [end]
# 956[start] a soldier looks through a telescope in to view [end]
# 957[start] a group of young adults take a break from riding a bike [end]
# 958[start] a man is looking out while putting up some bling on a newspaper [end]
# 959[start] a young boy and girl are smiling while holding a picture of them [end]
# 960[start] two men are wrestling the same time while kicking the ball in a field of them [end]
# 961[start] a bike rider in a yellow shirt is in midair with a trick [end]
# 962[start] two male guys are coming out of a fenced in area with one in statue [end]
# 963[start] two men are kayaking and some ornate on a bend yard [end]
# 964[start] two men are inspecting the same time while kicking the ball during a a game [end]
# 965[start] a man with a bike helmet rides a bucking horse and kid on top of rodeo [end]
# 966[start] a group of men dressed in costumes are performing [end]
# 967[start] a man and a woman are tackling an ethnic couple that are dressed up possibly spanish for the acoustic next to be sold at it [end]
# 968[start] a team takes in the water at a superman shirt [end]
# 969[start] a group of people walk out of the costa cloudy day for the others [end]
# 970[start] a man is holding a camera from a fire pit [end]
# 971[start] a man on a stage playing a flute with a white soda [end]
# 972[start] four young children playing with lego set in green and toy tools [end]
# 973[start] a group of people at a street performer dressed up working on a sports court [end]
# 974[start] a bicycle rider driving a red and yellow shirt is on a mound of one young with a motorcycle [end]
# 975[start] three dogs are playing in the water [end]
# 976[start] a man is performing a jump while a little boy swings his drums [end]
# 977[start] a group of young girls playing a game of football [end]
# 978[start] a man watches as a woman sits on a rail on a storefront [end]
# 979[start] the top of the biker riding away from the gate with his string [end]
# 980[start] a team of men in camouflage is skating and the same time down and leaving the tree [end]
# 981[start] a group of people in green and white pants are walking across a sand fountain [end]
# 982[start] a man in a colorful shirt is playing a trumpet [end]
# 983[start] the guy wearing a white tshirt is on a skateboard in front of young asian clothing [end]
# 984[start] mother and daughter posing for a photo [end]
# 985[start] a little boy uses a drill jumping to get a toy soccer ball [end]
# 986[start] two bicyclists racing along a road with people [end]
# 987[start] a girl wearing a white and blue dress is being contested by an st patricks day [end]
# 988[start] a team of young boys is using boards to perform [end]
# 989[start] two people are wearing flower loses playing drink [end]
# 990[start] two bicyclists travel by with people while they walk along a street [end]
# 991[start] a city street with a man in white shirt and down at the top of a road [end]
# 992[start] two black men wearing black and white uniforms are performing in a crowd of people competing [end]
# 993[start] two men one with a black and one is standing in the other is playing a guitar with a group of grass [end]
# 994[start] a tourist player from holding a plastic bag in a bookstore [end]
# 995[start] three people are walking on a track toward a parade [end]
# 996[start] football players completing a kick their game of clear leader in for the parade [end]
# 997[start] several uniformed men are praying that is sitting in an outdoor pole [end]
# 998[start] two indian women are jumping into traditional attire [end]
# 999[start] three children are standing near a wooden structure [end]
# 1000[start] a group of people walking around [end]
# 1001[start] two women walking down the beach holding hands [end]
# 1002[start] a boy sits on the rocks in the water looking close to a soccer ball [end]
# 1003[start] a woman stands on a pole that has a row of the water and is on a sunny day [end]
# 1004[start] a woman in a blue shirt is standing on the sidewalk and he is looking at a sporting goods [end]
# 1005[start] a group of three people are having a conversation with one another person [end]
# 1006[start] two men are standing on a bench to be some sort of exercise [end]
# 1007[start] a person in a blue and red shirt is serving stairs during the photo [end]
# 1008[start] farmers are cleaning up umbrellas on the incoming is juggling [end]
# 1009[start] a woman is participating in a fencing match [end]
# 1010[start] a group of men stand in front of a business [end]
# 1011[start] an older kitchen woman wears her hair and looks at the edge of a tennis match [end]
# 1012[start] two men are standing on throwing stones [end]
# 1013[start] two women wearing red and a man standing on top of a trough the sidewalk [end]
